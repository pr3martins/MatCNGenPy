# %% [markdown]
# # MatCNGenPy
#
# This is a python implementation of the algorithms described in
# **Efficient Match-Based Candidate Network Generation for Keyword
# Queries over Relational Databases** paper.
#
#
# ## Installation
# - Install virtalenv
# - Run ```source bin/activate``` to enter in the virtual enviroment
# - Run ```pip install -r requirements.txt```
# - Run ```python ModCNGen.py

# %%
import psycopg2
from psycopg2 import sql
from pprint import pprint as pp
from collections import defaultdict
import string
import itertools
import copy
from math import log1p
from queue import deque

# %%
# Connect to an existing database
conn = psycopg2.connect("dbname=imdb user=postgres")

# Open a cursor to perform database operations
cur = conn.cursor()

def createInvertedList():
    #Output: wordHash (Term Index) with this structure below
    #map['word'] = [ 'table': ( {column} , ['ctid'] ) ]

    '''
    The Term Index is built in a preprocessing step that scans only
    once all the relations over which the queries will be issued.
    '''
    
    wordHash = {}
    wordCount = {}
    
    # Get list of tablenames
    cur.execute("SELECT DISTINCT tablename FROM pg_tables WHERE schemaname!='pg_catalog' AND schemaname !='information_schema';")
    for table in cur.fetchall():
        table_name = table[0]
        print('INDEXING TABLE ',table_name)
        
        wordCount[table_name] = {}
        
        #Get all tuples for this tablename
        cur.execute(
            sql.SQL("SELECT ctid, * FROM {};").format(sql.Identifier(table_name))
            #NOTE: sql.SQL is needed to specify this parameter as table name (can't be passed as execute second parameter)
        )

        for row in cur.fetchall():
            for column in range(1,len(row)):
                column_name = cur.description[column][0]   
                ctid = row[0]

                #NOTE: Need to remove stopwords
                for word in [word.strip(string.punctuation) for word in str(row[column]).lower().split()]:

                    #If word entry doesn't exists, it will be inicialized (setdefault method),
                    #Append the location for this word
                    wordHash.setdefault(word, {})                    
                    wordHash[word].setdefault( table_name , {} )
                    wordHash[word][table_name].setdefault( column_name , [] ).append(ctid)
                    
                    wordCount[table_name].setdefault(column_name,set())
                    wordCount[table_name][column_name].add(word)
        
        #Count words
        for (column_name,wordSet) in wordCount[table_name].items():
            aux = len(wordSet)
            wordSet.clear()
            wordCount[table_name][column_name]=aux
            #print(table_name,'.',column_name,': ',wordCount[table_name][column_name])

    print ('INVERTED INDEX CREATED')
    return (wordHash,wordCount)

(wordHash,wordCount) = createInvertedList()
# Out:
# INDEXING TABLE  char_name
# INDEXING TABLE  name
# INDEXING TABLE  movie_info
# INDEXING TABLE  role_type
# INDEXING TABLE  title
# INDEXING TABLE  cast_info
# INVERTED INDEX CREATED

# %%
def processIAF(wordHash,wordCount):
    
    total_attributes = sum([len(relation) for relation in wordCount.values()]) 
    
    for (termo, values) in wordHash.items():
        for (table, attributes) in values.items():
            for (column,ctids) in attributes.items():
                
                num_occurences = len(ctids)
                
                IAF = log1p(total_attributes/num_occurences)
                
                wordHash[termo][table][column] = (IAF,ctids)

processIAF(wordHash,wordCount)

# %%
def TSFind(Q):
    #Input:  A keyword query Q=[k1, k2, . . . , km]
    #Output: Set of non-free and non-empty tuple-sets Rq

    '''
    The tuple-set Rki contains the tuples of Ri that contain all
    terms of K and no other keywords from Q
    '''
    
    #Part 1: Find sets of tuples containing each keyword
    global P
    P = {}
    for keyword in Q:
        tupleset = set()
        for (table,attributes) in wordHash.get(keyword).items():
            for (iaf,ctids) in attributes.values():
                for ctid in ctids:
                    tupleset.add( (table,ctid) )
        P[frozenset([keyword])] = tupleset

    #Part 2: Find sets of tuples containing larger termsets
    P = TSInter(P)

    #Part 3:Build tuple-sets
    Rq = set()
    for keyword , tuples in P.items():
        for (table,ctid) in tuples:
            Rq.add( (table,keyword) )
    print ('TUPLE SETS CREATED')
    return Rq


def TSInter(P):
    #Input: A Set of non-empty tuple-sets for each keyword alone P 
    #Output: The Set P, but now including larger termsets (process Intersections)

    '''
    Termset is any non-empty subset K of the terms of a query Q        
    '''
    
    Pprev = {}
    Pprev=copy.deepcopy(P)
    Pcurr = {}

    combinations = [x for x in itertools.combinations(Pprev.keys(),2)]
    for ( Ki , Kj ) in combinations[0:4]:
        Tki = Pprev[Ki]
        Tkj = Pprev[Kj]
        
        X = Ki | Kj
        Tx = Tki & Tkj        
        
        if len(Tx) > 0:            
            Pcurr[X]  = Tx            
            Pprev[Ki] = Tki - Tx         
            Pprev[Kj] = Tkj - Tx
            
    if Pcurr != {}:
        Pcurr = copy.deepcopy(TSInter(Pcurr))
        
    #Pprev = Pprev U Pcurr
    Pprev.update(Pcurr)     
    return Pprev       

Q = ['denzel','washington','gangster']
Rq = TSFind(Q)
pp(Rq)
# Out:
# TUPLE SETS CREATED
# {('cast_info', frozenset({'denzel', 'washington'})),
#  ('cast_info', frozenset({'gangster'})),
#  ('cast_info', frozenset({'denzel'})),
#  ('cast_info', frozenset({'washington'})),
#  ('char_name', frozenset({'denzel'})),
#  ('char_name', frozenset({'washington'})),
#  ('char_name', frozenset({'gangster'})),
#  ('movie_info', frozenset({'washington'})),
#  ('movie_info', frozenset({'denzel'})),
#  ('movie_info', frozenset({'denzel', 'washington'})),
#  ('movie_info', frozenset({'gangster'})),
#  ('movie_info', frozenset({'gangster', 'washington'})),
#  ('name', frozenset({'denzel'})),
#  ('name', frozenset({'washington'})),
#  ('name', frozenset({'denzel', 'washington'})),
#  ('title', frozenset({'gangster'})),
#  ('title', frozenset({'washington'}))}

# %%
#Rq[frozenset({'denzel', 'washington'})]
#Mq = QMGen(Q,Rq)
def QMGen(Q,Rq):
    #Input:  A keyword query Q, The set of non-empty non-free tuple-sets Rq
    #Output: The set Mq of query matches for Q
    
    '''
    Query match is a set of tuple-sets that, if properly joined,
    can produce networks of tuples that fulfill the query. They
    can be thought as the leaves of a Candidate Network.
    
    '''
    
    Mq = []
    for i in range(1,len(Q)+1):
        for subset in itertools.combinations(Rq,i):
            if(MinimalCover(subset,Q)):
                Mq.append(subset)
    print ('QUERY MATCHES CREATED')
    return Mq


def MinimalCover(MC, Q):
    #Input:  A subset MC (Match Candidate) to be checked as total and minimal cover
    #Output: If the match candidate is a TOTAL and MINIMAL cover

    '''
    Total:   every keyword is contained in at least one tuple-set of the match
    
    Minimal: we can not remove any tuple-set from the match and still have a
             total cover.    
    '''
    
    Subset = [termset for table,termset in MC]
    u = set().union(*Subset)    
    
    isTotal = (u == set(Q))
    for element in Subset:
        
        new_u = list(Subset)
        new_u.remove(element)
        
        new_u = set().union(*new_u)
        
        if new_u == set(Q):
            return False
    
    return isTotal

Mq = QMGen(Q,Rq)

for M in Mq:
    print(M,'\n\n')
# Out:
# QUERY MATCHES CREATED
# (('movie_info', frozenset({'denzel', 'washington'})), ('movie_info', frozenset({'gangster', 'washington'})))
#
#
# (('movie_info', frozenset({'denzel', 'washington'})), ('title', frozenset({'gangster'})))
#
#
# (('movie_info', frozenset({'denzel', 'washington'})), ('char_name', frozenset({'gangster'})))
#
#
# (('movie_info', frozenset({'denzel', 'washington'})), ('cast_info', frozenset({'gangster'})))
#
#
# (('movie_info', frozenset({'denzel', 'washington'})), ('movie_info', frozenset({'gangster'})))
#
#
# (('char_name', frozenset({'denzel'})), ('movie_info', frozenset({'gangster', 'washington'})))
#
#
# (('movie_info', frozenset({'gangster', 'washington'})), ('name', frozenset({'denzel', 'washington'})))
#
#
# (('movie_info', frozenset({'gangster', 'washington'})), ('cast_info', frozenset({'denzel', 'washington'})))
#
#
# (('movie_info', frozenset({'gangster', 'washington'})), ('name', frozenset({'denzel'})))
#
#
# (('movie_info', frozenset({'gangster', 'washington'})), ('cast_info', frozenset({'denzel'})))
#
#
# (('movie_info', frozenset({'gangster', 'washington'})), ('movie_info', frozenset({'denzel'})))
#
#
# (('title', frozenset({'gangster'})), ('name', frozenset({'denzel', 'washington'})))
#
#
# (('title', frozenset({'gangster'})), ('cast_info', frozenset({'denzel', 'washington'})))
#
#
# (('char_name', frozenset({'gangster'})), ('name', frozenset({'denzel', 'washington'})))
#
#
# (('char_name', frozenset({'gangster'})), ('cast_info', frozenset({'denzel', 'washington'})))
#
#
# (('name', frozenset({'denzel', 'washington'})), ('cast_info', frozenset({'gangster'})))
#
#
# (('name', frozenset({'denzel', 'washington'})), ('movie_info', frozenset({'gangster'})))
#
#
# (('cast_info', frozenset({'denzel', 'washington'})), ('cast_info', frozenset({'gangster'})))
#
#
# (('cast_info', frozenset({'denzel', 'washington'})), ('movie_info', frozenset({'gangster'})))
#
#
# (('char_name', frozenset({'denzel'})), ('char_name', frozenset({'washington'})), ('title', frozenset({'gangster'})))
#
#
# (('char_name', frozenset({'denzel'})), ('char_name', frozenset({'washington'})), ('char_name', frozenset({'gangster'})))
#
#
# (('char_name', frozenset({'denzel'})), ('char_name', frozenset({'washington'})), ('cast_info', frozenset({'gangster'})))
#
#
# (('char_name', frozenset({'denzel'})), ('char_name', frozenset({'washington'})), ('movie_info', frozenset({'gangster'})))
#
#
# (('char_name', frozenset({'denzel'})), ('title', frozenset({'gangster'})), ('title', frozenset({'washington'})))
#
#
# (('char_name', frozenset({'denzel'})), ('title', frozenset({'gangster'})), ('movie_info', frozenset({'washington'})))
#
#
# (('char_name', frozenset({'denzel'})), ('title', frozenset({'gangster'})), ('name', frozenset({'washington'})))
#
#
# (('char_name', frozenset({'denzel'})), ('title', frozenset({'gangster'})), ('cast_info', frozenset({'washington'})))
#
#
# (('char_name', frozenset({'denzel'})), ('title', frozenset({'washington'})), ('char_name', frozenset({'gangster'})))
#
#
# (('char_name', frozenset({'denzel'})), ('title', frozenset({'washington'})), ('cast_info', frozenset({'gangster'})))
#
#
# (('char_name', frozenset({'denzel'})), ('title', frozenset({'washington'})), ('movie_info', frozenset({'gangster'})))
#
#
# (('char_name', frozenset({'denzel'})), ('char_name', frozenset({'gangster'})), ('movie_info', frozenset({'washington'})))
#
#
# (('char_name', frozenset({'denzel'})), ('char_name', frozenset({'gangster'})), ('name', frozenset({'washington'})))
#
#
# (('char_name', frozenset({'denzel'})), ('char_name', frozenset({'gangster'})), ('cast_info', frozenset({'washington'})))
#
#
# (('char_name', frozenset({'denzel'})), ('movie_info', frozenset({'washington'})), ('cast_info', frozenset({'gangster'})))
#
#
# (('char_name', frozenset({'denzel'})), ('movie_info', frozenset({'washington'})), ('movie_info', frozenset({'gangster'})))
#
#
# (('char_name', frozenset({'denzel'})), ('cast_info', frozenset({'gangster'})), ('name', frozenset({'washington'})))
#
#
# (('char_name', frozenset({'denzel'})), ('cast_info', frozenset({'gangster'})), ('cast_info', frozenset({'washington'})))
#
#
# (('char_name', frozenset({'denzel'})), ('name', frozenset({'washington'})), ('movie_info', frozenset({'gangster'})))
#
#
# (('char_name', frozenset({'denzel'})), ('cast_info', frozenset({'washington'})), ('movie_info', frozenset({'gangster'})))
#
#
# (('char_name', frozenset({'washington'})), ('title', frozenset({'gangster'})), ('name', frozenset({'denzel'})))
#
#
# (('char_name', frozenset({'washington'})), ('title', frozenset({'gangster'})), ('cast_info', frozenset({'denzel'})))
#
#
# (('char_name', frozenset({'washington'})), ('title', frozenset({'gangster'})), ('movie_info', frozenset({'denzel'})))
#
#
# (('char_name', frozenset({'washington'})), ('char_name', frozenset({'gangster'})), ('name', frozenset({'denzel'})))
#
#
# (('char_name', frozenset({'washington'})), ('char_name', frozenset({'gangster'})), ('cast_info', frozenset({'denzel'})))
#
#
# (('char_name', frozenset({'washington'})), ('char_name', frozenset({'gangster'})), ('movie_info', frozenset({'denzel'})))
#
#
# (('char_name', frozenset({'washington'})), ('cast_info', frozenset({'gangster'})), ('name', frozenset({'denzel'})))
#
#
# (('char_name', frozenset({'washington'})), ('cast_info', frozenset({'gangster'})), ('cast_info', frozenset({'denzel'})))
#
#
# (('char_name', frozenset({'washington'})), ('cast_info', frozenset({'gangster'})), ('movie_info', frozenset({'denzel'})))
#
#
# (('char_name', frozenset({'washington'})), ('name', frozenset({'denzel'})), ('movie_info', frozenset({'gangster'})))
#
#
# (('char_name', frozenset({'washington'})), ('cast_info', frozenset({'denzel'})), ('movie_info', frozenset({'gangster'})))
#
#
# (('char_name', frozenset({'washington'})), ('movie_info', frozenset({'gangster'})), ('movie_info', frozenset({'denzel'})))
#
#
# (('title', frozenset({'gangster'})), ('title', frozenset({'washington'})), ('name', frozenset({'denzel'})))
#
#
# (('title', frozenset({'gangster'})), ('title', frozenset({'washington'})), ('cast_info', frozenset({'denzel'})))
#
#
# (('title', frozenset({'gangster'})), ('title', frozenset({'washington'})), ('movie_info', frozenset({'denzel'})))
#
#
# (('title', frozenset({'gangster'})), ('movie_info', frozenset({'washington'})), ('name', frozenset({'denzel'})))
#
#
# (('title', frozenset({'gangster'})), ('movie_info', frozenset({'washington'})), ('cast_info', frozenset({'denzel'})))
#
#
# (('title', frozenset({'gangster'})), ('movie_info', frozenset({'washington'})), ('movie_info', frozenset({'denzel'})))
#
#
# (('title', frozenset({'gangster'})), ('name', frozenset({'denzel'})), ('name', frozenset({'washington'})))
#
#
# (('title', frozenset({'gangster'})), ('name', frozenset({'denzel'})), ('cast_info', frozenset({'washington'})))
#
#
# (('title', frozenset({'gangster'})), ('name', frozenset({'washington'})), ('cast_info', frozenset({'denzel'})))
#
#
# (('title', frozenset({'gangster'})), ('name', frozenset({'washington'})), ('movie_info', frozenset({'denzel'})))
#
#
# (('title', frozenset({'gangster'})), ('cast_info', frozenset({'denzel'})), ('cast_info', frozenset({'washington'})))
#
#
# (('title', frozenset({'gangster'})), ('cast_info', frozenset({'washington'})), ('movie_info', frozenset({'denzel'})))
#
#
# (('title', frozenset({'washington'})), ('char_name', frozenset({'gangster'})), ('name', frozenset({'denzel'})))
#
#
# (('title', frozenset({'washington'})), ('char_name', frozenset({'gangster'})), ('cast_info', frozenset({'denzel'})))
#
#
# (('title', frozenset({'washington'})), ('char_name', frozenset({'gangster'})), ('movie_info', frozenset({'denzel'})))
#
#
# (('title', frozenset({'washington'})), ('cast_info', frozenset({'gangster'})), ('name', frozenset({'denzel'})))
#
#
# (('title', frozenset({'washington'})), ('cast_info', frozenset({'gangster'})), ('cast_info', frozenset({'denzel'})))
#
#
# (('title', frozenset({'washington'})), ('cast_info', frozenset({'gangster'})), ('movie_info', frozenset({'denzel'})))
#
#
# (('title', frozenset({'washington'})), ('name', frozenset({'denzel'})), ('movie_info', frozenset({'gangster'})))
#
#
# (('title', frozenset({'washington'})), ('cast_info', frozenset({'denzel'})), ('movie_info', frozenset({'gangster'})))
#
#
# (('title', frozenset({'washington'})), ('movie_info', frozenset({'gangster'})), ('movie_info', frozenset({'denzel'})))
#
#
# (('char_name', frozenset({'gangster'})), ('movie_info', frozenset({'washington'})), ('name', frozenset({'denzel'})))
#
#
# (('char_name', frozenset({'gangster'})), ('movie_info', frozenset({'washington'})), ('cast_info', frozenset({'denzel'})))
#
#
# (('char_name', frozenset({'gangster'})), ('movie_info', frozenset({'washington'})), ('movie_info', frozenset({'denzel'})))
#
#
# (('char_name', frozenset({'gangster'})), ('name', frozenset({'denzel'})), ('name', frozenset({'washington'})))
#
#
# (('char_name', frozenset({'gangster'})), ('name', frozenset({'denzel'})), ('cast_info', frozenset({'washington'})))
#
#
# (('char_name', frozenset({'gangster'})), ('name', frozenset({'washington'})), ('cast_info', frozenset({'denzel'})))
#
#
# (('char_name', frozenset({'gangster'})), ('name', frozenset({'washington'})), ('movie_info', frozenset({'denzel'})))
#
#
# (('char_name', frozenset({'gangster'})), ('cast_info', frozenset({'denzel'})), ('cast_info', frozenset({'washington'})))
#
#
# (('char_name', frozenset({'gangster'})), ('cast_info', frozenset({'washington'})), ('movie_info', frozenset({'denzel'})))
#
#
# (('movie_info', frozenset({'washington'})), ('cast_info', frozenset({'gangster'})), ('name', frozenset({'denzel'})))
#
#
# (('movie_info', frozenset({'washington'})), ('cast_info', frozenset({'gangster'})), ('cast_info', frozenset({'denzel'})))
#
#
# (('movie_info', frozenset({'washington'})), ('cast_info', frozenset({'gangster'})), ('movie_info', frozenset({'denzel'})))
#
#
# (('movie_info', frozenset({'washington'})), ('name', frozenset({'denzel'})), ('movie_info', frozenset({'gangster'})))
#
#
# (('movie_info', frozenset({'washington'})), ('cast_info', frozenset({'denzel'})), ('movie_info', frozenset({'gangster'})))
#
#
# (('movie_info', frozenset({'washington'})), ('movie_info', frozenset({'gangster'})), ('movie_info', frozenset({'denzel'})))
#
#
# (('cast_info', frozenset({'gangster'})), ('name', frozenset({'denzel'})), ('name', frozenset({'washington'})))
#
#
# (('cast_info', frozenset({'gangster'})), ('name', frozenset({'denzel'})), ('cast_info', frozenset({'washington'})))
#
#
# (('cast_info', frozenset({'gangster'})), ('name', frozenset({'washington'})), ('cast_info', frozenset({'denzel'})))
#
#
# (('cast_info', frozenset({'gangster'})), ('name', frozenset({'washington'})), ('movie_info', frozenset({'denzel'})))
#
#
# (('cast_info', frozenset({'gangster'})), ('cast_info', frozenset({'denzel'})), ('cast_info', frozenset({'washington'})))
#
#
# (('cast_info', frozenset({'gangster'})), ('cast_info', frozenset({'washington'})), ('movie_info', frozenset({'denzel'})))
#
#
# (('name', frozenset({'denzel'})), ('name', frozenset({'washington'})), ('movie_info', frozenset({'gangster'})))
#
#
# (('name', frozenset({'denzel'})), ('cast_info', frozenset({'washington'})), ('movie_info', frozenset({'gangster'})))
#
#
# (('name', frozenset({'washington'})), ('cast_info', frozenset({'denzel'})), ('movie_info', frozenset({'gangster'})))
#
#
# (('name', frozenset({'washington'})), ('movie_info', frozenset({'gangster'})), ('movie_info', frozenset({'denzel'})))
#
#
# (('cast_info', frozenset({'denzel'})), ('cast_info', frozenset({'washington'})), ('movie_info', frozenset({'gangster'})))
#
#
# (('cast_info', frozenset({'washington'})), ('movie_info', frozenset({'gangster'})), ('movie_info', frozenset({'denzel'})))

# %%
def getSchemaGraph():
    #Output: A Schema Graph G  with the structure below:
    # G['node'] = edges
    # G['table'] = { 'foreign_table' : (direction, column, foreign_column) }
    
    G = {} 
    cur.execute("SELECT tablename FROM pg_tables WHERE schemaname!='pg_catalog' AND schemaname !='information_schema';")
    for table in cur.fetchall():
        G.setdefault(table[0],{})
    
    sql = "SELECT DISTINCT \
                tc.table_name, kcu.column_name, \
                ccu.table_name AS foreign_table_name, ccu.column_name AS foreign_column_name \
            FROM information_schema.table_constraints AS tc  \
            JOIN information_schema.key_column_usage AS kcu \
                ON tc.constraint_name = kcu.constraint_name \
            JOIN information_schema.constraint_column_usage AS ccu \
                ON ccu.constraint_name = tc.constraint_name \
            WHERE constraint_type = 'FOREIGN KEY'"
    cur.execute(sql)
    relations = cur.fetchall()
    
    for (table,column,foreign_table,foreign_column) in relations:
        G[table][foreign_table] = (1,column, foreign_column)
        G[foreign_table][table] = (-1,foreign_column,column)
    print ('SCHEMA CREATED')
    return G

def MatchGraph(Rq, G, M):
    #Input:  The set of non-empty non-free tuple-sets Rq,
    #        The Schema Graph G,
    #        A Query Match M
    #Output: A Schema Graph Gts  with the structure below:
    # G['node'] = edges
    # G['table'] = { 'foreign_table' : (direction, column, foreign_column) }

    '''
    A Match Subgraph Gts[M] is a subgraph of G that contains:
        The set of free tuple-sets of G
        The query match M
    '''
    
    Gts = copy.deepcopy(G)
    
    tables = set()
    #Insert non-free nodes
    for (table , keywords) in M:
        Gts[(table,keywords)]=copy.deepcopy(Gts[table])
        for foreign_table , (direction,column,foreign_column) in Gts[(table,keywords)].items():
            Gts[foreign_table][(table,keywords)] = (direction*(-1),foreign_column,column)

    return Gts 

G = getSchemaGraph()
pp(G)

print('\n\nMATCH GRAPH FOR ',Mq[6],'\n')
Gts =  MatchGraph(Rq,G,Mq[6])
pp(Gts)
# Out:
# SCHEMA CREATED
# {'cast_info': {'char_name': (1, 'person_role_id', 'id'),
#                'name': (1, 'person_id', 'id'),
#                'role_type': (1, 'role_id', 'id'),
#                'title': (1, 'movie_id', 'id')},
#  'char_name': {'cast_info': (-1, 'id', 'person_role_id')},
#  'movie_info': {'title': (1, 'movie_id', 'id')},
#  'name': {'cast_info': (-1, 'id', 'person_id')},
#  'role_type': {'cast_info': (-1, 'id', 'role_id')},
#  'title': {'cast_info': (-1, 'id', 'movie_id'),
#            'movie_info': (-1, 'id', 'movie_id')}}
#
#
# MATCH GRAPH FOR  (('movie_info', frozenset({'gangster', 'washington'})), ('name', frozenset({'denzel', 'washington'})))
#
# {'cast_info': {'char_name': (1, 'person_role_id', 'id'),
#                'name': (1, 'person_id', 'id'),
#                'role_type': (1, 'role_id', 'id'),
#                'title': (1, 'movie_id', 'id'),
#                ('name', frozenset({'denzel', 'washington'})): (1,
#                                                                'person_id',
#                                                                'id')},
#  'char_name': {'cast_info': (-1, 'id', 'person_role_id')},
#  'movie_info': {'title': (1, 'movie_id', 'id')},
#  'name': {'cast_info': (-1, 'id', 'person_id')},
#  'role_type': {'cast_info': (-1, 'id', 'role_id')},
#  'title': {'cast_info': (-1, 'id', 'movie_id'),
#            'movie_info': (-1, 'id', 'movie_id'),
#            ('movie_info', frozenset({'gangster', 'washington'})): (-1,
#                                                                    'id',
#                                                                    'movie_id')},
#  ('movie_info', frozenset({'gangster', 'washington'})): {'title': (1,
#                                                                    'movie_id',
#                                                                    'id')},
#  ('name', frozenset({'denzel', 'washington'})): {'cast_info': (-1,
#                                                                'id',
#                                                                'person_id')}}

# %%
def containsMatch(Ji,M):
    for relation in M:
        if relation not in Ji:
            return False
    return True

def isJNTSound(Gts,Ji):
    if len(Ji)<3:
        return True
    for i in range(len(Ji)-2):
        if (Ji[i],)[0] == (Ji[i+2],)[0]:
            edge_info = Gts[Ji[i]][Ji[i+1]]
            if(edge_info[0] == -1):
                return False
    return True

#CN = SingleCN(Mq[0],Gts,5,Q)
def SingleCN(M,Gts,Tmax,Q):
    F = deque()
    J = [M[0]]
    F.append(J)
    while F:
        J = F.pop()
        u = J[-1]
        for (adjacent,edge_info) in Gts[u].items():
            if (type(adjacent) is str) or (adjacent not in J):
                Ji = J + [adjacent]
                if (Ji not in F) and (len(Ji)<Tmax) and (isJNTSound(Gts,Ji)):
                    if(containsMatch(Ji,M)):
                       return Ji
                    else:
                       F.append(Ji)
Cn = SingleCN(Mq[6],Gts,10,Q)
pp(Cn)
#Cn=[('movie_info', frozenset({'gangster'})), 'title', ('cast_info', frozenset({'washington', 'denzel'}))]
# Out:
# [('movie_info', frozenset({'gangster', 'washington'})),
#  'title',
#  'cast_info',
#  ('name', frozenset({'denzel', 'washington'}))]

# %%
for M in Mq: 
    Gts =  MatchGraph(Rq,G,M)
    Cn = SingleCN(M,Gts,10,Q)
    
    # Connect to an existing database
    conn = psycopg2.connect("dbname=imdb user=postgres")

    # Open a cursor to perform database operations
    cur = conn.cursor()
    
    if Cn is not None:
        print('===============================================================================================================================================\n')
        pp(Cn)
        sqlText = getSQLfromCN(Gts,Cn)
        print('\n',sqlText,'\n')
        cur.execute(sqlText)
        results = cur.fetchall()
        print(results)
# Out:
# ===============================================================================================================================================
#
# [('movie_info', frozenset({'denzel', 'washington'})),
#  'title',
#  ('movie_info', frozenset({'gangster', 'washington'}))]
#
#  SELECT * FROM title, movie_info WHERE movie_info.info ILIKE '%denzel%' AND movie_info.info ILIKE '%washington%' AND movie_info.movie_id = title.id AND title.id = movie_info.movie_id AND movie_info.info ILIKE '%gangster%' AND movie_info.info ILIKE '%washington%'
#
# []
# ===============================================================================================================================================
#
# [('movie_info', frozenset({'denzel', 'washington'})),
#  ('title', frozenset({'gangster'}))]
#
#  SELECT * FROM title, movie_info WHERE movie_info.info ILIKE '%denzel%' AND movie_info.info ILIKE '%washington%' AND movie_info.movie_id = title.id AND title.title ILIKE '%gangster%'
#
# []
# ===============================================================================================================================================
#
# [('movie_info', frozenset({'denzel', 'washington'})),
#  'title',
#  'cast_info',
#  ('char_name', frozenset({'gangster'}))]
#
#  SELECT * FROM cast_info, title, char_name, movie_info WHERE movie_info.info ILIKE '%denzel%' AND movie_info.info ILIKE '%washington%' AND movie_info.movie_id = title.id AND title.id = cast_info.movie_id AND cast_info.person_role_id = char_name.id AND char_name.name ILIKE '%gangster%'
#
# []
# ===============================================================================================================================================
#
# [('movie_info', frozenset({'denzel', 'washington'})),
#  'title',
#  ('cast_info', frozenset({'gangster'}))]
#
#  SELECT * FROM cast_info, title, movie_info WHERE movie_info.info ILIKE '%denzel%' AND movie_info.info ILIKE '%washington%' AND movie_info.movie_id = title.id AND title.id = cast_info.movie_id AND cast_info.note ILIKE '%gangster%'
#
# []
# ===============================================================================================================================================
#
# [('movie_info', frozenset({'denzel', 'washington'})),
#  'title',
#  ('movie_info', frozenset({'gangster'}))]
#
#  SELECT * FROM title, movie_info WHERE movie_info.info ILIKE '%denzel%' AND movie_info.info ILIKE '%washington%' AND movie_info.movie_id = title.id AND title.id = movie_info.movie_id AND movie_info.info ILIKE '%gangster%'
#
# []
# ===============================================================================================================================================
#
# [('char_name', frozenset({'denzel'})),
#  'cast_info',
#  'role_type',
#  'cast_info',
#  'char_name',
#  'cast_info',
#  'title',
#  ('movie_info', frozenset({'gangster', 'washington'}))]
#
#  SELECT * FROM cast_info, movie_info, role_type, title, char_name WHERE char_name.name ILIKE '%denzel%' AND char_name.id = cast_info.person_role_id AND cast_info.role_id = role_type.id AND role_type.id = cast_info.role_id AND cast_info.person_role_id = char_name.id AND char_name.id = cast_info.person_role_id AND cast_info.movie_id = title.id AND title.id = movie_info.movie_id AND movie_info.info ILIKE '%gangster%' AND movie_info.info ILIKE '%washington%'
#
# []
# ===============================================================================================================================================
#
# [('movie_info', frozenset({'gangster', 'washington'})),
#  'title',
#  'cast_info',
#  ('name', frozenset({'denzel', 'washington'}))]
#
#  SELECT * FROM cast_info, title, name, movie_info WHERE movie_info.info ILIKE '%gangster%' AND movie_info.info ILIKE '%washington%' AND movie_info.movie_id = title.id AND title.id = cast_info.movie_id AND cast_info.person_id = name.id AND name.name ILIKE '%denzel%' AND name.name ILIKE '%washington%'
#
# []
# ===============================================================================================================================================
#
# [('movie_info', frozenset({'gangster', 'washington'})),
#  'title',
#  ('cast_info', frozenset({'denzel', 'washington'}))]
#
#  SELECT * FROM cast_info, title, movie_info WHERE movie_info.info ILIKE '%gangster%' AND movie_info.info ILIKE '%washington%' AND movie_info.movie_id = title.id AND title.id = cast_info.movie_id AND cast_info.note ILIKE '%denzel%' AND cast_info.note ILIKE '%washington%'
#
# []
# ===============================================================================================================================================
#
# [('movie_info', frozenset({'gangster', 'washington'})),
#  'title',
#  'cast_info',
#  ('name', frozenset({'denzel'}))]
#
#  SELECT * FROM cast_info, title, name, movie_info WHERE movie_info.info ILIKE '%gangster%' AND movie_info.info ILIKE '%washington%' AND movie_info.movie_id = title.id AND title.id = cast_info.movie_id AND cast_info.person_id = name.id AND name.name ILIKE '%denzel%'
#
# []
# ===============================================================================================================================================
#
# [('movie_info', frozenset({'gangster', 'washington'})),
#  'title',
#  ('cast_info', frozenset({'denzel'}))]
#
#  SELECT * FROM cast_info, title, movie_info WHERE movie_info.info ILIKE '%gangster%' AND movie_info.info ILIKE '%washington%' AND movie_info.movie_id = title.id AND title.id = cast_info.movie_id AND cast_info.note ILIKE '%denzel%'
#
# []
# ===============================================================================================================================================
#
# [('movie_info', frozenset({'gangster', 'washington'})),
#  'title',
#  ('movie_info', frozenset({'denzel'}))]
#
#  SELECT * FROM title, movie_info WHERE movie_info.info ILIKE '%gangster%' AND movie_info.info ILIKE '%washington%' AND movie_info.movie_id = title.id AND title.id = movie_info.movie_id AND movie_info.info ILIKE '%denzel%'
#
# []
# ===============================================================================================================================================
#
# [('title', frozenset({'gangster'})),
#  'movie_info',
#  'title',
#  'cast_info',
#  ('name', frozenset({'denzel', 'washington'}))]
#
#  SELECT * FROM cast_info, title, name, movie_info WHERE title.title ILIKE '%gangster%' AND title.id = movie_info.movie_id AND movie_info.movie_id = title.id AND title.id = cast_info.movie_id AND cast_info.person_id = name.id AND name.name ILIKE '%denzel%' AND name.name ILIKE '%washington%'
#
# [(7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None, None, None, 43784946, 1023912, 'Washington, Denzel', None, None, 'W2523', 'D5242', None, 39927668, 327208, 31472, 15, "Frank Lucas: I don't care what you call it, put a choke-hold on the motherfucker and call it Blue Dog Shit.", None, 26096287), (7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None, None, None, 43784946, 1023912, 'Washington, Denzel', None, None, 'W2523', 'D5242', None, 39927668, 327207, 31472, 15, "Redtop: What's the matter? Ain't you niggas never seen naked coochie before?::Huey Lucas: Why they all naked?::Frank Lucas: So they can't steal nothin'.", None, 26096286), (7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None, None, None, 43784946, 1023912, 'Washington, Denzel', None, None, 'W2523', 'D5242', None, 39927668, 327206, 31472, 15, 'Frank Lucas: [Last line] Even a fool gets to be young once.', None, 26096285), (7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None, None, None, 43784946, 1023912, 'Washington, Denzel', None, None, 'W2523', 'D5242', None, 39927668, 327205, 31472, 15, "Bumpy Johnson: This is the problem. This is what's wrong with America. It's gotten so big, you just can't find your way. The grocery store on the corner is now a supermarket. The candy store is a MacDonald's. And this place, a super fucking discount store. Where's the pride of ownership? Where's the personal service? [Enters the store] See what I mean? Shit. I mean, what right do they have, of cutting out the suppliers? Pushing out all the middlemen. Buying direct from the manufacturer. Sony this. Toshiba that. All them Chinks putting Americans out of work. That's the way it is now. You can't find the heart of anything to stick the knife.", None, 26096284), (7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None, None, None, 43784946, 1023912, 'Washington, Denzel', None, None, 'W2523', 'D5242', None, 39927668, 327204, 31472, 15, "Detective Trupo: I got a better idea. Or, would you rather me throw you and your brother in the fuckin' river?::Frank Lucas: Or, would you rather your house blows up next time?", None, 26096283), (7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None, None, None, 43784946, 1023912, 'Washington, Denzel', None, None, 'W2523', 'D5242', None, 39927668, 327203, 31472, 15, '[last lines]::Prison Guard: Check your property. Sign, please.', None, 26096282), (7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None, None, None, 43784946, 1023912, 'Washington, Denzel', None, None, 'W2523', 'D5242', None, 39927668, 327202, 31472, 15, "[last title cards]::Title cards: Frank Lucas was convicted of Conspiracy to Distribute Narcotics and sentenced to 70 years.::Title cards: Federal authorities confiscated over 250 million dollars of Frank's assets in U.S. and foreign banks.::Title cards: Frank and Richie's collaboration led to the conviction of three quarters of New York City's Drug Enforcement Agency.::Title cards: Thirty members of Frank's family were convicted of drug trafficking and sent to prison.::Title cards: Frank's wife returned to Puerto Rico.::Title cards: His mother moved back to North Carolina.::Title cards: Richie Roberts quit the Prosecutor's Office to become a defense attorney.::Title cards: His first client was Frank Lucas.::Title cards: For his cooperation, Frank's prison sentence was reduced to 15 years. He was released in 1991.", None, 26096281), (7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None,  ...
# ===============================================================================================================================================
#
# [('title', frozenset({'gangster'})),
#  ('cast_info', frozenset({'denzel', 'washington'}))]
#
#  SELECT * FROM cast_info, title WHERE title.title ILIKE '%gangster%' AND title.id = cast_info.movie_id AND cast_info.note ILIKE '%denzel%' AND cast_info.note ILIKE '%washington%'
# []
# ===============================================================================================================================================
#
# [('char_name', frozenset({'gangster'})),
#  'cast_info',
#  ('name', frozenset({'denzel', 'washington'}))]
#
#  SELECT * FROM cast_info, name, char_name WHERE char_name.name ILIKE '%gangster%' AND char_name.id = cast_info.person_role_id AND cast_info.person_id = name.id AND name.name ILIKE '%denzel%' AND name.name ILIKE '%washington%'
#
# []
# ===============================================================================================================================================
#
# [('char_name', frozenset({'gangster'})),
#  ('cast_info', frozenset({'denzel', 'washington'}))]
#
#  SELECT * FROM cast_info, char_name WHERE char_name.name ILIKE '%gangster%' AND char_name.id = cast_info.person_role_id AND cast_info.note ILIKE '%denzel%' AND cast_info.note ILIKE '%washington%'
#
# []
# ===============================================================================================================================================
#
# [('name', frozenset({'denzel', 'washington'})),
#  ('cast_info', frozenset({'gangster'}))]
#
#  SELECT * FROM cast_info, name WHERE name.name ILIKE '%denzel%' AND name.name ILIKE '%washington%' AND name.id = cast_info.person_id AND cast_info.note ILIKE '%gangster%'
#
# []
# ===============================================================================================================================================
#
# [('name', frozenset({'denzel', 'washington'})),
#  'cast_info',
#  'role_type',
#  'cast_info',
#  'char_name',
#  'cast_info',
#  'title',
#  ('movie_info', frozenset({'gangster'}))]
#
#  SELECT * FROM cast_info, movie_info, role_type, title, char_name, name WHERE name.name ILIKE '%denzel%' AND name.name ILIKE '%washington%' AND name.id = cast_info.person_id AND cast_info.role_id = role_type.id AND role_type.id = cast_info.role_id AND cast_info.person_role_id = char_name.id AND char_name.id = cast_info.person_role_id AND cast_info.movie_id = title.id AND title.id = movie_info.movie_id AND movie_info.info ILIKE '%gangster%'
#
# []
# ===============================================================================================================================================
#
# [('cast_info', frozenset({'denzel', 'washington'})),
#  'role_type',
#  ('cast_info', frozenset({'gangster'}))]
#
#  SELECT * FROM cast_info, role_type WHERE cast_info.note ILIKE '%denzel%' AND cast_info.note ILIKE '%washington%' AND cast_info.role_id = role_type.id AND role_type.id = cast_info.role_id AND cast_info.note ILIKE '%gangster%'
#
# []
# ===============================================================================================================================================
#
# [('cast_info', frozenset({'denzel', 'washington'})),
#  'role_type',
#  'cast_info',
#  'char_name',
#  'cast_info',
#  'role_type',
#  'cast_info',
#  'title',
#  ('movie_info', frozenset({'gangster'}))]
#
#  SELECT * FROM cast_info, movie_info, role_type, title, char_name WHERE cast_info.note ILIKE '%denzel%' AND cast_info.note ILIKE '%washington%' AND cast_info.role_id = role_type.id AND role_type.id = cast_info.role_id AND cast_info.person_role_id = char_name.id AND char_name.id = cast_info.person_role_id AND cast_info.role_id = role_type.id AND role_type.id = cast_info.role_id AND cast_info.movie_id = title.id AND title.id = movie_info.movie_id AND movie_info.info ILIKE '%gangster%'
#
# []
# ===============================================================================================================================================
#
# [('char_name', frozenset({'denzel'})),
#  'cast_info',
#  ('title', frozenset({'gangster'})),
#  'movie_info',
#  'title',
#  'cast_info',
#  ('char_name', frozenset({'washington'}))]
#
#  SELECT * FROM cast_info, title, char_name, movie_info WHERE char_name.name ILIKE '%denzel%' AND char_name.id = cast_info.person_role_id AND cast_info.movie_id = title.id AND title.title ILIKE '%gangster%' AND title.id = movie_info.movie_id AND movie_info.movie_id = title.id AND title.id = cast_info.movie_id AND cast_info.person_role_id = char_name.id AND char_name.name ILIKE '%washington%'
#
# []
# ===============================================================================================================================================
#
# [('char_name', frozenset({'denzel'})),
#  'cast_info',
#  ('char_name', frozenset({'gangster'})),
#  'cast_info',
#  ('char_name', frozenset({'washington'}))]
#
#  SELECT * FROM cast_info, char_name WHERE char_name.name ILIKE '%denzel%' AND char_name.id = cast_info.person_role_id AND cast_info.person_role_id = char_name.id AND char_name.name ILIKE '%gangster%' AND char_name.id = cast_info.person_role_id AND cast_info.person_role_id = char_name.id AND char_name.name ILIKE '%washington%'
#
# []
# ===============================================================================================================================================
#
# [('char_name', frozenset({'denzel'})),
#  ('cast_info', frozenset({'gangster'})),
#  ('char_name', frozenset({'washington'}))]
#
#  SELECT * FROM cast_info, char_name WHERE char_name.name ILIKE '%denzel%' AND char_name.id = cast_info.person_role_id AND cast_info.note ILIKE '%gangster%' AND cast_info.person_role_id = char_name.id AND char_name.name ILIKE '%washington%'
#
# []
# ===============================================================================================================================================
#
# [('char_name', frozenset({'denzel'})),
#  'cast_info',
#  ('char_name', frozenset({'washington'})),
#  'cast_info',
#  'role_type',
#  'cast_info',
#  'title',
#  ('movie_info', frozenset({'gangster'}))]
#
#  SELECT * FROM cast_info, movie_info, role_type, title, char_name WHERE char_name.name ILIKE '%denzel%' AND char_name.id = cast_info.person_role_id AND cast_info.person_role_id = char_name.id AND char_name.name ILIKE '%washington%' AND char_name.id = cast_info.person_role_id AND cast_info.role_id = role_type.id AND role_type.id = cast_info.role_id AND cast_info.movie_id = title.id AND title.id = movie_info.movie_id AND movie_info.info ILIKE '%gangster%'
#
# []
# ===============================================================================================================================================
#
# [('char_name', frozenset({'denzel'})),
#  'cast_info',
#  ('title', frozenset({'washington'})),
#  'movie_info',
#  ('title', frozenset({'gangster'}))]
#
#  SELECT * FROM cast_info, title, char_name, movie_info WHERE char_name.name ILIKE '%denzel%' AND char_name.id = cast_info.person_role_id AND cast_info.movie_id = title.id AND title.title ILIKE '%washington%' AND title.id = movie_info.movie_id AND movie_info.movie_id = title.id AND title.title ILIKE '%gangster%'
#
# []
# ===============================================================================================================================================
#
# [('char_name', frozenset({'denzel'})),
#  'cast_info',
#  ('title', frozenset({'gangster'})),
#  ('movie_info', frozenset({'washington'}))]
#
#  SELECT * FROM cast_info, title, char_name, movie_info WHERE char_name.name ILIKE '%denzel%' AND char_name.id = cast_info.person_role_id AND cast_info.movie_id = title.id AND title.title ILIKE '%gangster%' AND title.id = movie_info.movie_id AND movie_info.info ILIKE '%washington%'
#
# []
# ===============================================================================================================================================
#
# [('char_name', frozenset({'denzel'})),
#  'cast_info',
#  ('name', frozenset({'washington'})),
#  'cast_info',
#  ('title', frozenset({'gangster'}))]
#
#  SELECT * FROM cast_info, title, name, char_name WHERE char_name.name ILIKE '%denzel%' AND char_name.id = cast_info.person_role_id AND cast_info.person_id = name.id AND name.name ILIKE '%washington%' AND name.id = cast_info.person_id AND cast_info.movie_id = title.id AND title.title ILIKE '%gangster%'
#
# []
# ===============================================================================================================================================
#
# [('char_name', frozenset({'denzel'})),
#  ('cast_info', frozenset({'washington'})),
#  ('title', frozenset({'gangster'}))]
#
#  SELECT * FROM cast_info, title, char_name WHERE char_name.name ILIKE '%denzel%' AND char_name.id = cast_info.person_role_id AND cast_info.note ILIKE '%washington%' AND cast_info.movie_id = title.id AND title.title ILIKE '%gangster%'
# []
# ===============================================================================================================================================
#
# [('char_name', frozenset({'denzel'})),
#  'cast_info',
#  ('char_name', frozenset({'gangster'})),
#  'cast_info',
#  ('title', frozenset({'washington'}))]
#
#  SELECT * FROM cast_info, title, char_name WHERE char_name.name ILIKE '%denzel%' AND char_name.id = cast_info.person_role_id AND cast_info.person_role_id = char_name.id AND char_name.name ILIKE '%gangster%' AND char_name.id = cast_info.person_role_id AND cast_info.movie_id = title.id AND title.title ILIKE '%washington%'
#
# []
# ===============================================================================================================================================
#
# [('char_name', frozenset({'denzel'})),
#  ('cast_info', frozenset({'gangster'})),
#  ('title', frozenset({'washington'}))]
#
#  SELECT * FROM cast_info, title, char_name WHERE char_name.name ILIKE '%denzel%' AND char_name.id = cast_info.person_role_id AND cast_info.note ILIKE '%gangster%' AND cast_info.movie_id = title.id AND title.title ILIKE '%washington%'
#
# []
# ===============================================================================================================================================
#
# [('char_name', frozenset({'denzel'})),
#  'cast_info',
#  ('title', frozenset({'washington'})),
#  ('movie_info', frozenset({'gangster'}))]
#
#  SELECT * FROM cast_info, title, char_name, movie_info WHERE char_name.name ILIKE '%denzel%' AND char_name.id = cast_info.person_role_id AND cast_info.movie_id = title.id AND title.title ILIKE '%washington%' AND title.id = movie_info.movie_id AND movie_info.info ILIKE '%gangster%'
#
# []
# ===============================================================================================================================================
#
# [('char_name', frozenset({'denzel'})),
#  'cast_info',
#  ('char_name', frozenset({'gangster'})),
#  'cast_info',
#  'role_type',
#  'cast_info',
#  'title',
#  ('movie_info', frozenset({'washington'}))]
#
#  SELECT * FROM cast_info, movie_info, role_type, title, char_name WHERE char_name.name ILIKE '%denzel%' AND char_name.id = cast_info.person_role_id AND cast_info.person_role_id = char_name.id AND char_name.name ILIKE '%gangster%' AND char_name.id = cast_info.person_role_id AND cast_info.role_id = role_type.id AND role_type.id = cast_info.role_id AND cast_info.movie_id = title.id AND title.id = movie_info.movie_id AND movie_info.info ILIKE '%washington%'
#
# []
# ===============================================================================================================================================
#
# [('char_name', frozenset({'denzel'})),
#  'cast_info',
#  ('name', frozenset({'washington'})),
#  'cast_info',
#  ('char_name', frozenset({'gangster'}))]
#
#  SELECT * FROM cast_info, name, char_name WHERE char_name.name ILIKE '%denzel%' AND char_name.id = cast_info.person_role_id AND cast_info.person_id = name.id AND name.name ILIKE '%washington%' AND name.id = cast_info.person_id AND cast_info.person_role_id = char_name.id AND char_name.name ILIKE '%gangster%'
#
# []
# ===============================================================================================================================================
#
# [('char_name', frozenset({'denzel'})),
#  ('cast_info', frozenset({'washington'})),
#  ('char_name', frozenset({'gangster'}))]
#
#  SELECT * FROM cast_info, char_name WHERE char_name.name ILIKE '%denzel%' AND char_name.id = cast_info.person_role_id AND cast_info.note ILIKE '%washington%' AND cast_info.person_role_id = char_name.id AND char_name.name ILIKE '%gangster%'
#
# []
# ===============================================================================================================================================
#
# [('char_name', frozenset({'denzel'})),
#  ('cast_info', frozenset({'gangster'})),
#  'role_type',
#  'cast_info',
#  'char_name',
#  'cast_info',
#  'title',
#  ('movie_info', frozenset({'washington'}))]
#
#  SELECT * FROM cast_info, movie_info, role_type, title, char_name WHERE char_name.name ILIKE '%denzel%' AND char_name.id = cast_info.person_role_id AND cast_info.note ILIKE '%gangster%' AND cast_info.role_id = role_type.id AND role_type.id = cast_info.role_id AND cast_info.person_role_id = char_name.id AND char_name.id = cast_info.person_role_id AND cast_info.movie_id = title.id AND title.id = movie_info.movie_id AND movie_info.info ILIKE '%washington%'
#
# []
# ===============================================================================================================================================
#
# [('char_name', frozenset({'denzel'})),
#  ('cast_info', frozenset({'gangster'})),
#  ('name', frozenset({'washington'}))]
#
#  SELECT * FROM cast_info, name, char_name WHERE char_name.name ILIKE '%denzel%' AND char_name.id = cast_info.person_role_id AND cast_info.note ILIKE '%gangster%' AND cast_info.person_id = name.id AND name.name ILIKE '%washington%'
#
# []
# ===============================================================================================================================================
#
# [('char_name', frozenset({'denzel'})),
#  ('cast_info', frozenset({'washington'})),
#  'role_type',
#  ('cast_info', frozenset({'gangster'}))]
#
#  SELECT * FROM cast_info, role_type, char_name WHERE char_name.name ILIKE '%denzel%' AND char_name.id = cast_info.person_role_id AND cast_info.note ILIKE '%washington%' AND cast_info.role_id = role_type.id AND role_type.id = cast_info.role_id AND cast_info.note ILIKE '%gangster%'
#
# []
# ===============================================================================================================================================
#
# [('char_name', frozenset({'denzel'})),
#  'cast_info',
#  ('name', frozenset({'washington'})),
#  'cast_info',
#  'role_type',
#  'cast_info',
#  'title',
#  ('movie_info', frozenset({'gangster'}))]
#
#  SELECT * FROM cast_info, movie_info, role_type, title, char_name, name WHERE char_name.name ILIKE '%denzel%' AND char_name.id = cast_info.person_role_id AND cast_info.person_id = name.id AND name.name ILIKE '%washington%' AND name.id = cast_info.person_id AND cast_info.role_id = role_type.id AND role_type.id = cast_info.role_id AND cast_info.movie_id = title.id AND title.id = movie_info.movie_id AND movie_info.info ILIKE '%gangster%'
#
# []
# ===============================================================================================================================================
#
# [('char_name', frozenset({'denzel'})),
#  ('cast_info', frozenset({'washington'})),
#  'role_type',
#  'cast_info',
#  'char_name',
#  'cast_info',
#  'title',
#  ('movie_info', frozenset({'gangster'}))]
#
#  SELECT * FROM cast_info, movie_info, role_type, title, char_name WHERE char_name.name ILIKE '%denzel%' AND char_name.id = cast_info.person_role_id AND cast_info.note ILIKE '%washington%' AND cast_info.role_id = role_type.id AND role_type.id = cast_info.role_id AND cast_info.person_role_id = char_name.id AND char_name.id = cast_info.person_role_id AND cast_info.movie_id = title.id AND title.id = movie_info.movie_id AND movie_info.info ILIKE '%gangster%'
#
# []
# ===============================================================================================================================================
#
# [('char_name', frozenset({'washington'})),
#  'cast_info',
#  ('name', frozenset({'denzel'})),
#  'cast_info',
#  ('title', frozenset({'gangster'}))]
#
#  SELECT * FROM cast_info, title, name, char_name WHERE char_name.name ILIKE '%washington%' AND char_name.id = cast_info.person_role_id AND cast_info.person_id = name.id AND name.name ILIKE '%denzel%' AND name.id = cast_info.person_id AND cast_info.movie_id = title.id AND title.title ILIKE '%gangster%'
#
# []
# ===============================================================================================================================================
#
# [('char_name', frozenset({'washington'})),
#  ('cast_info', frozenset({'denzel'})),
#  ('title', frozenset({'gangster'}))]
#
#  SELECT * FROM cast_info, title, char_name WHERE char_name.name ILIKE '%washington%' AND char_name.id = cast_info.person_role_id AND cast_info.note ILIKE '%denzel%' AND cast_info.movie_id = title.id AND title.title ILIKE '%gangster%'
#
# []
# ===============================================================================================================================================
#
# [('char_name', frozenset({'washington'})),
#  'cast_info',
#  ('title', frozenset({'gangster'})),
#  ('movie_info', frozenset({'denzel'}))]
#
#  SELECT * FROM cast_info, title, char_name, movie_info WHERE char_name.name ILIKE '%washington%' AND char_name.id = cast_info.person_role_id AND cast_info.movie_id = title.id AND title.title ILIKE '%gangster%' AND title.id = movie_info.movie_id AND movie_info.info ILIKE '%denzel%'
# []
# ===============================================================================================================================================
#
# [('char_name', frozenset({'washington'})),
#  'cast_info',
#  ('name', frozenset({'denzel'})),
#  'cast_info',
#  ('char_name', frozenset({'gangster'}))]
#
#  SELECT * FROM cast_info, name, char_name WHERE char_name.name ILIKE '%washington%' AND char_name.id = cast_info.person_role_id AND cast_info.person_id = name.id AND name.name ILIKE '%denzel%' AND name.id = cast_info.person_id AND cast_info.person_role_id = char_name.id AND char_name.name ILIKE '%gangster%'
#
# []
# ===============================================================================================================================================
#
# [('char_name', frozenset({'washington'})),
#  ('cast_info', frozenset({'denzel'})),
#  ('char_name', frozenset({'gangster'}))]
#
#  SELECT * FROM cast_info, char_name WHERE char_name.name ILIKE '%washington%' AND char_name.id = cast_info.person_role_id AND cast_info.note ILIKE '%denzel%' AND cast_info.person_role_id = char_name.id AND char_name.name ILIKE '%gangster%'
#
# []
# ===============================================================================================================================================
#
# [('char_name', frozenset({'washington'})),
#  'cast_info',
#  ('char_name', frozenset({'gangster'})),
#  'cast_info',
#  'role_type',
#  'cast_info',
#  'title',
#  ('movie_info', frozenset({'denzel'}))]
#
#  SELECT * FROM cast_info, movie_info, role_type, title, char_name WHERE char_name.name ILIKE '%washington%' AND char_name.id = cast_info.person_role_id AND cast_info.person_role_id = char_name.id AND char_name.name ILIKE '%gangster%' AND char_name.id = cast_info.person_role_id AND cast_info.role_id = role_type.id AND role_type.id = cast_info.role_id AND cast_info.movie_id = title.id AND title.id = movie_info.movie_id AND movie_info.info ILIKE '%denzel%'
#
# []
# ===============================================================================================================================================
#
# [('char_name', frozenset({'washington'})),
#  ('cast_info', frozenset({'gangster'})),
#  ('name', frozenset({'denzel'}))]
#
#  SELECT * FROM cast_info, name, char_name WHERE char_name.name ILIKE '%washington%' AND char_name.id = cast_info.person_role_id AND cast_info.note ILIKE '%gangster%' AND cast_info.person_id = name.id AND name.name ILIKE '%denzel%'
#
# []
# ===============================================================================================================================================
#
# [('char_name', frozenset({'washington'})),
#  ('cast_info', frozenset({'denzel'})),
#  'role_type',
#  ('cast_info', frozenset({'gangster'}))]
#
#  SELECT * FROM cast_info, role_type, char_name WHERE char_name.name ILIKE '%washington%' AND char_name.id = cast_info.person_role_id AND cast_info.note ILIKE '%denzel%' AND cast_info.role_id = role_type.id AND role_type.id = cast_info.role_id AND cast_info.note ILIKE '%gangster%'
#
# []
# ===============================================================================================================================================
#
# [('char_name', frozenset({'washington'})),
#  ('cast_info', frozenset({'gangster'})),
#  'role_type',
#  'cast_info',
#  'char_name',
#  'cast_info',
#  'title',
#  ('movie_info', frozenset({'denzel'}))]
#
#  SELECT * FROM cast_info, movie_info, role_type, title, char_name WHERE char_name.name ILIKE '%washington%' AND char_name.id = cast_info.person_role_id AND cast_info.note ILIKE '%gangster%' AND cast_info.role_id = role_type.id AND role_type.id = cast_info.role_id AND cast_info.person_role_id = char_name.id AND char_name.id = cast_info.person_role_id AND cast_info.movie_id = title.id AND title.id = movie_info.movie_id AND movie_info.info ILIKE '%denzel%'
#
# []
# ===============================================================================================================================================
#
# [('char_name', frozenset({'washington'})),
#  'cast_info',
#  ('name', frozenset({'denzel'})),
#  'cast_info',
#  'role_type',
#  'cast_info',
#  'title',
#  ('movie_info', frozenset({'gangster'}))]
#
#  SELECT * FROM cast_info, movie_info, role_type, title, char_name, name WHERE char_name.name ILIKE '%washington%' AND char_name.id = cast_info.person_role_id AND cast_info.person_id = name.id AND name.name ILIKE '%denzel%' AND name.id = cast_info.person_id AND cast_info.role_id = role_type.id AND role_type.id = cast_info.role_id AND cast_info.movie_id = title.id AND title.id = movie_info.movie_id AND movie_info.info ILIKE '%gangster%'
#
# []
# ===============================================================================================================================================
#
# [('char_name', frozenset({'washington'})),
#  ('cast_info', frozenset({'denzel'})),
#  'role_type',
#  'cast_info',
#  'char_name',
#  'cast_info',
#  'title',
#  ('movie_info', frozenset({'gangster'}))]
#
#  SELECT * FROM cast_info, movie_info, role_type, title, char_name WHERE char_name.name ILIKE '%washington%' AND char_name.id = cast_info.person_role_id AND cast_info.note ILIKE '%denzel%' AND cast_info.role_id = role_type.id AND role_type.id = cast_info.role_id AND cast_info.person_role_id = char_name.id AND char_name.id = cast_info.person_role_id AND cast_info.movie_id = title.id AND title.id = movie_info.movie_id AND movie_info.info ILIKE '%gangster%'
#
# []
# ===============================================================================================================================================
#
# [('title', frozenset({'gangster'})),
#  'movie_info',
#  ('title', frozenset({'washington'})),
#  'movie_info',
#  'title',
#  'cast_info',
#  ('name', frozenset({'denzel'}))]
#
#  SELECT * FROM cast_info, title, name, movie_info WHERE title.title ILIKE '%gangster%' AND title.id = movie_info.movie_id AND movie_info.movie_id = title.id AND title.title ILIKE '%washington%' AND title.id = movie_info.movie_id AND movie_info.movie_id = title.id AND title.id = cast_info.movie_id AND cast_info.person_id = name.id AND name.name ILIKE '%denzel%'
#
# []
# ===============================================================================================================================================
#
# [('title', frozenset({'gangster'})),
#  ('cast_info', frozenset({'denzel'})),
#  ('title', frozenset({'washington'}))]
#
#  SELECT * FROM cast_info, title WHERE title.title ILIKE '%gangster%' AND title.id = cast_info.movie_id AND cast_info.note ILIKE '%denzel%' AND cast_info.movie_id = title.id AND title.title ILIKE '%washington%'
#
# []
# ===============================================================================================================================================
#
# [('title', frozenset({'gangster'})),
#  ('movie_info', frozenset({'denzel'})),
#  ('title', frozenset({'washington'}))]
#
#  SELECT * FROM title, movie_info WHERE title.title ILIKE '%gangster%' AND title.id = movie_info.movie_id AND movie_info.info ILIKE '%denzel%' AND movie_info.movie_id = title.id AND title.title ILIKE '%washington%'
#
# []
# ===============================================================================================================================================
#
# [('title', frozenset({'gangster'})),
#  ('movie_info', frozenset({'washington'})),
#  'title',
#  'cast_info',
#  ('name', frozenset({'denzel'}))]
#
#  SELECT * FROM cast_info, title, name, movie_info WHERE title.title ILIKE '%gangster%' AND title.id = movie_info.movie_id AND movie_info.info ILIKE '%washington%' AND movie_info.movie_id = title.id AND title.id = cast_info.movie_id AND cast_info.person_id = name.id AND name.name ILIKE '%denzel%'
#
# []
# ===============================================================================================================================================
#
# [('title', frozenset({'gangster'})),
#  ('cast_info', frozenset({'denzel'})),
#  'role_type',
#  'cast_info',
#  'char_name',
#  'cast_info',
#  'title',
#  ('movie_info', frozenset({'washington'}))]
#
#  SELECT * FROM cast_info, movie_info, role_type, title, char_name WHERE title.title ILIKE '%gangster%' AND title.id = cast_info.movie_id AND cast_info.note ILIKE '%denzel%' AND cast_info.role_id = role_type.id AND role_type.id = cast_info.role_id AND cast_info.person_role_id = char_name.id AND char_name.id = cast_info.person_role_id AND cast_info.movie_id = title.id AND title.id = movie_info.movie_id AND movie_info.info ILIKE '%washington%'
#
# []
# ===============================================================================================================================================
#
# [('title', frozenset({'gangster'})),
#  ('movie_info', frozenset({'denzel'})),
#  'title',
#  ('movie_info', frozenset({'washington'}))]
#
#  SELECT * FROM title, movie_info WHERE title.title ILIKE '%gangster%' AND title.id = movie_info.movie_id AND movie_info.info ILIKE '%denzel%' AND movie_info.movie_id = title.id AND title.id = movie_info.movie_id AND movie_info.info ILIKE '%washington%'
#
# []
# ===============================================================================================================================================
#
# [('title', frozenset({'gangster'})),
#  'movie_info',
#  'title',
#  'cast_info',
#  ('name', frozenset({'washington'})),
#  'cast_info',
#  ('name', frozenset({'denzel'}))]
#
#  SELECT * FROM cast_info, title, name, movie_info WHERE title.title ILIKE '%gangster%' AND title.id = movie_info.movie_id AND movie_info.movie_id = title.id AND title.id = cast_info.movie_id AND cast_info.person_id = name.id AND name.name ILIKE '%washington%' AND name.id = cast_info.person_id AND cast_info.person_id = name.id AND name.name ILIKE '%denzel%'
#
# [(7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None, None, None, 43784946, 1023912, 'Washington, Denzel', None, None, 'W2523', 'D5242', None, 39927668, 327208, 31472, 15, "Frank Lucas: I don't care what you call it, put a choke-hold on the motherfucker and call it Blue Dog Shit.", None, 26096287), (7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None, None, None, 43784946, 1023912, 'Washington, Denzel', None, None, 'W2523', 'D5242', None, 39927668, 327207, 31472, 15, "Redtop: What's the matter? Ain't you niggas never seen naked coochie before?::Huey Lucas: Why they all naked?::Frank Lucas: So they can't steal nothin'.", None, 26096286), (7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None, None, None, 43784946, 1023912, 'Washington, Denzel', None, None, 'W2523', 'D5242', None, 39927668, 327206, 31472, 15, 'Frank Lucas: [Last line] Even a fool gets to be young once.', None, 26096285), (7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None, None, None, 43784946, 1023912, 'Washington, Denzel', None, None, 'W2523', 'D5242', None, 39927668, 327205, 31472, 15, "Bumpy Johnson: This is the problem. This is what's wrong with America. It's gotten so big, you just can't find your way. The grocery store on the corner is now a supermarket. The candy store is a MacDonald's. And this place, a super fucking discount store. Where's the pride of ownership? Where's the personal service? [Enters the store] See what I mean? Shit. I mean, what right do they have, of cutting out the suppliers? Pushing out all the middlemen. Buying direct from the manufacturer. Sony this. Toshiba that. All them Chinks putting Americans out of work. That's the way it is now. You can't find the heart of anything to stick the knife.", None, 26096284), (7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None, None, None, 43784946, 1023912, 'Washington, Denzel', None, None, 'W2523', 'D5242', None, 39927668, 327204, 31472, 15, "Detective Trupo: I got a better idea. Or, would you rather me throw you and your brother in the fuckin' river?::Frank Lucas: Or, would you rather your house blows up next time?", None, 26096283), (7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None, None, None, 43784946, 1023912, 'Washington, Denzel', None, None, 'W2523', 'D5242', None, 39927668, 327203, 31472, 15, '[last lines]::Prison Guard: Check your property. Sign, please.', None, 26096282), (7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None, None, None, 43784946, 1023912, 'Washington, Denzel', None, None, 'W2523', 'D5242', None, 39927668, 327202, 31472, 15, "[last title cards]::Title cards: Frank Lucas was convicted of Conspiracy to Distribute Narcotics and sentenced to 70 years.::Title cards: Federal authorities confiscated over 250 million dollars of Frank's assets in U.S. and foreign banks.::Title cards: Frank and Richie's collaboration led to the conviction of three quarters of New York City's Drug Enforcement Agency.::Title cards: Thirty members of Frank's family were convicted of drug trafficking and sent to prison.::Title cards: Frank's wife returned to Puerto Rico.::Title cards: His mother moved back to North Carolina.::Title cards: Richie Roberts quit the Prosecutor's Office to become a defense attorney.::Title cards: His first client was Frank Lucas.::Title cards: For his cooperation, Frank's prison sentence was reduced to 15 years. He was released in 1991.", None, 26096281), (7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None,  ...
# ===============================================================================================================================================
#
# [('title', frozenset({'gangster'})),
#  ('cast_info', frozenset({'washington'})),
#  ('name', frozenset({'denzel'}))]
#
#  SELECT * FROM cast_info, title, name WHERE title.title ILIKE '%gangster%' AND title.id = cast_info.movie_id AND cast_info.note ILIKE '%washington%' AND cast_info.person_id = name.id AND name.name ILIKE '%denzel%'
#
# []
# ===============================================================================================================================================
#
# [('title', frozenset({'gangster'})),
#  ('cast_info', frozenset({'denzel'})),
#  ('name', frozenset({'washington'}))]
#
#  SELECT * FROM cast_info, title, name WHERE title.title ILIKE '%gangster%' AND title.id = cast_info.movie_id AND cast_info.note ILIKE '%denzel%' AND cast_info.person_id = name.id AND name.name ILIKE '%washington%'
#
# []
# ===============================================================================================================================================
#
# [('title', frozenset({'gangster'})),
#  ('movie_info', frozenset({'denzel'})),
#  'title',
#  'cast_info',
#  ('name', frozenset({'washington'}))]
#
#  SELECT * FROM cast_info, title, name, movie_info WHERE title.title ILIKE '%gangster%' AND title.id = movie_info.movie_id AND movie_info.info ILIKE '%denzel%' AND movie_info.movie_id = title.id AND title.id = cast_info.movie_id AND cast_info.person_id = name.id AND name.name ILIKE '%washington%'
#
# []
# ===============================================================================================================================================
#
# [('title', frozenset({'gangster'})),
#  ('cast_info', frozenset({'washington'})),
#  'role_type',
#  ('cast_info', frozenset({'denzel'}))]
#
#  SELECT * FROM cast_info, title, role_type WHERE title.title ILIKE '%gangster%' AND title.id = cast_info.movie_id AND cast_info.note ILIKE '%washington%' AND cast_info.role_id = role_type.id AND role_type.id = cast_info.role_id AND cast_info.note ILIKE '%denzel%'
#
# []
# ===============================================================================================================================================
#
# [('title', frozenset({'gangster'})),
#  ('movie_info', frozenset({'denzel'})),
#  'title',
#  ('cast_info', frozenset({'washington'}))]
#
#  SELECT * FROM cast_info, title, movie_info WHERE title.title ILIKE '%gangster%' AND title.id = movie_info.movie_id AND movie_info.info ILIKE '%denzel%' AND movie_info.movie_id = title.id AND title.id = cast_info.movie_id AND cast_info.note ILIKE '%washington%'
#
# []
# ===============================================================================================================================================
#
# [('title', frozenset({'washington'})),
#  'movie_info',
#  'title',
#  'cast_info',
#  ('name', frozenset({'denzel'})),
#  'cast_info',
#  ('char_name', frozenset({'gangster'}))]
#
#  SELECT * FROM cast_info, movie_info, title, char_name, name WHERE title.title ILIKE '%washington%' AND title.id = movie_info.movie_id AND movie_info.movie_id = title.id AND title.id = cast_info.movie_id AND cast_info.person_id = name.id AND name.name ILIKE '%denzel%' AND name.id = cast_info.person_id AND cast_info.person_role_id = char_name.id AND char_name.name ILIKE '%gangster%'
#
# []
# ===============================================================================================================================================
#
# [('title', frozenset({'washington'})),
#  ('cast_info', frozenset({'denzel'})),
#  ('char_name', frozenset({'gangster'}))]
#
#  SELECT * FROM cast_info, title, char_name WHERE title.title ILIKE '%washington%' AND title.id = cast_info.movie_id AND cast_info.note ILIKE '%denzel%' AND cast_info.person_role_id = char_name.id AND char_name.name ILIKE '%gangster%'
#
# []
# ===============================================================================================================================================
#
# [('title', frozenset({'washington'})),
#  ('movie_info', frozenset({'denzel'})),
#  'title',
#  'cast_info',
#  ('char_name', frozenset({'gangster'}))]
#
#  SELECT * FROM cast_info, title, char_name, movie_info WHERE title.title ILIKE '%washington%' AND title.id = movie_info.movie_id AND movie_info.info ILIKE '%denzel%' AND movie_info.movie_id = title.id AND title.id = cast_info.movie_id AND cast_info.person_role_id = char_name.id AND char_name.name ILIKE '%gangster%'
#
# []
# ===============================================================================================================================================
#
# [('title', frozenset({'washington'})),
#  ('cast_info', frozenset({'gangster'})),
#  ('name', frozenset({'denzel'}))]
#
#  SELECT * FROM cast_info, title, name WHERE title.title ILIKE '%washington%' AND title.id = cast_info.movie_id AND cast_info.note ILIKE '%gangster%' AND cast_info.person_id = name.id AND name.name ILIKE '%denzel%'
#
# []
# ===============================================================================================================================================
#
# [('title', frozenset({'washington'})),
#  ('cast_info', frozenset({'denzel'})),
#  'role_type',
#  ('cast_info', frozenset({'gangster'}))]
#
#  SELECT * FROM cast_info, title, role_type WHERE title.title ILIKE '%washington%' AND title.id = cast_info.movie_id AND cast_info.note ILIKE '%denzel%' AND cast_info.role_id = role_type.id AND role_type.id = cast_info.role_id AND cast_info.note ILIKE '%gangster%'
#
# []
# ===============================================================================================================================================
#
# [('title', frozenset({'washington'})),
#  ('movie_info', frozenset({'denzel'})),
#  'title',
#  ('cast_info', frozenset({'gangster'}))]
#
#  SELECT * FROM cast_info, title, movie_info WHERE title.title ILIKE '%washington%' AND title.id = movie_info.movie_id AND movie_info.info ILIKE '%denzel%' AND movie_info.movie_id = title.id AND title.id = cast_info.movie_id AND cast_info.note ILIKE '%gangster%'
#
# []
# ===============================================================================================================================================
#
# [('title', frozenset({'washington'})),
#  ('movie_info', frozenset({'gangster'})),
#  'title',
#  'cast_info',
#  ('name', frozenset({'denzel'}))]
#
# ...
#
# []
# ===============================================================================================================================================
#
# [('char_name', frozenset({'gangster'})),
#  'cast_info',
#  ('name', frozenset({'denzel'})),
#  'cast_info',
#  'role_type',
#  'cast_info',
#  'title',
#  ('movie_info', frozenset({'washington'}))]
#
#  SELECT * FROM cast_info, movie_info, role_type, title, char_name, name WHERE char_name.name ILIKE '%gangster%' AND char_name.id = cast_info.person_role_id AND cast_info.person_id = name.id AND name.name ILIKE '%denzel%' AND name.id = cast_info.person_id AND cast_info.role_id = role_type.id AND role_type.id = cast_info.role_id AND cast_info.movie_id = title.id AND title.id = movie_info.movie_id AND movie_info.info ILIKE '%washington%'
# []
# ===============================================================================================================================================
#
# [('char_name', frozenset({'gangster'})),
#  ('cast_info', frozenset({'denzel'})),
#  'role_type',
#  'cast_info',
#  'char_name',
#  'cast_info',
#  'title',
#  ('movie_info', frozenset({'washington'}))]
#
#  SELECT * FROM cast_info, movie_info, role_type, title, char_name WHERE char_name.name ILIKE '%gangster%' AND char_name.id = cast_info.person_role_id AND cast_info.note ILIKE '%denzel%' AND cast_info.role_id = role_type.id AND role_type.id = cast_info.role_id AND cast_info.person_role_id = char_name.id AND char_name.id = cast_info.person_role_id AND cast_info.movie_id = title.id AND title.id = movie_info.movie_id AND movie_info.info ILIKE '%washington%'
#
# []
# ===============================================================================================================================================
#
# [('char_name', frozenset({'gangster'})),
#  'cast_info',
#  ('name', frozenset({'washington'})),
#  'cast_info',
#  ('name', frozenset({'denzel'}))]
#
#  SELECT * FROM cast_info, name, char_name WHERE char_name.name ILIKE '%gangster%' AND char_name.id = cast_info.person_role_id AND cast_info.person_id = name.id AND name.name ILIKE '%washington%' AND name.id = cast_info.person_id AND cast_info.person_id = name.id AND name.name ILIKE '%denzel%'
#
# []
# ===============================================================================================================================================
#
# [('char_name', frozenset({'gangster'})),
#  ('cast_info', frozenset({'washington'})),
#  ('name', frozenset({'denzel'}))]
#
#  SELECT * FROM cast_info, name, char_name WHERE char_name.name ILIKE '%gangster%' AND char_name.id = cast_info.person_role_id AND cast_info.note ILIKE '%washington%' AND cast_info.person_id = name.id AND name.name ILIKE '%denzel%'
#
# []
# ===============================================================================================================================================
#
# [('char_name', frozenset({'gangster'})),
#  ('cast_info', frozenset({'denzel'})),
#  ('name', frozenset({'washington'}))]
#
#  SELECT * FROM cast_info, name, char_name WHERE char_name.name ILIKE '%gangster%' AND char_name.id = cast_info.person_role_id AND cast_info.note ILIKE '%denzel%' AND cast_info.person_id = name.id AND name.name ILIKE '%washington%'
#
# []
# ===============================================================================================================================================
#
# [('char_name', frozenset({'gangster'})),
#  'cast_info',
#  ('name', frozenset({'washington'})),
#  'cast_info',
#  'role_type',
#  'cast_info',
#  'title',
#  ('movie_info', frozenset({'denzel'}))]
#
#  SELECT * FROM cast_info, movie_info, role_type, title, char_name, name WHERE char_name.name ILIKE '%gangster%' AND char_name.id = cast_info.person_role_id AND cast_info.person_id = name.id AND name.name ILIKE '%washington%' AND name.id = cast_info.person_id AND cast_info.role_id = role_type.id AND role_type.id = cast_info.role_id AND cast_info.movie_id = title.id AND title.id = movie_info.movie_id AND movie_info.info ILIKE '%denzel%'
#
# []
# ===============================================================================================================================================
#
# [('char_name', frozenset({'gangster'})),
#  ('cast_info', frozenset({'washington'})),
#  'role_type',
#  ('cast_info', frozenset({'denzel'}))]
#
#  SELECT * FROM cast_info, role_type, char_name WHERE char_name.name ILIKE '%gangster%' AND char_name.id = cast_info.person_role_id AND cast_info.note ILIKE '%washington%' AND cast_info.role_id = role_type.id AND role_type.id = cast_info.role_id AND cast_info.note ILIKE '%denzel%'
#
# []
# ===============================================================================================================================================
#
# [('char_name', frozenset({'gangster'})),
#  ('cast_info', frozenset({'washington'})),
#  'role_type',
#  'cast_info',
#  'char_name',
#  'cast_info',
#  'title',
#  ('movie_info', frozenset({'denzel'}))]
#
#  SELECT * FROM cast_info, movie_info, role_type, title, char_name WHERE char_name.name ILIKE '%gangster%' AND char_name.id = cast_info.person_role_id AND cast_info.note ILIKE '%washington%' AND cast_info.role_id = role_type.id AND role_type.id = cast_info.role_id AND cast_info.person_role_id = char_name.id AND char_name.id = cast_info.person_role_id AND cast_info.movie_id = title.id AND title.id = movie_info.movie_id AND movie_info.info ILIKE '%denzel%'
#
# []
# ===============================================================================================================================================
#
# [('movie_info', frozenset({'washington'})),
#  'title',
#  ('cast_info', frozenset({'gangster'})),
#  ('name', frozenset({'denzel'}))]
#
#  SELECT * FROM cast_info, title, name, movie_info WHERE movie_info.info ILIKE '%washington%' AND movie_info.movie_id = title.id AND title.id = cast_info.movie_id AND cast_info.note ILIKE '%gangster%' AND cast_info.person_id = name.id AND name.name ILIKE '%denzel%'
#
# []
# ===============================================================================================================================================
#
# [('movie_info', frozenset({'washington'})),
#  'title',
#  ('cast_info', frozenset({'denzel'})),
#  'role_type',
#  ('cast_info', frozenset({'gangster'}))]
#
#  SELECT * FROM cast_info, title, role_type, movie_info WHERE movie_info.info ILIKE '%washington%' AND movie_info.movie_id = title.id AND title.id = cast_info.movie_id AND cast_info.note ILIKE '%denzel%' AND cast_info.role_id = role_type.id AND role_type.id = cast_info.role_id AND cast_info.note ILIKE '%gangster%'
#
# []
# ===============================================================================================================================================
#
# [('movie_info', frozenset({'washington'})),
#  'title',
#  ('cast_info', frozenset({'gangster'})),
#  'role_type',
#  'cast_info',
#  'char_name',
#  'cast_info',
#  'title',
#  ('movie_info', frozenset({'denzel'}))]
#
#  SELECT * FROM cast_info, movie_info, role_type, title, char_name WHERE movie_info.info ILIKE '%washington%' AND movie_info.movie_id = title.id AND title.id = cast_info.movie_id AND cast_info.note ILIKE '%gangster%' AND cast_info.role_id = role_type.id AND role_type.id = cast_info.role_id AND cast_info.person_role_id = char_name.id AND char_name.id = cast_info.person_role_id AND cast_info.movie_id = title.id AND title.id = movie_info.movie_id AND movie_info.info ILIKE '%denzel%'
#
# []
# ===============================================================================================================================================
#
# [('movie_info', frozenset({'washington'})),
#  'title',
#  'cast_info',
#  ('name', frozenset({'denzel'})),
#  'cast_info',
#  'role_type',
#  'cast_info',
#  'title',
#  ('movie_info', frozenset({'gangster'}))]
#
#  SELECT * FROM cast_info, movie_info, role_type, title, name WHERE movie_info.info ILIKE '%washington%' AND movie_info.movie_id = title.id AND title.id = cast_info.movie_id AND cast_info.person_id = name.id AND name.name ILIKE '%denzel%' AND name.id = cast_info.person_id AND cast_info.role_id = role_type.id AND role_type.id = cast_info.role_id AND cast_info.movie_id = title.id AND title.id = movie_info.movie_id AND movie_info.info ILIKE '%gangster%'
#
# []
# ===============================================================================================================================================
#
# [('movie_info', frozenset({'washington'})),
#  'title',
#  ('cast_info', frozenset({'denzel'})),
#  'role_type',
#  'cast_info',
#  'char_name',
#  'cast_info',
#  'title',
#  ('movie_info', frozenset({'gangster'}))]
#
#  SELECT * FROM cast_info, movie_info, role_type, title, char_name WHERE movie_info.info ILIKE '%washington%' AND movie_info.movie_id = title.id AND title.id = cast_info.movie_id AND cast_info.note ILIKE '%denzel%' AND cast_info.role_id = role_type.id AND role_type.id = cast_info.role_id AND cast_info.person_role_id = char_name.id AND char_name.id = cast_info.person_role_id AND cast_info.movie_id = title.id AND title.id = movie_info.movie_id AND movie_info.info ILIKE '%gangster%'
#
# []
# ===============================================================================================================================================
#
# [('cast_info', frozenset({'gangster'})),
#  ('name', frozenset({'washington'})),
#  'cast_info',
#  ('name', frozenset({'denzel'}))]
#
#  SELECT * FROM cast_info, name WHERE cast_info.note ILIKE '%gangster%' AND cast_info.person_id = name.id AND name.name ILIKE '%washington%' AND name.id = cast_info.person_id AND cast_info.person_id = name.id AND name.name ILIKE '%denzel%'
# []
# ===============================================================================================================================================
#
# [('cast_info', frozenset({'gangster'})),
#  ('name', frozenset({'denzel'})),
#  ('cast_info', frozenset({'washington'}))]
#
#  SELECT * FROM cast_info, name WHERE cast_info.note ILIKE '%gangster%' AND cast_info.person_id = name.id AND name.name ILIKE '%denzel%' AND name.id = cast_info.person_id AND cast_info.note ILIKE '%washington%'
#
# []
# ===============================================================================================================================================
#
# [('cast_info', frozenset({'gangster'})),
#  ('name', frozenset({'washington'})),
#  ('cast_info', frozenset({'denzel'}))]
#
#  SELECT * FROM cast_info, name WHERE cast_info.note ILIKE '%gangster%' AND cast_info.person_id = name.id AND name.name ILIKE '%washington%' AND name.id = cast_info.person_id AND cast_info.note ILIKE '%denzel%'
#
# []
# ===============================================================================================================================================
#
# [('cast_info', frozenset({'gangster'})),
#  ('name', frozenset({'washington'})),
#  'cast_info',
#  'role_type',
#  'cast_info',
#  'char_name',
#  'cast_info',
#  'title',
#  ('movie_info', frozenset({'denzel'}))]
#
#  SELECT * FROM cast_info, movie_info, role_type, title, char_name, name WHERE cast_info.note ILIKE '%gangster%' AND cast_info.person_id = name.id AND name.name ILIKE '%washington%' AND name.id = cast_info.person_id AND cast_info.role_id = role_type.id AND role_type.id = cast_info.role_id AND cast_info.person_role_id = char_name.id AND char_name.id = cast_info.person_role_id AND cast_info.movie_id = title.id AND title.id = movie_info.movie_id AND movie_info.info ILIKE '%denzel%'
#
# []
# ===============================================================================================================================================
#
# [('cast_info', frozenset({'gangster'})),
#  'role_type',
#  ('cast_info', frozenset({'washington'})),
#  'char_name',
#  ('cast_info', frozenset({'denzel'}))]
#
#  SELECT * FROM cast_info, role_type, char_name WHERE cast_info.note ILIKE '%gangster%' AND cast_info.role_id = role_type.id AND role_type.id = cast_info.role_id AND cast_info.note ILIKE '%washington%' AND cast_info.person_role_id = char_name.id AND char_name.id = cast_info.person_role_id AND cast_info.note ILIKE '%denzel%'
#
# []
# ===============================================================================================================================================
#
# [('cast_info', frozenset({'gangster'})),
#  'role_type',
#  ('cast_info', frozenset({'washington'})),
#  'char_name',
#  'cast_info',
#  'role_type',
#  'cast_info',
#  'title',
#  ('movie_info', frozenset({'denzel'}))]
#
#  SELECT * FROM cast_info, movie_info, role_type, title, char_name WHERE cast_info.note ILIKE '%gangster%' AND cast_info.role_id = role_type.id AND role_type.id = cast_info.role_id AND cast_info.note ILIKE '%washington%' AND cast_info.person_role_id = char_name.id AND char_name.id = cast_info.person_role_id AND cast_info.role_id = role_type.id AND role_type.id = cast_info.role_id AND cast_info.movie_id = title.id AND title.id = movie_info.movie_id AND movie_info.info ILIKE '%denzel%'
#
# []
# ===============================================================================================================================================
#
# [('name', frozenset({'denzel'})),
#  'cast_info',
#  ('name', frozenset({'washington'})),
#  'cast_info',
#  'role_type',
#  'cast_info',
#  'title',
#  ('movie_info', frozenset({'gangster'}))]
#
#  SELECT * FROM cast_info, movie_info, role_type, title, name WHERE name.name ILIKE '%denzel%' AND name.id = cast_info.person_id AND cast_info.person_id = name.id AND name.name ILIKE '%washington%' AND name.id = cast_info.person_id AND cast_info.role_id = role_type.id AND role_type.id = cast_info.role_id AND cast_info.movie_id = title.id AND title.id = movie_info.movie_id AND movie_info.info ILIKE '%gangster%'
#
# []
# ===============================================================================================================================================
#
# [('name', frozenset({'denzel'})),
#  ('cast_info', frozenset({'washington'})),
#  'role_type',
#  'cast_info',
#  'char_name',
#  'cast_info',
#  'title',
#  ('movie_info', frozenset({'gangster'}))]
#
#  SELECT * FROM cast_info, movie_info, role_type, title, char_name, name WHERE name.name ILIKE '%denzel%' AND name.id = cast_info.person_id AND cast_info.note ILIKE '%washington%' AND cast_info.role_id = role_type.id AND role_type.id = cast_info.role_id AND cast_info.person_role_id = char_name.id AND char_name.id = cast_info.person_role_id AND cast_info.movie_id = title.id AND title.id = movie_info.movie_id AND movie_info.info ILIKE '%gangster%'
#
# []
# ===============================================================================================================================================
#
# [('name', frozenset({'washington'})),
#  ('cast_info', frozenset({'denzel'})),
#  'role_type',
#  'cast_info',
#  'char_name',
#  'cast_info',
#  'title',
#  ('movie_info', frozenset({'gangster'}))]
#
#  SELECT * FROM cast_info, movie_info, role_type, title, char_name, name WHERE name.name ILIKE '%washington%' AND name.id = cast_info.person_id AND cast_info.note ILIKE '%denzel%' AND cast_info.role_id = role_type.id AND role_type.id = cast_info.role_id AND cast_info.person_role_id = char_name.id AND char_name.id = cast_info.person_role_id AND cast_info.movie_id = title.id AND title.id = movie_info.movie_id AND movie_info.info ILIKE '%gangster%'
#
# []
# ===============================================================================================================================================
#
# [('cast_info', frozenset({'denzel'})),
#  'role_type',
#  ('cast_info', frozenset({'washington'})),
#  'char_name',
#  'cast_info',
#  'role_type',
#  'cast_info',
#  'title',
#  ('movie_info', frozenset({'gangster'}))]
#
#  SELECT * FROM cast_info, movie_info, role_type, title, char_name WHERE cast_info.note ILIKE '%denzel%' AND cast_info.role_id = role_type.id AND role_type.id = cast_info.role_id AND cast_info.note ILIKE '%washington%' AND cast_info.person_role_id = char_name.id AND char_name.id = cast_info.person_role_id AND cast_info.role_id = role_type.id AND role_type.id = cast_info.role_id AND cast_info.movie_id = title.id AND title.id = movie_info.movie_id AND movie_info.info ILIKE '%gangster%'
#
# []

# %%
def TF_IAF(term,table_name,column_name,wordHash,wordCount):
    
    (IAF,ctids) = wordHash[term][table_name][column_name]
    
    frequency = len(ctids)
    distinct_terms = wordCount[table_name][column_name]
    TF = log1p(frequency) / log1p(distinct_terms)
    
    return TF*IAF

# %%
Gts =  MatchGraph(Rq,G,Mq[0])
Cn = SingleCN(Mq[0],Gts,10,Q)
Cn
# Out:
# [('movie_info', frozenset({'denzel', 'washington'})),
#  'title',
#  ('movie_info', frozenset({'gangster', 'washington'}))]

# %%
def anorm(relation,Bj):
    return wordCount[relation][Bj]
    
def CNRank(Cns,mi):
    Ranking = []
    for (Cn,Gts) in Cns:
        cosprod = 1
        
        if Cn is None:
            continue
        
        for relation in Cn:
            if(type(relation) is str):
                continue

            (table_name,predicates) = relation

            for term in predicates:
                wsum = 0
                for Bj in wordHash[term][table_name].keys():       
                    w=TF_IAF(term,table_name,Bj,wordHash,wordCount)
                    wsum += w

                cos = wsum/anorm(table_name,Bj)
                cosprod *= cos

            score = mi * cosprod * 1/len(Cn)
            Ranking.append((Cn,Gts,score))
        
    return sorted(Ranking,key=lambda x: x[-1],reverse=True)

# %%
Cns = []
for M in Mq: 
    Gts =  MatchGraph(Rq,G,M)
    Cn = SingleCN(M,Gts,10,Q)
    Cns.append( (Cn,Gts) )
RankedCns=CNRank(Cns,200000)

for (Cn,Gts,Score) in RankedCns:
    print(Score)
    print(Cn)
# Out:
# 0.9921613800900272
# [('cast_info', frozenset({'gangster'})), ('name', frozenset({'denzel'})), ('cast_info', frozenset({'washington'}))]
# 0.9921613800900272
# [('cast_info', frozenset({'gangster'})), ('name', frozenset({'washington'})), ('cast_info', frozenset({'denzel'}))]
# 0.7441210350675204
# [('cast_info', frozenset({'gangster'})), ('name', frozenset({'washington'})), 'cast_info', ('name', frozenset({'denzel'}))]
# 0.5952968280540163
# [('cast_info', frozenset({'gangster'})), 'role_type', ('cast_info', frozenset({'washington'})), 'char_name', ('cast_info', frozenset({'denzel'}))]
# 0.3629354197338176
# [('title', frozenset({'gangster'})), ('cast_info', frozenset({'denzel', 'washington'}))]
# 0.33072046003000904
# [('cast_info', frozenset({'gangster'})), ('name', frozenset({'washington'})), 'cast_info', 'role_type', 'cast_info', 'char_name', 'cast_info', 'title', ('movie_info', frozenset({'denzel'}))]
# 0.33072046003000904
# [('cast_info', frozenset({'gangster'})), 'role_type', ('cast_info', frozenset({'washington'})), 'char_name', 'cast_info', 'role_type', 'cast_info', 'title', ('movie_info', frozenset({'denzel'}))]
# 0.2848572085681347
# [('cast_info', frozenset({'denzel'})), 'role_type', ('cast_info', frozenset({'washington'})), 'char_name', 'cast_info', 'role_type', 'cast_info', 'title', ('movie_info', frozenset({'gangster'}))]
# 0.24195694648921173
# [('title', frozenset({'gangster'})), ('cast_info', frozenset({'denzel'})), ('title', frozenset({'washington'}))]
# 0.24195694648921173
# [('title', frozenset({'gangster'})), ('movie_info', frozenset({'denzel'})), ('title', frozenset({'washington'}))]
# 0.24195694648921173
# [('title', frozenset({'gangster'})), ('cast_info', frozenset({'washington'})), ('name', frozenset({'denzel'}))]
# 0.24195694648921173
# [('title', frozenset({'gangster'})), ('cast_info', frozenset({'denzel'})), ('name', frozenset({'washington'}))]
# 0.1998971388111065
# [('char_name', frozenset({'denzel'})), ('cast_info', frozenset({'gangster'})), ('char_name', frozenset({'washington'}))]
# 0.1998971388111065
# [('char_name', frozenset({'denzel'})), ('cast_info', frozenset({'washington'})), ('title', frozenset({'gangster'}))]
# 0.1998971388111065
# [('char_name', frozenset({'denzel'})), ('cast_info', frozenset({'gangster'})), ('title', frozenset({'washington'}))]
# 0.1998971388111065
# [('char_name', frozenset({'denzel'})), ('cast_info', frozenset({'washington'})), ('char_name', frozenset({'gangster'}))]
# 0.1998971388111065
# [('char_name', frozenset({'denzel'})), ('cast_info', frozenset({'gangster'})), ('name', frozenset({'washington'}))]
# 0.18888765530679943
# [('char_name', frozenset({'gangster'})), ('cast_info', frozenset({'denzel', 'washington'}))]
# 0.1814677098669088
# [('title', frozenset({'gangster'})), ('movie_info', frozenset({'denzel'})), 'title', ('movie_info', frozenset({'washington'}))]
# 0.1814677098669088
# [('title', frozenset({'gangster'})), ('cast_info', frozenset({'washington'})), 'role_type', ('cast_info', frozenset({'denzel'}))]
# 0.1814677098669088
# [('title', frozenset({'gangster'})), ('movie_info', frozenset({'denzel'})), 'title', ('cast_info', frozenset({'washington'}))]
# 0.14992285410832987
# [('char_name', frozenset({'denzel'})), 'cast_info', ('title', frozenset({'gangster'})), ('movie_info', frozenset({'washington'}))]
# 0.14992285410832987
# [('char_name', frozenset({'denzel'})), 'cast_info', ('title', frozenset({'washington'})), ('movie_info', frozenset({'gangster'}))]
# 0.14992285410832987
# [('char_name', frozenset({'denzel'})), ('cast_info', frozenset({'washington'})), 'role_type', ('cast_info', frozenset({'gangster'}))]
# 0.14517416789352705
# [('title', frozenset({'gangster'})), 'movie_info', 'title', 'cast_info', ('name', frozenset({'denzel', 'washington'}))]
# 0.14517416789352705
# [('title', frozenset({'gangster'})), ('movie_info', frozenset({'washington'})), 'title', 'cast_info', ('name', frozenset({'denzel'}))]
# 0.14517416789352705
# [('title', frozenset({'gangster'})), ('movie_info', frozenset({'denzel'})), 'title', 'cast_info', ('name', frozenset({'washington'}))]
# 0.14380421091293621
# [('char_name', frozenset({'washington'})), ('cast_info', frozenset({'denzel'})), ('title', frozenset({'gangster'}))]
# 0.14380421091293621
# [('char_name', frozenset({'washington'})), ('cast_info', frozenset({'denzel'})), ('char_name', frozenset({'gangster'}))]
# 0.14380421091293621
# [('char_name', frozenset({'washington'})), ('cast_info', frozenset({'gangster'})), ('name', frozenset({'denzel'}))]
# 0.12876756986240867
# [('title', frozenset({'washington'})), ('cast_info', frozenset({'denzel'})), ('char_name', frozenset({'gangster'}))]
# 0.12876756986240867
# [('title', frozenset({'washington'})), ('cast_info', frozenset({'gangster'})), ('name', frozenset({'denzel'}))]
# 0.1259251035378663
# [('char_name', frozenset({'gangster'})), 'cast_info', ('name', frozenset({'denzel', 'washington'}))]
# 0.1259251035378663
# [('char_name', frozenset({'gangster'})), ('cast_info', frozenset({'washington'})), ('name', frozenset({'denzel'}))]
# 0.1259251035378663
# [('char_name', frozenset({'gangster'})), ('cast_info', frozenset({'denzel'})), ('name', frozenset({'washington'}))]
# 0.1199382832866639
# [('char_name', frozenset({'denzel'})), 'cast_info', ('char_name', frozenset({'gangster'})), 'cast_info', ('char_name', frozenset({'washington'}))]
# 0.1199382832866639
# [('char_name', frozenset({'denzel'})), 'cast_info', ('title', frozenset({'washington'})), 'movie_info', ('title', frozenset({'gangster'}))]
# 0.1199382832866639
# [('char_name', frozenset({'denzel'})), 'cast_info', ('name', frozenset({'washington'})), 'cast_info', ('title', frozenset({'gangster'}))]
# 0.1199382832866639
# [('char_name', frozenset({'denzel'})), 'cast_info', ('char_name', frozenset({'gangster'})), 'cast_info', ('title', frozenset({'washington'}))]
# 0.1199382832866639
# [('char_name', frozenset({'denzel'})), 'cast_info', ('name', frozenset({'washington'})), 'cast_info', ('char_name', frozenset({'gangster'}))]
# 0.10785315818470216
# [('char_name', frozenset({'washington'})), 'cast_info', ('title', frozenset({'gangster'})), ('movie_info', frozenset({'denzel'}))]
# 0.10785315818470216
# [('char_name', frozenset({'washington'})), ('cast_info', frozenset({'denzel'})), 'role_type', ('cast_info', frozenset({'gangster'}))]
# 0.10369583420966218
# [('title', frozenset({'gangster'})), 'movie_info', ('title', frozenset({'washington'})), 'movie_info', 'title', 'cast_info', ('name', frozenset({'denzel'}))]
# 0.10369583420966218
# [('title', frozenset({'gangster'})), 'movie_info', 'title', 'cast_info', ('name', frozenset({'washington'})), 'cast_info', ('name', frozenset({'denzel'}))]
# 0.0965756773968065
# [('title', frozenset({'washington'})), ('cast_info', frozenset({'denzel'})), 'role_type', ('cast_info', frozenset({'gangster'}))]
# 0.0965756773968065
# [('title', frozenset({'washington'})), ('movie_info', frozenset({'denzel'})), 'title', ('cast_info', frozenset({'gangster'}))]
# 0.0965756773968065
# [('title', frozenset({'washington'})), ('movie_info', frozenset({'gangster'})), 'title', ('cast_info', frozenset({'denzel'}))]
# 0.0965756773968065
# [('title', frozenset({'washington'})), ('movie_info', frozenset({'denzel'})), 'title', ('movie_info', frozenset({'gangster'}))]
# 0.09444382765339972
# [('char_name', frozenset({'gangster'})), ('cast_info', frozenset({'washington'})), 'role_type', ('cast_info', frozenset({'denzel'}))]
# 0.0907338549334544
# [('title', frozenset({'gangster'})), ('cast_info', frozenset({'denzel'})), 'role_type', 'cast_info', 'char_name', 'cast_info', 'title', ('movie_info', frozenset({'washington'}))]
# 0.08628252654776172
# [('char_name', frozenset({'washington'})), 'cast_info', ('name', frozenset({'denzel'})), 'cast_info', ('title', frozenset({'gangster'}))]
# 0.08628252654776172
# [('char_name', frozenset({'washington'})), 'cast_info', ('name', frozenset({'denzel'})), 'cast_info', ('char_name', frozenset({'gangster'}))]
# 0.08567020234761706
# [('char_name', frozenset({'denzel'})), 'cast_info', ('title', frozenset({'gangster'})), 'movie_info', 'title', 'cast_info', ('char_name', frozenset({'washington'}))]
# 0.07966352039873341
# [('name', frozenset({'denzel'})), 'cast_info', ('name', frozenset({'washington'})), 'cast_info', 'role_type', 'cast_info', 'title', ('movie_info', frozenset({'gangster'}))]
# 0.07966352039873341
# [('name', frozenset({'denzel'})), ('cast_info', frozenset({'washington'})), 'role_type', 'cast_info', 'char_name', 'cast_info', 'title', ('movie_info', frozenset({'gangster'}))]
# 0.0772605419174452
# [('title', frozenset({'washington'})), ('movie_info', frozenset({'denzel'})), 'title', 'cast_info', ('char_name', frozenset({'gangster'}))]
# 0.0772605419174452
# [('title', frozenset({'washington'})), ('movie_info', frozenset({'gangster'})), 'title', 'cast_info', ('name', frozenset({'denzel'}))]
# 0.07555506212271977
# [('char_name', frozenset({'gangster'})), 'cast_info', ('name', frozenset({'washington'})), 'cast_info', ('name', frozenset({'denzel'}))]
# 0.07496142705416493
# [('char_name', frozenset({'denzel'})), 'cast_info', 'role_type', 'cast_info', 'char_name', 'cast_info', 'title', ('movie_info', frozenset({'gangster', 'washington'}))]
# 0.07496142705416493
# [('char_name', frozenset({'denzel'})), 'cast_info', ('char_name', frozenset({'washington'})), 'cast_info', 'role_type', 'cast_info', 'title', ('movie_info', frozenset({'gangster'}))]
# 0.07496142705416493
# [('char_name', frozenset({'denzel'})), 'cast_info', ('char_name', frozenset({'gangster'})), 'cast_info', 'role_type', 'cast_info', 'title', ('movie_info', frozenset({'washington'}))]
# 0.07496142705416493
# [('char_name', frozenset({'denzel'})), ('cast_info', frozenset({'gangster'})), 'role_type', 'cast_info', 'char_name', 'cast_info', 'title', ('movie_info', frozenset({'washington'}))]
# 0.07496142705416493
# [('char_name', frozenset({'denzel'})), 'cast_info', ('name', frozenset({'washington'})), 'cast_info', 'role_type', 'cast_info', 'title', ('movie_info', frozenset({'gangster'}))]
# 0.07496142705416493
# [('char_name', frozenset({'denzel'})), ('cast_info', frozenset({'washington'})), 'role_type', 'cast_info', 'char_name', 'cast_info', 'title', ('movie_info', frozenset({'gangster'}))]
# 0.05518610136960372
# [('title', frozenset({'washington'})), 'movie_info', 'title', 'cast_info', ('name', frozenset({'denzel'})), 'cast_info', ('char_name', frozenset({'gangster'}))]
# 0.05392657909235108
# [('char_name', frozenset({'washington'})), 'cast_info', ('char_name', frozenset({'gangster'})), 'cast_info', 'role_type', 'cast_info', 'title', ('movie_info', frozenset({'denzel'}))]
# 0.05392657909235108
# [('char_name', frozenset({'washington'})), ('cast_info', frozenset({'gangster'})), 'role_type', 'cast_info', 'char_name', 'cast_info', 'title', ('movie_info', frozenset({'denzel'}))]
# 0.05392657909235108
# [('char_name', frozenset({'washington'})), 'cast_info', ('name', frozenset({'denzel'})), 'cast_info', 'role_type', 'cast_info', 'title', ('movie_info', frozenset({'gangster'}))]
# 0.05392657909235108
# [('char_name', frozenset({'washington'})), ('cast_info', frozenset({'denzel'})), 'role_type', 'cast_info', 'char_name', 'cast_info', 'title', ('movie_info', frozenset({'gangster'}))]
# 0.04722191382669986
# [('char_name', frozenset({'gangster'})), 'cast_info', ('name', frozenset({'denzel'})), 'cast_info', 'role_type', 'cast_info', 'title', ('movie_info', frozenset({'washington'}))]
# 0.04722191382669986
# [('char_name', frozenset({'gangster'})), ('cast_info', frozenset({'denzel'})), 'role_type', 'cast_info', 'char_name', 'cast_info', 'title', ('movie_info', frozenset({'washington'}))]
# 0.04722191382669986
# [('char_name', frozenset({'gangster'})), 'cast_info', ('name', frozenset({'washington'})), 'cast_info', 'role_type', 'cast_info', 'title', ('movie_info', frozenset({'denzel'}))]
# 0.04722191382669986
# [('char_name', frozenset({'gangster'})), ('cast_info', frozenset({'washington'})), 'role_type', 'cast_info', 'char_name', 'cast_info', 'title', ('movie_info', frozenset({'denzel'}))]
# 0.013780124728635691
# [('name', frozenset({'washington'})), ('cast_info', frozenset({'denzel'})), 'role_type', 'cast_info', 'char_name', 'cast_info', 'title', ('movie_info', frozenset({'gangster'}))]
# 0.006132935137186792
# [('movie_info', frozenset({'washington'})), 'title', ('cast_info', frozenset({'gangster'})), ('name', frozenset({'denzel'}))]
# 0.004906348109749434
# [('movie_info', frozenset({'washington'})), 'title', ('cast_info', frozenset({'denzel'})), 'role_type', ('cast_info', frozenset({'gangster'}))]
# 0.0027257489498607964
# [('movie_info', frozenset({'washington'})), 'title', ('cast_info', frozenset({'gangster'})), 'role_type', 'cast_info', 'char_name', 'cast_info', 'title', ('movie_info', frozenset({'denzel'}))]
# 0.0027257489498607964
# [('movie_info', frozenset({'washington'})), 'title', 'cast_info', ('name', frozenset({'denzel'})), 'cast_info', 'role_type', 'cast_info', 'title', ('movie_info', frozenset({'gangster'}))]
# 0.0027257489498607964
# [('movie_info', frozenset({'washington'})), 'title', ('cast_info', frozenset({'denzel'})), 'role_type', 'cast_info', 'char_name', 'cast_info', 'title', ('movie_info', frozenset({'gangster'}))]
# 4.161049918445109e-06
# [('cast_info', frozenset({'denzel', 'washington'})), 'role_type', ('cast_info', frozenset({'gangster'}))]
# 3.161562733665495e-06
# [('cast_info', frozenset({'gangster'})), ('name', frozenset({'denzel'})), ('cast_info', frozenset({'washington'}))]
# 3.1015431166763867e-06
# [('title', frozenset({'gangster'})), ('cast_info', frozenset({'denzel'})), ('title', frozenset({'washington'}))]
# 3.1015431166763867e-06
# [('title', frozenset({'gangster'})), ('cast_info', frozenset({'denzel'})), ('name', frozenset({'washington'}))]
# 2.9749533167831272e-06
# [('char_name', frozenset({'denzel'})), ('cast_info', frozenset({'gangster'})), ('char_name', frozenset({'washington'}))]
# 2.9749533167831272e-06
# [('char_name', frozenset({'denzel'})), ('cast_info', frozenset({'gangster'})), ('title', frozenset({'washington'}))]
# 2.9749533167831272e-06
# [('char_name', frozenset({'denzel'})), ('cast_info', frozenset({'gangster'})), ('name', frozenset({'washington'}))]
# 2.8985982488981104e-06
# [('cast_info', frozenset({'gangster'})), 'role_type', ('cast_info', frozenset({'washington'})), 'char_name', ('cast_info', frozenset({'denzel'}))]
# 2.140154765432042e-06
# [('char_name', frozenset({'washington'})), ('cast_info', frozenset({'gangster'})), ('name', frozenset({'denzel'}))]
# 1.916373147382896e-06
# [('title', frozenset({'washington'})), ('cast_info', frozenset({'gangster'})), ('name', frozenset({'denzel'}))]
# 1.8433649745451032e-06
# [('char_name', frozenset({'washington'})), ('cast_info', frozenset({'denzel'})), ('title', frozenset({'gangster'}))]
# 1.8433649745451032e-06
# [('char_name', frozenset({'washington'})), ('cast_info', frozenset({'denzel'})), ('char_name', frozenset({'gangster'}))]
# 1.6506166727298597e-06
# [('title', frozenset({'washington'})), ('cast_info', frozenset({'denzel'})), ('char_name', frozenset({'gangster'}))]
# 1.6141803067102465e-06
# [('char_name', frozenset({'gangster'})), ('cast_info', frozenset({'denzel'})), ('name', frozenset({'washington'}))]
# 1.6103323604989502e-06
# [('cast_info', frozenset({'gangster'})), 'role_type', ('cast_info', frozenset({'washington'})), 'char_name', 'cast_info', 'role_type', 'cast_info', 'title', ('movie_info', frozenset({'denzel'}))]
# 1.387016639481703e-06
# [('cast_info', frozenset({'denzel', 'washington'})), 'role_type', 'cast_info', 'char_name', 'cast_info', 'role_type', 'cast_info', 'title', ('movie_info', frozenset({'gangster'}))]
# 1.387016639481703e-06
# [('cast_info', frozenset({'denzel'})), 'role_type', ('cast_info', frozenset({'washington'})), 'char_name', 'cast_info', 'role_type', 'cast_info', 'title', ('movie_info', frozenset({'gangster'}))]
# 1.3825237309088274e-06
# [('char_name', frozenset({'washington'})), ('cast_info', frozenset({'denzel'})), 'role_type', ('cast_info', frozenset({'gangster'}))]
# 1.2379625045473948e-06
# [('title', frozenset({'washington'})), ('cast_info', frozenset({'denzel'})), 'role_type', ('cast_info', frozenset({'gangster'}))]
# 1.1781282015141608e-06
# [('title', frozenset({'gangster'})), ('cast_info', frozenset({'washington'})), ('name', frozenset({'denzel'}))]
# 1.163078668753645e-06
# [('title', frozenset({'gangster'})), ('cast_info', frozenset({'denzel'})), 'role_type', 'cast_info', 'char_name', 'cast_info', 'title', ('movie_info', frozenset({'washington'}))]
# 1.1156074937936728e-06
# [('char_name', frozenset({'denzel'})), ('cast_info', frozenset({'gangster'})), 'role_type', 'cast_info', 'char_name', 'cast_info', 'title', ('movie_info', frozenset({'washington'}))]
# 9.733320743732234e-07
# [('char_name', frozenset({'denzel'})), ('cast_info', frozenset({'washington'})), ('title', frozenset({'gangster'}))]
# 9.733320743732234e-07
# [('char_name', frozenset({'denzel'})), ('cast_info', frozenset({'washington'})), ('char_name', frozenset({'gangster'}))]
# 8.835961511356206e-07
# [('title', frozenset({'gangster'})), ('cast_info', frozenset({'washington'})), 'role_type', ('cast_info', frozenset({'denzel'}))]
# 8.025580370370157e-07
# [('char_name', frozenset({'washington'})), ('cast_info', frozenset({'gangster'})), 'role_type', 'cast_info', 'char_name', 'cast_info', 'title', ('movie_info', frozenset({'denzel'}))]
# 7.299990557799175e-07
# [('char_name', frozenset({'denzel'})), ('cast_info', frozenset({'washington'})), 'role_type', ('cast_info', frozenset({'gangster'}))]
# 6.912618654544137e-07
# [('char_name', frozenset({'washington'})), ('cast_info', frozenset({'denzel'})), 'role_type', 'cast_info', 'char_name', 'cast_info', 'title', ('movie_info', frozenset({'gangster'}))]
# 6.131500579305159e-07
# [('char_name', frozenset({'gangster'})), ('cast_info', frozenset({'washington'})), ('name', frozenset({'denzel'}))]
# 6.053176150163424e-07
# [('char_name', frozenset({'gangster'})), ('cast_info', frozenset({'denzel'})), 'role_type', 'cast_info', 'char_name', 'cast_info', 'title', ('movie_info', frozenset({'washington'}))]
# 5.468843027430359e-07
# [('cast_info', frozenset({'gangster'})), ('name', frozenset({'washington'})), ('cast_info', frozenset({'denzel'}))]
# 5.44123139834986e-07
# [('char_name', frozenset({'denzel'})), 'cast_info', ('title', frozenset({'gangster'})), ('movie_info', frozenset({'washington'}))]
# 4.598625434478869e-07
# [('char_name', frozenset({'gangster'})), ('cast_info', frozenset({'washington'})), 'role_type', ('cast_info', frozenset({'denzel'}))]
# 4.1016322705727687e-07
# [('cast_info', frozenset({'gangster'})), ('name', frozenset({'washington'})), 'cast_info', ('name', frozenset({'denzel'}))]
# 3.91437312353827e-07
# [('char_name', frozenset({'washington'})), 'cast_info', ('title', frozenset({'gangster'})), ('movie_info', frozenset({'denzel'}))]
# 3.8789479440645526e-07
# [('name', frozenset({'denzel'})), ('cast_info', frozenset({'washington'})), 'role_type', 'cast_info', 'char_name', 'cast_info', 'title', ('movie_info', frozenset({'gangster'}))]
# 3.6499952788995875e-07
# [('char_name', frozenset({'denzel'})), ('cast_info', frozenset({'washington'})), 'role_type', 'cast_info', 'char_name', 'cast_info', 'title', ('movie_info', frozenset({'gangster'}))]
# 3.109275084771349e-07
# [('char_name', frozenset({'denzel'})), 'cast_info', ('title', frozenset({'gangster'})), 'movie_info', 'title', 'cast_info', ('char_name', frozenset({'washington'}))]
# 2.8957802385549105e-07
# [('char_name', frozenset({'denzel'})), 'cast_info', ('title', frozenset({'washington'})), ('movie_info', frozenset({'gangster'}))]
# 2.7494279254767495e-07
# [('char_name', frozenset({'washington'})), 'cast_info', ('name', frozenset({'denzel'})), 'cast_info', ('title', frozenset({'gangster'}))]
# 2.7494279254767495e-07
# [('char_name', frozenset({'washington'})), 'cast_info', ('name', frozenset({'denzel'})), 'cast_info', ('char_name', frozenset({'gangster'}))]
# 2.3166241908439284e-07
# [('char_name', frozenset({'denzel'})), 'cast_info', ('title', frozenset({'washington'})), 'movie_info', ('title', frozenset({'gangster'}))]
# 2.2993127172394344e-07
# [('char_name', frozenset({'gangster'})), ('cast_info', frozenset({'washington'})), 'role_type', 'cast_info', 'char_name', 'cast_info', 'title', ('movie_info', frozenset({'denzel'}))]
# 2.2654861111540638e-07
# [('char_name', frozenset({'denzel'})), 'cast_info', ('char_name', frozenset({'gangster'})), 'cast_info', ('char_name', frozenset({'washington'}))]
# 2.2654861111540638e-07
# [('char_name', frozenset({'denzel'})), 'cast_info', ('char_name', frozenset({'gangster'})), 'cast_info', ('title', frozenset({'washington'}))]
# 2.0028990864050131e-07
# [('title', frozenset({'gangster'})), 'movie_info', ('title', frozenset({'washington'})), 'movie_info', 'title', 'cast_info', ('name', frozenset({'denzel'}))]
# 1.834164663173132e-07
# [('title', frozenset({'gangster'})), ('movie_info', frozenset({'denzel'})), ('title', frozenset({'washington'}))]
# 1.8229476758101193e-07
# [('cast_info', frozenset({'gangster'})), ('name', frozenset({'washington'})), 'cast_info', 'role_type', 'cast_info', 'char_name', 'cast_info', 'title', ('movie_info', frozenset({'denzel'}))]
# 1.7664155387639492e-07
# [('name', frozenset({'washington'})), ('cast_info', frozenset({'denzel'})), 'role_type', 'cast_info', 'char_name', 'cast_info', 'title', ('movie_info', frozenset({'gangster'}))]
# 1.758527644873598e-07
# [('title', frozenset({'washington'})), 'movie_info', 'title', 'cast_info', ('name', frozenset({'denzel'})), 'cast_info', ('char_name', frozenset({'gangster'}))]
# 1.7564371958668162e-07
# [('name', frozenset({'denzel', 'washington'})), ('cast_info', frozenset({'gangster'}))]
# 1.7183924534229684e-07
# [('char_name', frozenset({'washington'})), 'cast_info', ('name', frozenset({'denzel'})), 'cast_info', 'role_type', 'cast_info', 'title', ('movie_info', frozenset({'gangster'}))]
# 1.6169653299647726e-07
# [('char_name', frozenset({'denzel'})), 'cast_info', ('char_name', frozenset({'washington'})), 'cast_info', 'role_type', 'cast_info', 'title', ('movie_info', frozenset({'gangster'}))]
# 1.504745558160214e-07
# [('char_name', frozenset({'gangster'})), 'cast_info', ('name', frozenset({'denzel'})), 'cast_info', 'role_type', 'cast_info', 'title', ('movie_info', frozenset({'washington'}))]
# 1.4159288194712898e-07
# [('char_name', frozenset({'denzel'})), 'cast_info', ('char_name', frozenset({'gangster'})), 'cast_info', 'role_type', 'cast_info', 'title', ('movie_info', frozenset({'washington'}))]
# 1.375623497379849e-07
# [('title', frozenset({'gangster'})), ('movie_info', frozenset({'denzel'})), 'title', ('movie_info', frozenset({'washington'}))]
# 1.375623497379849e-07
# [('title', frozenset({'gangster'})), ('movie_info', frozenset({'denzel'})), 'title', ('cast_info', frozenset({'washington'}))]
# 1.1004987979038793e-07
# [('title', frozenset({'gangster'})), ('movie_info', frozenset({'denzel'})), 'title', 'cast_info', ('name', frozenset({'washington'}))]
# 1.0186065083470867e-07
# [('char_name', frozenset({'washington'})), 'cast_info', ('char_name', frozenset({'gangster'})), 'cast_info', 'role_type', 'cast_info', 'title', ('movie_info', frozenset({'denzel'}))]
# 9.1272920845708e-08
# [('movie_info', frozenset({'washington'})), 'title', ('cast_info', frozenset({'gangster'})), ('name', frozenset({'denzel'}))]
# 7.320959260457881e-08
# [('title', frozenset({'washington'})), ('movie_info', frozenset({'denzel'})), 'title', ('cast_info', frozenset({'gangster'}))]
# 7.320959260457881e-08
# [('title', frozenset({'washington'})), ('movie_info', frozenset({'denzel'})), 'title', ('movie_info', frozenset({'gangster'}))]
# 6.61105801371468e-08
# [('char_name', frozenset({'denzel'})), 'cast_info', ('name', frozenset({'washington'})), 'cast_info', ('title', frozenset({'gangster'}))]
# 6.61105801371468e-08
# [('char_name', frozenset({'denzel'})), 'cast_info', ('name', frozenset({'washington'})), 'cast_info', ('char_name', frozenset({'gangster'}))]
# 6.289238820630455e-08
# [('movie_info', frozenset({'washington'})), 'title', ('cast_info', frozenset({'denzel'})), 'role_type', ('cast_info', frozenset({'gangster'}))]
# 5.856767408366305e-08
# [('title', frozenset({'washington'})), ('movie_info', frozenset({'denzel'})), 'title', 'cast_info', ('char_name', frozenset({'gangster'}))]
# 5.71576611699629e-08
# [('title', frozenset({'gangster'})), 'movie_info', 'title', 'cast_info', ('name', frozenset({'washington'})), 'cast_info', ('name', frozenset({'denzel'}))]
# 4.3910929896670404e-08
# [('name', frozenset({'denzel', 'washington'})), 'cast_info', 'role_type', 'cast_info', 'char_name', 'cast_info', 'title', ('movie_info', frozenset({'gangster'}))]
# 4.3910929896670404e-08
# [('name', frozenset({'denzel'})), 'cast_info', ('name', frozenset({'washington'})), 'cast_info', 'role_type', 'cast_info', 'title', ('movie_info', frozenset({'gangster'}))]
# 4.164632719723586e-08
# [('char_name', frozenset({'gangster'})), 'cast_info', ('name', frozenset({'washington'})), 'cast_info', ('name', frozenset({'denzel'}))]
# 4.131911258571675e-08
# [('char_name', frozenset({'denzel'})), 'cast_info', ('name', frozenset({'washington'})), 'cast_info', 'role_type', 'cast_info', 'title', ('movie_info', frozenset({'gangster'}))]
# 4.0565742598092444e-08
# [('movie_info', frozenset({'washington'})), 'title', ('cast_info', frozenset({'gangster'})), 'role_type', 'cast_info', 'char_name', 'cast_info', 'title', ('movie_info', frozenset({'denzel'}))]
# 3.494021567016919e-08
# [('movie_info', frozenset({'washington'})), 'title', ('cast_info', frozenset({'denzel'})), 'role_type', 'cast_info', 'char_name', 'cast_info', 'title', ('movie_info', frozenset({'gangster'}))]
# 3.11509465374332e-08
# [('title', frozenset({'washington'})), ('movie_info', frozenset({'gangster'})), 'title', ('cast_info', frozenset({'denzel'}))]
# 2.602895449827241e-08
# [('char_name', frozenset({'gangster'})), 'cast_info', ('name', frozenset({'washington'})), 'cast_info', 'role_type', 'cast_info', 'title', ('movie_info', frozenset({'denzel'}))]
# 2.4920757229946563e-08
# [('title', frozenset({'washington'})), ('movie_info', frozenset({'gangster'})), 'title', 'cast_info', ('name', frozenset({'denzel'}))]
# 1.780687510572133e-08
# [('title', frozenset({'gangster'})), ('movie_info', frozenset({'washington'})), 'title', 'cast_info', ('name', frozenset({'denzel'}))]
# 9.298193809585404e-09
# [('movie_info', frozenset({'denzel', 'washington'})), ('title', frozenset({'gangster'}))]
# 8.68571028276247e-09
# [('movie_info', frozenset({'washington'})), 'title', 'cast_info', ('name', frozenset({'denzel'})), 'cast_info', 'role_type', 'cast_info', 'title', ('movie_info', frozenset({'gangster'}))]
# 6.198795873056936e-09
# [('movie_info', frozenset({'denzel', 'washington'})), 'title', ('movie_info', frozenset({'gangster', 'washington'}))]
# 6.198795873056936e-09
# [('movie_info', frozenset({'denzel', 'washington'})), 'title', ('cast_info', frozenset({'gangster'}))]
# 6.198795873056936e-09
# [('movie_info', frozenset({'denzel', 'washington'})), 'title', ('movie_info', frozenset({'gangster'}))]
# 4.649096904792702e-09
# [('movie_info', frozenset({'denzel', 'washington'})), 'title', 'cast_info', ('char_name', frozenset({'gangster'}))]
# 2.6376100722350024e-09
# [('movie_info', frozenset({'gangster', 'washington'})), 'title', ('cast_info', frozenset({'denzel', 'washington'}))]
# 2.6376100722350024e-09
# [('movie_info', frozenset({'gangster', 'washington'})), 'title', ('cast_info', frozenset({'denzel'}))]
# 2.6376100722350024e-09
# [('movie_info', frozenset({'gangster', 'washington'})), 'title', ('movie_info', frozenset({'denzel'}))]
# 1.9782075541762517e-09
# [('movie_info', frozenset({'gangster', 'washington'})), 'title', 'cast_info', ('name', frozenset({'denzel', 'washington'}))]
# 1.9782075541762517e-09
# [('movie_info', frozenset({'gangster', 'washington'})), 'title', 'cast_info', ('name', frozenset({'denzel'}))]
# 6.192649544561991e-11
# [('cast_info', frozenset({'denzel', 'washington'})), 'role_type', ('cast_info', frozenset({'gangster'}))]
# 3.715589726737195e-11
# [('cast_info', frozenset({'gangster'})), 'role_type', ('cast_info', frozenset({'washington'})), 'char_name', ('cast_info', frozenset({'denzel'}))]
# 2.2652885980263644e-11
# [('title', frozenset({'gangster'})), ('cast_info', frozenset({'denzel', 'washington'}))]
# 2.057529979298573e-11
# [('char_name', frozenset({'washington'})), ('cast_info', frozenset({'denzel'})), 'role_type', ('cast_info', frozenset({'gangster'}))]
# 1.8423878805171746e-11
# [('title', frozenset({'washington'})), ('cast_info', frozenset({'denzel'})), 'role_type', ('cast_info', frozenset({'gangster'}))]
# 1.539416938192184e-11
# [('cast_info', frozenset({'gangster'})), ('name', frozenset({'denzel'})), ('cast_info', frozenset({'washington'}))]
# 1.1789564440644684e-11
# [('char_name', frozenset({'gangster'})), ('cast_info', frozenset({'denzel', 'washington'}))]
# 1.1326442990131822e-11
# [('title', frozenset({'gangster'})), ('cast_info', frozenset({'washington'})), 'role_type', ('cast_info', frozenset({'denzel'}))]
# 1.0864153059705294e-11
# [('char_name', frozenset({'denzel'})), ('cast_info', frozenset({'washington'})), 'role_type', ('cast_info', frozenset({'gangster'}))]
# 7.010277115010033e-12
# [('cast_info', frozenset({'gangster'})), ('name', frozenset({'washington'})), ('cast_info', frozenset({'denzel'}))]
# 6.81969051249768e-12
# [('char_name', frozenset({'washington'})), ('cast_info', frozenset({'gangster'})), ('name', frozenset({'denzel'}))]
# 6.6902244075914495e-12
# [('char_name', frozenset({'washington'})), ('cast_info', frozenset({'denzel'})), ('title', frozenset({'gangster'}))]
# 6.417162213342299e-12
# [('char_name', frozenset({'denzel'})), ('cast_info', frozenset({'gangster'})), ('char_name', frozenset({'washington'}))]
# 6.10660125272489e-12
# [('title', frozenset({'washington'})), ('cast_info', frozenset({'gangster'})), ('name', frozenset({'denzel'}))]
# 5.9906725493684894e-12
# [('title', frozenset({'gangster'})), ('cast_info', frozenset({'denzel'})), ('title', frozenset({'washington'}))]
# 5.894782220322342e-12
# [('char_name', frozenset({'gangster'})), ('cast_info', frozenset({'washington'})), 'role_type', ('cast_info', frozenset({'denzel'}))]
# 5.746162635844135e-12
# [('char_name', frozenset({'denzel'})), ('cast_info', frozenset({'gangster'})), ('title', frozenset({'washington'}))]
# 3.754153600545859e-12
# [('title', frozenset({'gangster'})), ('cast_info', frozenset({'washington'})), ('name', frozenset({'denzel'}))]
# 3.5325668495303314e-12
# [('char_name', frozenset({'denzel'})), ('cast_info', frozenset({'washington'})), ('title', frozenset({'gangster'}))]
# 3.4818888791650252e-12
# [('char_name', frozenset({'washington'})), ('cast_info', frozenset({'denzel'})), ('char_name', frozenset({'gangster'}))]
# 3.1178111312225387e-12
# [('title', frozenset({'washington'})), ('cast_info', frozenset({'denzel'})), ('char_name', frozenset({'gangster'}))]
# 2.6140037284390164e-12
# [('name', frozenset({'denzel', 'washington'})), ('cast_info', frozenset({'gangster'}))]
# 1.953827685897289e-12
# [('char_name', frozenset({'gangster'})), ('cast_info', frozenset({'washington'})), ('name', frozenset({'denzel'}))]
# 1.838504133632615e-12
# [('char_name', frozenset({'denzel'})), ('cast_info', frozenset({'washington'})), ('char_name', frozenset({'gangster'}))]
# 1.7095860399616836e-12
# [('title', frozenset({'gangster'})), ('cast_info', frozenset({'denzel'})), ('name', frozenset({'washington'}))]
# 1.6398091106855975e-12
# [('char_name', frozenset({'denzel'})), ('cast_info', frozenset({'gangster'})), ('name', frozenset({'washington'}))]
# 1.307001864219508e-12
# [('cast_info', frozenset({'gangster'})), ('name', frozenset({'washington'})), 'cast_info', ('name', frozenset({'denzel'}))]
# 1.2207191215000086e-12
# [('cast_info', frozenset({'gangster'})), 'role_type', ('cast_info', frozenset({'washington'})), 'char_name', 'cast_info', 'role_type', 'cast_info', 'title', ('movie_info', frozenset({'denzel'}))]
# 1.0895359565158133e-12
# [('title', frozenset({'washington'})), ('movie_info', frozenset({'denzel'})), 'title', ('cast_info', frozenset({'gangster'}))]
# 9.978647781607834e-13
# [('char_name', frozenset({'washington'})), 'cast_info', ('name', frozenset({'denzel'})), 'cast_info', ('title', frozenset({'gangster'}))]
# 9.359909801988729e-13
# [('movie_info', frozenset({'washington'})), 'title', ('cast_info', frozenset({'denzel'})), 'role_type', ('cast_info', frozenset({'gangster'}))]
# 8.897442384389846e-13
# [('char_name', frozenset({'gangster'})), ('cast_info', frozenset({'denzel'})), ('name', frozenset({'washington'}))]
# 8.407849730694565e-13
# [('char_name', frozenset({'denzel'})), 'cast_info', ('title', frozenset({'washington'})), 'movie_info', ('title', frozenset({'gangster'}))]
# 6.706902751151949e-13
# [('char_name', frozenset({'denzel'})), 'cast_info', ('title', frozenset({'gangster'})), 'movie_info', 'title', 'cast_info', ('char_name', frozenset({'washington'}))]
# 6.698137253112519e-13
# [('title', frozenset({'gangster'})), ('movie_info', frozenset({'denzel'})), 'title', ('cast_info', frozenset({'washington'}))]
# 6.38231968905721e-13
# [('title', frozenset({'gangster'})), 'movie_info', ('title', frozenset({'washington'})), 'movie_info', 'title', 'cast_info', ('name', frozenset({'denzel'}))]
# 6.083824469757565e-13
# [('char_name', frozenset({'washington'})), ('cast_info', frozenset({'gangster'})), 'role_type', 'cast_info', 'char_name', 'cast_info', 'title', ('movie_info', frozenset({'denzel'}))]
# 5.193329942783409e-13
# [('char_name', frozenset({'washington'})), 'cast_info', ('name', frozenset({'denzel'})), 'cast_info', ('char_name', frozenset({'gangster'}))]
# 4.886796638230898e-13
# [('char_name', frozenset({'denzel'})), 'cast_info', ('char_name', frozenset({'gangster'})), 'cast_info', ('char_name', frozenset({'washington'}))]
# 4.4738884932173953e-13
# [('cast_info', frozenset({'denzel', 'washington'})), 'role_type', 'cast_info', 'char_name', 'cast_info', 'role_type', 'cast_info', 'title', ('movie_info', frozenset({'gangster'}))]
# 4.4738884932173953e-13
# [('cast_info', frozenset({'denzel'})), 'role_type', ('cast_info', frozenset({'washington'})), 'char_name', 'cast_info', 'role_type', 'cast_info', 'title', ('movie_info', frozenset({'gangster'}))]
# 4.3758171163552105e-13
# [('char_name', frozenset({'denzel'})), 'cast_info', ('char_name', frozenset({'gangster'})), 'cast_info', ('title', frozenset({'washington'}))]
# 3.9931072537087893e-13
# [('title', frozenset({'washington'})), ('movie_info', frozenset({'gangster'})), 'title', ('cast_info', frozenset({'denzel'}))]
# 3.5427138960646133e-13
# [('title', frozenset({'gangster'})), ('movie_info', frozenset({'denzel'})), ('title', frozenset({'washington'}))]
# 3.32164163632362e-13
# [('title', frozenset({'washington'})), 'movie_info', 'title', 'cast_info', ('name', frozenset({'denzel'})), 'cast_info', ('char_name', frozenset({'gangster'}))]
# 2.9673067733100413e-13
# [('char_name', frozenset({'washington'})), 'cast_info', ('title', frozenset({'gangster'})), ('movie_info', frozenset({'denzel'}))]
# 2.908448876657616e-13
# [('movie_info', frozenset({'washington'})), 'title', ('cast_info', frozenset({'gangster'})), ('name', frozenset({'denzel'}))]
# 2.54989308367205e-13
# [('title', frozenset({'gangster'})), 'movie_info', 'title', 'cast_info', ('name', frozenset({'denzel', 'washington'}))]
# 2.399387115092156e-13
# [('char_name', frozenset({'denzel'})), 'cast_info', ('name', frozenset({'washington'})), 'cast_info', ('title', frozenset({'gangster'}))]
# 2.2296982008897446e-13
# [('char_name', frozenset({'washington'})), ('cast_info', frozenset({'denzel'})), 'role_type', 'cast_info', 'char_name', 'cast_info', 'title', ('movie_info', frozenset({'gangster'}))]
# 2.2117953574728833e-13
# [('char_name', frozenset({'gangster'})), 'cast_info', ('name', frozenset({'denzel', 'washington'}))]
# 1.8213522026228928e-13
# [('title', frozenset({'gangster'})), 'movie_info', 'title', 'cast_info', ('name', frozenset({'washington'})), 'cast_info', ('name', frozenset({'denzel'}))]
# 1.743003537091342e-13
# [('char_name', frozenset({'gangster'})), ('cast_info', frozenset({'washington'})), 'role_type', 'cast_info', 'char_name', 'cast_info', 'title', ('movie_info', frozenset({'denzel'}))]
# 1.4266172069823337e-13
# [('title', frozenset({'gangster'})), ('cast_info', frozenset({'denzel'})), 'role_type', 'cast_info', 'char_name', 'cast_info', 'title', ('movie_info', frozenset({'washington'}))]
# 1.381893042667239e-13
# [('cast_info', frozenset({'gangster'})), ('name', frozenset({'washington'})), 'cast_info', 'role_type', 'cast_info', 'char_name', 'cast_info', 'title', ('movie_info', frozenset({'denzel'}))]
# 1.3683896795992222e-13
# [('char_name', frozenset({'denzel'})), ('cast_info', frozenset({'gangster'})), 'role_type', 'cast_info', 'char_name', 'cast_info', 'title', ('movie_info', frozenset({'washington'}))]
# 1.32707721448373e-13
# [('char_name', frozenset({'gangster'})), 'cast_info', ('name', frozenset({'washington'})), 'cast_info', ('name', frozenset({'denzel'}))]
# 1.2511732072100062e-13
# [('name', frozenset({'denzel'})), ('cast_info', frozenset({'washington'})), 'role_type', 'cast_info', 'char_name', 'cast_info', 'title', ('movie_info', frozenset({'gangster'}))]
# 1.2487472473077927e-13
# [('char_name', frozenset({'denzel'})), 'cast_info', ('name', frozenset({'washington'})), 'cast_info', ('char_name', frozenset({'gangster'}))]
# 1.1773234302847811e-13
# [('char_name', frozenset({'denzel'})), ('cast_info', frozenset({'washington'})), 'role_type', 'cast_info', 'char_name', 'cast_info', 'title', ('movie_info', frozenset({'gangster'}))]
# 1.1062710634435915e-13
# [('title', frozenset({'washington'})), ('movie_info', frozenset({'denzel'})), 'title', 'cast_info', ('char_name', frozenset({'gangster'}))]
# 9.340477626135962e-14
# [('char_name', frozenset({'denzel'})), 'cast_info', ('title', frozenset({'washington'})), ('movie_info', frozenset({'gangster'}))]
# 9.225308802462803e-14
# [('movie_info', frozenset({'denzel', 'washington'})), 'title', ('cast_info', frozenset({'gangster'}))]
# 7.941101007758924e-14
# [('title', frozenset({'washington'})), ('movie_info', frozenset({'gangster'})), 'title', 'cast_info', ('name', frozenset({'denzel'}))]
# 7.721588862800832e-14
# [('char_name', frozenset({'washington'})), 'cast_info', ('char_name', frozenset({'gangster'})), 'cast_info', 'role_type', 'cast_info', 'title', ('movie_info', frozenset({'denzel'}))]
# 7.424747340583668e-14
# [('char_name', frozenset({'gangster'})), ('cast_info', frozenset({'denzel'})), 'role_type', 'cast_info', 'char_name', 'cast_info', 'title', ('movie_info', frozenset({'washington'}))]
# 6.674143846500776e-14
# [('char_name', frozenset({'denzel'})), 'cast_info', ('title', frozenset({'gangster'})), ('movie_info', frozenset({'washington'}))]
# 6.066004279531638e-14
# [('title', frozenset({'gangster'})), ('movie_info', frozenset({'denzel'})), 'title', 'cast_info', ('name', frozenset({'washington'}))]
# 5.697657784458531e-14
# [('name', frozenset({'washington'})), ('cast_info', frozenset({'denzel'})), 'role_type', 'cast_info', 'char_name', 'cast_info', 'title', ('movie_info', frozenset({'gangster'}))]
# 5.674233432889318e-14
# [('title', frozenset({'gangster'})), ('movie_info', frozenset({'washington'})), 'title', 'cast_info', ('name', frozenset({'denzel'}))]
# 5.5427570263853663e-14
# [('char_name', frozenset({'washington'})), 'cast_info', ('name', frozenset({'denzel'})), 'cast_info', 'role_type', 'cast_info', 'title', ('movie_info', frozenset({'gangster'}))]
# 5.2155989897598444e-14
# [('char_name', frozenset({'denzel'})), 'cast_info', ('char_name', frozenset({'washington'})), 'cast_info', 'role_type', 'cast_info', 'title', ('movie_info', frozenset({'gangster'}))]
# 3.381040091106264e-14
# [('movie_info', frozenset({'gangster', 'washington'})), 'title', ('cast_info', frozenset({'denzel'}))]
# 3.3746438730482635e-14
# [('movie_info', frozenset({'denzel', 'washington'})), ('title', frozenset({'gangster'}))]
# 3.0751029341542673e-14
# [('movie_info', frozenset({'washington'})), 'title', ('cast_info', frozenset({'gangster'})), 'role_type', 'cast_info', 'char_name', 'cast_info', 'title', ('movie_info', frozenset({'denzel'}))]
# 2.3614104158775605e-14
# [('title', frozenset({'washington'})), ('movie_info', frozenset({'denzel'})), 'title', ('movie_info', frozenset({'gangster'}))]
# 1.973135686030046e-14
# [('char_name', frozenset({'gangster'})), 'cast_info', ('name', frozenset({'washington'})), 'cast_info', 'role_type', 'cast_info', 'title', ('movie_info', frozenset({'denzel'}))]
# 1.845701381233306e-14
# [('char_name', frozenset({'gangster'})), 'cast_info', ('name', frozenset({'denzel'})), 'cast_info', 'role_type', 'cast_info', 'title', ('movie_info', frozenset({'washington'}))]
# 1.7367599217381773e-14
# [('char_name', frozenset({'denzel'})), 'cast_info', ('char_name', frozenset({'gangster'})), 'cast_info', 'role_type', 'cast_info', 'title', ('movie_info', frozenset({'washington'}))]
# 1.6873219365241317e-14
# [('title', frozenset({'gangster'})), ('movie_info', frozenset({'denzel'})), 'title', ('movie_info', frozenset({'washington'}))]
# 1.4163680405780809e-14
# [('name', frozenset({'denzel', 'washington'})), 'cast_info', 'role_type', 'cast_info', 'char_name', 'cast_info', 'title', ('movie_info', frozenset({'gangster'}))]
# 1.4163680405780809e-14
# [('name', frozenset({'denzel'})), 'cast_info', ('name', frozenset({'washington'})), 'cast_info', 'role_type', 'cast_info', 'title', ('movie_info', frozenset({'gangster'}))]
# 1.3327677338915645e-14
# [('char_name', frozenset({'denzel'})), 'cast_info', ('name', frozenset({'washington'})), 'cast_info', 'role_type', 'cast_info', 'title', ('movie_info', frozenset({'gangster'}))]
# 1.1270133637020881e-14
# [('movie_info', frozenset({'washington'})), 'title', ('cast_info', frozenset({'denzel'})), 'role_type', 'cast_info', 'char_name', 'cast_info', 'title', ('movie_info', frozenset({'gangster'}))]
# 8.78157013640392e-15
# [('movie_info', frozenset({'denzel', 'washington'})), 'title', 'cast_info', ('char_name', frozenset({'gangster'}))]
# 6.303639113801935e-15
# [('movie_info', frozenset({'gangster', 'washington'})), 'title', 'cast_info', ('name', frozenset({'denzel'}))]
# 2.965785225407623e-15
# [('char_name', frozenset({'denzel'})), 'cast_info', 'role_type', 'cast_info', 'char_name', 'cast_info', 'title', ('movie_info', frozenset({'gangster', 'washington'}))]
# 2.801617383911971e-15
# [('movie_info', frozenset({'washington'})), 'title', 'cast_info', ('name', frozenset({'denzel'})), 'cast_info', 'role_type', 'cast_info', 'title', ('movie_info', frozenset({'gangster'}))]
# 1.9994512494555222e-15
# [('movie_info', frozenset({'denzel', 'washington'})), 'title', ('movie_info', frozenset({'gangster'}))]
# 1.9994512494555222e-15
# [('movie_info', frozenset({'gangster', 'washington'})), 'title', ('movie_info', frozenset({'denzel'}))]
# 1.646284076394518e-19
# [('movie_info', frozenset({'gangster', 'washington'})), 'title', ('cast_info', frozenset({'denzel', 'washington'}))]
# 3.4745973292998884e-21
# [('movie_info', frozenset({'gangster', 'washington'})), 'title', 'cast_info', ('name', frozenset({'denzel', 'washington'}))]
# 2.452500964575561e-22
# [('movie_info', frozenset({'denzel', 'washington'})), 'title', ('movie_info', frozenset({'gangster', 'washington'}))]

# %%
def getSQLfromCN(Gts,Cn):
    #print('CN:\n',Cn)
    
    tables = set()
    conditions=[]
    for i in range(len(Cn)):
        if(type(Cn[i]) is str):
            A = Cn[i]
        else:
            (A,keywords) = Cn[i]           
            
            #tratamento de keywords
            for term in keywords:
                attrA= [column_name for column_name in wordHash[term][A].keys()][0]
                condition = A + '.' + attrA + ' ILIKE \'%' + term + '%\''
                conditions.append(condition)
                
        tables.add(A)
        
        if(i<len(Cn)-1):
            if(type(Cn[i+1]) is str):
                B = Cn[i+1]
            else:
                B = Cn[i+1][0]
            
            edge_info = Gts[Cn[i]][Cn[i+1]]
            (direction,attrA,attrB) = edge_info
            
            condition = A + '.' + attrA + ' = ' + B + '.' + attrB         
            conditions.append(condition)
            
    #print('TABLES:\n',tables)
    #print('CONDITIONS:')
    #pp(conditions)
    
    sqlText = 'SELECT * FROM ' + ', '.join(tables)
    sqlText += ' WHERE ' + ' AND '.join(conditions)
    #print('SQL:\n',sql)
    return sqlText

# %%
# Connect to an existing database
conn = psycopg2.connect("dbname=imdb user=postgres")

# Open a cursor to perform database operations
cur = conn.cursor()

for (Cn,Gts,score) in RankedCns:
    if Cn is not None:
        sqlText = getSQLfromCN(Gts,Cn)
        cur.execute(sqlText)
        results = cur.fetchall()
        print(results)
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [(7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None, None, None, 43784946, 1023912, 'Washington, Denzel', None, None, 'W2523', 'D5242', None, 39927668, 327208, 31472, 15, "Frank Lucas: I don't care what you call it, put a choke-hold on the motherfucker and call it Blue Dog Shit.", None, 26096287), (7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None, None, None, 43784946, 1023912, 'Washington, Denzel', None, None, 'W2523', 'D5242', None, 39927668, 327207, 31472, 15, "Redtop: What's the matter? Ain't you niggas never seen naked coochie before?::Huey Lucas: Why they all naked?::Frank Lucas: So they can't steal nothin'.", None, 26096286), (7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None, None, None, 43784946, 1023912, 'Washington, Denzel', None, None, 'W2523', 'D5242', None, 39927668, 327206, 31472, 15, 'Frank Lucas: [Last line] Even a fool gets to be young once.', None, 26096285), (7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None, None, None, 43784946, 1023912, 'Washington, Denzel', None, None, 'W2523', 'D5242', None, 39927668, 327205, 31472, 15, "Bumpy Johnson: This is the problem. This is what's wrong with America. It's gotten so big, you just can't find your way. The grocery store on the corner is now a supermarket. The candy store is a MacDonald's. And this place, a super fucking discount store. Where's the pride of ownership? Where's the personal service? [Enters the store] See what I mean? Shit. I mean, what right do they have, of cutting out the suppliers? Pushing out all the middlemen. Buying direct from the manufacturer. Sony this. Toshiba that. All them Chinks putting Americans out of work. That's the way it is now. You can't find the heart of anything to stick the knife.", None, 26096284), (7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None, None, None, 43784946, 1023912, 'Washington, Denzel', None, None, 'W2523', 'D5242', None, 39927668, 327204, 31472, 15, "Detective Trupo: I got a better idea. Or, would you rather me throw you and your brother in the fuckin' river?::Frank Lucas: Or, would you rather your house blows up next time?", None, 26096283), (7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None, None, None, 43784946, 1023912, 'Washington, Denzel', None, None, 'W2523', 'D5242', None, 39927668, 327203, 31472, 15, '[last lines]::Prison Guard: Check your property. Sign, please.', None, 26096282), (7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None, None, None, 43784946, 1023912, 'Washington, Denzel', None, None, 'W2523', 'D5242', None, 39927668, 327202, 31472, 15, "[last title cards]::Title cards: Frank Lucas was convicted of Conspiracy to Distribute Narcotics and sentenced to 70 years.::Title cards: Federal authorities confiscated over 250 million dollars of Frank's assets in U.S. and foreign banks.::Title cards: Frank and Richie's collaboration led to the conviction of three quarters of New York City's Drug Enforcement Agency.::Title cards: Thirty members of Frank's family were convicted of drug trafficking and sent to prison.::Title cards: Frank's wife returned to Puerto Rico.::Title cards: His mother moved back to North Carolina.::Title cards: Richie Roberts quit the Prosecutor's Office to become a defense attorney.::Title cards: His first client was Frank Lucas.::Title cards: For his cooperation, Frank's prison sentence was reduced to 15 years. He was released in 1991.", None, 26096281), (7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None,  ...
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [(7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None, None, None, 43784946, 1023912, 'Washington, Denzel', None, None, 'W2523', 'D5242', None, 39927668, 327208, 31472, 15, "Frank Lucas: I don't care what you call it, put a choke-hold on the motherfucker and call it Blue Dog Shit.", None, 26096287), (7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None, None, None, 43784946, 1023912, 'Washington, Denzel', None, None, 'W2523', 'D5242', None, 39927668, 327207, 31472, 15, "Redtop: What's the matter? Ain't you niggas never seen naked coochie before?::Huey Lucas: Why they all naked?::Frank Lucas: So they can't steal nothin'.", None, 26096286), (7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None, None, None, 43784946, 1023912, 'Washington, Denzel', None, None, 'W2523', 'D5242', None, 39927668, 327206, 31472, 15, 'Frank Lucas: [Last line] Even a fool gets to be young once.', None, 26096285), (7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None, None, None, 43784946, 1023912, 'Washington, Denzel', None, None, 'W2523', 'D5242', None, 39927668, 327205, 31472, 15, "Bumpy Johnson: This is the problem. This is what's wrong with America. It's gotten so big, you just can't find your way. The grocery store on the corner is now a supermarket. The candy store is a MacDonald's. And this place, a super fucking discount store. Where's the pride of ownership? Where's the personal service? [Enters the store] See what I mean? Shit. I mean, what right do they have, of cutting out the suppliers? Pushing out all the middlemen. Buying direct from the manufacturer. Sony this. Toshiba that. All them Chinks putting Americans out of work. That's the way it is now. You can't find the heart of anything to stick the knife.", None, 26096284), (7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None, None, None, 43784946, 1023912, 'Washington, Denzel', None, None, 'W2523', 'D5242', None, 39927668, 327204, 31472, 15, "Detective Trupo: I got a better idea. Or, would you rather me throw you and your brother in the fuckin' river?::Frank Lucas: Or, would you rather your house blows up next time?", None, 26096283), (7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None, None, None, 43784946, 1023912, 'Washington, Denzel', None, None, 'W2523', 'D5242', None, 39927668, 327203, 31472, 15, '[last lines]::Prison Guard: Check your property. Sign, please.', None, 26096282), (7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None, None, None, 43784946, 1023912, 'Washington, Denzel', None, None, 'W2523', 'D5242', None, 39927668, 327202, 31472, 15, "[last title cards]::Title cards: Frank Lucas was convicted of Conspiracy to Distribute Narcotics and sentenced to 70 years.::Title cards: Federal authorities confiscated over 250 million dollars of Frank's assets in U.S. and foreign banks.::Title cards: Frank and Richie's collaboration led to the conviction of three quarters of New York City's Drug Enforcement Agency.::Title cards: Thirty members of Frank's family were convicted of drug trafficking and sent to prison.::Title cards: Frank's wife returned to Puerto Rico.::Title cards: His mother moved back to North Carolina.::Title cards: Richie Roberts quit the Prosecutor's Office to become a defense attorney.::Title cards: His first client was Frank Lucas.::Title cards: For his cooperation, Frank's prison sentence was reduced to 15 years. He was released in 1991.", None, 26096281), (7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None,  ...
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [(7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None, None, None, 43784946, 1023912, 'Washington, Denzel', None, None, 'W2523', 'D5242', None, 39927668, 327208, 31472, 15, "Frank Lucas: I don't care what you call it, put a choke-hold on the motherfucker and call it Blue Dog Shit.", None, 26096287), (7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None, None, None, 43784946, 1023912, 'Washington, Denzel', None, None, 'W2523', 'D5242', None, 39927668, 327207, 31472, 15, "Redtop: What's the matter? Ain't you niggas never seen naked coochie before?::Huey Lucas: Why they all naked?::Frank Lucas: So they can't steal nothin'.", None, 26096286), (7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None, None, None, 43784946, 1023912, 'Washington, Denzel', None, None, 'W2523', 'D5242', None, 39927668, 327206, 31472, 15, 'Frank Lucas: [Last line] Even a fool gets to be young once.', None, 26096285), (7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None, None, None, 43784946, 1023912, 'Washington, Denzel', None, None, 'W2523', 'D5242', None, 39927668, 327205, 31472, 15, "Bumpy Johnson: This is the problem. This is what's wrong with America. It's gotten so big, you just can't find your way. The grocery store on the corner is now a supermarket. The candy store is a MacDonald's. And this place, a super fucking discount store. Where's the pride of ownership? Where's the personal service? [Enters the store] See what I mean? Shit. I mean, what right do they have, of cutting out the suppliers? Pushing out all the middlemen. Buying direct from the manufacturer. Sony this. Toshiba that. All them Chinks putting Americans out of work. That's the way it is now. You can't find the heart of anything to stick the knife.", None, 26096284), (7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None, None, None, 43784946, 1023912, 'Washington, Denzel', None, None, 'W2523', 'D5242', None, 39927668, 327204, 31472, 15, "Detective Trupo: I got a better idea. Or, would you rather me throw you and your brother in the fuckin' river?::Frank Lucas: Or, would you rather your house blows up next time?", None, 26096283), (7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None, None, None, 43784946, 1023912, 'Washington, Denzel', None, None, 'W2523', 'D5242', None, 39927668, 327203, 31472, 15, '[last lines]::Prison Guard: Check your property. Sign, please.', None, 26096282), (7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None, None, None, 43784946, 1023912, 'Washington, Denzel', None, None, 'W2523', 'D5242', None, 39927668, 327202, 31472, 15, "[last title cards]::Title cards: Frank Lucas was convicted of Conspiracy to Distribute Narcotics and sentenced to 70 years.::Title cards: Federal authorities confiscated over 250 million dollars of Frank's assets in U.S. and foreign banks.::Title cards: Frank and Richie's collaboration led to the conviction of three quarters of New York City's Drug Enforcement Agency.::Title cards: Thirty members of Frank's family were convicted of drug trafficking and sent to prison.::Title cards: Frank's wife returned to Puerto Rico.::Title cards: His mother moved back to North Carolina.::Title cards: Richie Roberts quit the Prosecutor's Office to become a defense attorney.::Title cards: His first client was Frank Lucas.::Title cards: For his cooperation, Frank's prison sentence was reduced to 15 years. He was released in 1991.", None, 26096281), (7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None,  ...
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [(7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None, None, None, 43784946, 1023912, 'Washington, Denzel', None, None, 'W2523', 'D5242', None, 39927668, 327208, 31472, 15, "Frank Lucas: I don't care what you call it, put a choke-hold on the motherfucker and call it Blue Dog Shit.", None, 26096287), (7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None, None, None, 43784946, 1023912, 'Washington, Denzel', None, None, 'W2523', 'D5242', None, 39927668, 327207, 31472, 15, "Redtop: What's the matter? Ain't you niggas never seen naked coochie before?::Huey Lucas: Why they all naked?::Frank Lucas: So they can't steal nothin'.", None, 26096286), (7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None, None, None, 43784946, 1023912, 'Washington, Denzel', None, None, 'W2523', 'D5242', None, 39927668, 327206, 31472, 15, 'Frank Lucas: [Last line] Even a fool gets to be young once.', None, 26096285), (7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None, None, None, 43784946, 1023912, 'Washington, Denzel', None, None, 'W2523', 'D5242', None, 39927668, 327205, 31472, 15, "Bumpy Johnson: This is the problem. This is what's wrong with America. It's gotten so big, you just can't find your way. The grocery store on the corner is now a supermarket. The candy store is a MacDonald's. And this place, a super fucking discount store. Where's the pride of ownership? Where's the personal service? [Enters the store] See what I mean? Shit. I mean, what right do they have, of cutting out the suppliers? Pushing out all the middlemen. Buying direct from the manufacturer. Sony this. Toshiba that. All them Chinks putting Americans out of work. That's the way it is now. You can't find the heart of anything to stick the knife.", None, 26096284), (7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None, None, None, 43784946, 1023912, 'Washington, Denzel', None, None, 'W2523', 'D5242', None, 39927668, 327204, 31472, 15, "Detective Trupo: I got a better idea. Or, would you rather me throw you and your brother in the fuckin' river?::Frank Lucas: Or, would you rather your house blows up next time?", None, 26096283), (7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None, None, None, 43784946, 1023912, 'Washington, Denzel', None, None, 'W2523', 'D5242', None, 39927668, 327203, 31472, 15, '[last lines]::Prison Guard: Check your property. Sign, please.', None, 26096282), (7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None, None, None, 43784946, 1023912, 'Washington, Denzel', None, None, 'W2523', 'D5242', None, 39927668, 327202, 31472, 15, "[last title cards]::Title cards: Frank Lucas was convicted of Conspiracy to Distribute Narcotics and sentenced to 70 years.::Title cards: Federal authorities confiscated over 250 million dollars of Frank's assets in U.S. and foreign banks.::Title cards: Frank and Richie's collaboration led to the conviction of three quarters of New York City's Drug Enforcement Agency.::Title cards: Thirty members of Frank's family were convicted of drug trafficking and sent to prison.::Title cards: Frank's wife returned to Puerto Rico.::Title cards: His mother moved back to North Carolina.::Title cards: Richie Roberts quit the Prosecutor's Office to become a defense attorney.::Title cards: His first client was Frank Lucas.::Title cards: For his cooperation, Frank's prison sentence was reduced to 15 years. He was released in 1991.", None, 26096281), (7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None,  ...
# []
# []
# []
# [(7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None, None, None, 43784946, 1023912, 'Washington, Denzel', None, None, 'W2523', 'D5242', None, 39927668, 327208, 31472, 15, "Frank Lucas: I don't care what you call it, put a choke-hold on the motherfucker and call it Blue Dog Shit.", None, 26096287), (7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None, None, None, 43784946, 1023912, 'Washington, Denzel', None, None, 'W2523', 'D5242', None, 39927668, 327207, 31472, 15, "Redtop: What's the matter? Ain't you niggas never seen naked coochie before?::Huey Lucas: Why they all naked?::Frank Lucas: So they can't steal nothin'.", None, 26096286), (7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None, None, None, 43784946, 1023912, 'Washington, Denzel', None, None, 'W2523', 'D5242', None, 39927668, 327206, 31472, 15, 'Frank Lucas: [Last line] Even a fool gets to be young once.', None, 26096285), (7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None, None, None, 43784946, 1023912, 'Washington, Denzel', None, None, 'W2523', 'D5242', None, 39927668, 327205, 31472, 15, "Bumpy Johnson: This is the problem. This is what's wrong with America. It's gotten so big, you just can't find your way. The grocery store on the corner is now a supermarket. The candy store is a MacDonald's. And this place, a super fucking discount store. Where's the pride of ownership? Where's the personal service? [Enters the store] See what I mean? Shit. I mean, what right do they have, of cutting out the suppliers? Pushing out all the middlemen. Buying direct from the manufacturer. Sony this. Toshiba that. All them Chinks putting Americans out of work. That's the way it is now. You can't find the heart of anything to stick the knife.", None, 26096284), (7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None, None, None, 43784946, 1023912, 'Washington, Denzel', None, None, 'W2523', 'D5242', None, 39927668, 327204, 31472, 15, "Detective Trupo: I got a better idea. Or, would you rather me throw you and your brother in the fuckin' river?::Frank Lucas: Or, would you rather your house blows up next time?", None, 26096283), (7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None, None, None, 43784946, 1023912, 'Washington, Denzel', None, None, 'W2523', 'D5242', None, 39927668, 327203, 31472, 15, '[last lines]::Prison Guard: Check your property. Sign, please.', None, 26096282), (7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None, None, None, 43784946, 1023912, 'Washington, Denzel', None, None, 'W2523', 'D5242', None, 39927668, 327202, 31472, 15, "[last title cards]::Title cards: Frank Lucas was convicted of Conspiracy to Distribute Narcotics and sentenced to 70 years.::Title cards: Federal authorities confiscated over 250 million dollars of Frank's assets in U.S. and foreign banks.::Title cards: Frank and Richie's collaboration led to the conviction of three quarters of New York City's Drug Enforcement Agency.::Title cards: Thirty members of Frank's family were convicted of drug trafficking and sent to prison.::Title cards: Frank's wife returned to Puerto Rico.::Title cards: His mother moved back to North Carolina.::Title cards: Richie Roberts quit the Prosecutor's Office to become a defense attorney.::Title cards: His first client was Frank Lucas.::Title cards: For his cooperation, Frank's prison sentence was reduced to 15 years. He was released in 1991.", None, 26096281), (7425591, 1023912, 31472, 213404, None, 1, 1, 9871867, 31472, 'American Gangster', None, 1, 2007, None, 'A5625', None, None,  ...
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []

# %% [markdown]
# Tutorial
# http://www.nltk.org/howto/wordnet.html
# http://www.nltk.org/_modules/nltk/corpus/reader/wordnet.html

# %%
import nltk 
nltk.download('wordnet')
nltk.download('omw')
from nltk.corpus import wordnet as wn
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\pr3ma\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw to
# [nltk_data]     C:\Users\pr3ma\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw is already up-to-date!

# %%
pp(wordCount)
# Out:
# {'cast_info': {'__search_id': 812695,
#                'id': 812695,
#                'movie_id': 181706,
#                'note': 26395,
#                'nr_order': 332,
#                'person_id': 273034,
#                'person_role_id': 206953,
#                'role_id': 11},
#  'char_name': {'__search_id': 206952,
#                'id': 206952,
#                'imdb_id': 1,
#                'imdb_index': 1,
#                'name': 78110,
#                'name_pcode_nf': 17359,
#                'surname_pcode': 7423},
#  'movie_info': {'__search_id': 198678,
#                 'id': 198678,
#                 'info': 416236,
#                 'info_type_id': 1,
#                 'movie_id': 17553,
#                 'note': 1},
#  'name': {'__search_id': 273034,
#           'id': 273034,
#           'imdb_id': 1,
#           'imdb_index': 76,
#           'name': 107066,
#           'name_pcode_cf': 18183,
#           'name_pcode_nf': 16421,
#           'surname_pcode': 3751},
#  'role_type': {'__search_id': 11, 'id': 11, 'role': 13},
#  'title': {'__search_id': 181706,
#            'episode_nr': 1,
#            'episode_of_id': 1,
#            'id': 181706,
#            'imdb_id': 1,
#            'imdb_index': 14,
#            'kind_id': 1,
#            'phonetic_code': 18024,
#            'production_year': 123,
#            'season_nr': 1,
#            'series_years': 1,
#            'title': 79691}}

# %%
wn.synsets('movie')[0].wup_similarity(wn.synsets('film')[0])
# Out:
# 1.0

# %%
for syn in wn.synsets('note'):
    print(wn.synsets('movie')[0].wup_similarity(syn),syn)
# Out:
# 0.26666666666666666 Synset('note.n.01')
# 0.631578947368421 Synset('note.n.02')
# 0.26666666666666666 Synset('note.n.03')
# 0.2857142857142857 Synset('note.n.04')
# 0.3076923076923077 Synset('note.n.05')
# 0.25 Synset('bill.n.03')
# 0.2857142857142857 Synset('note.n.07')
# 0.2857142857142857 Synset('eminence.n.01')
# 0.3076923076923077 Synset('note.n.09')
# None Synset('note.v.01')
# None Synset('notice.v.02')
# None Synset('note.v.03')
# None Synset('note.v.04')

# %%
for syn in wn.synsets('paper'):
    print(wn.synsets('article')[0].wup_similarity(syn),syn)
# Out:
# 0.26666666666666666 Synset('paper.n.01')
# 0.4 Synset('composition.n.08')
# 0.5555555555555556 Synset('newspaper.n.01')
# 0.625 Synset('paper.n.04')
# 0.9411764705882353 Synset('paper.n.05')
# 0.2222222222222222 Synset('newspaper.n.02')
# 0.75 Synset('newspaper.n.03')
# None Synset('paper.v.01')
# None Synset('wallpaper.v.01')
