# %%
import gensim.models.keyedvectors as word2vec

model = word2vec.KeyedVectors.load_word2vec_format("GoogleNews-vectors-negative300.bin", binary=True, limit=500000)

# %%
model.most_similar('actor')
# Out:
# [('actress', 0.7930009961128235),
#  ('Actor', 0.7446157932281494),
#  ('thesp', 0.6954970955848694),
#  ('thespian', 0.6651668548583984),
#  ('actors', 0.651985228061676),
#  ('funnyman', 0.6352446675300598),
#  ('entertainer', 0.6184110641479492),
#  ('Shakespearean_actor', 0.6067742109298706),
#  ('ACTOR', 0.6015552878379822),
#  ('comedian', 0.5981959104537964)]

# %%
model.most_similar(positive=('casting'))
# Out:
# [('Casting', 0.7591177225112915),
#  ('cast', 0.7188456058502197),
#  ('casts', 0.6471916437149048),
#  ('casted', 0.6132380962371826),
#  ('Cast', 0.5140810608863831),
#  ('recasting', 0.430996298789978),
#  ('auditioning', 0.42711859941482544),
#  ('auditions', 0.41568922996520996),
#  ('actors', 0.41477301716804504),
#  ('audition', 0.4146764874458313)]

# %%
schemaWords = ['casting','note','name','character','movie','title','person','role']

# %%
import itertools
from pprint import pprint as pp

for i in range(1,5):
    for group in itertools.combinations(schemaWords,i):
        print ('Grupo:',group,'\n')
        pp(model.most_similar(positive=group))
        print('\n\n--------------------------------------------------\n')
# Out:
# Grupo: ('casting',)
#
# [('Casting', 0.7591177225112915),
#  ('cast', 0.7188456058502197),
#  ('casts', 0.6471916437149048),
#  ('casted', 0.6132380962371826),
#  ('Cast', 0.5140810608863831),
#  ('recasting', 0.430996298789978),
#  ('auditioning', 0.42711859941482544),
#  ('auditions', 0.41568922996520996),
#  ('actors', 0.41477301716804504),
#  ('audition', 0.4146764874458313)]
#
#
# --------------------------------------------------
#
# Grupo: ('note',)
#
# [('notes', 0.5398550629615784),
#  ('missive', 0.42899325489997864),
#  ('letter', 0.42833825945854187),
#  ('Glen_Yeung', 0.41627949476242065),
#  ('handwritten_note', 0.41346654295921326),
#  ('postscript', 0.4040994644165039),
#  ('cautionary_note', 0.395345002412796),
#  ('Sarah_Friar', 0.3902687430381775),
#  ('analyst_Charles_Grom', 0.3896912634372711),
#  ('Ladenburg_Thalmann_analyst', 0.38424739241600037)]
#
#
# --------------------------------------------------
#
# Grupo: ('name',)
#
# [('names', 0.7523384094238281),
#  ('surname', 0.707518994808197),
#  ('moniker', 0.6013294458389282),
#  ('Trajche_Shoposki', 0.5322816967964172),
#  ('monikers', 0.5309423208236694),
#  ('nickname', 0.5223192572593689),
#  ('pseudonym', 0.5128253698348999),
#  ('monicker', 0.5074477195739746),
#  ('Name', 0.5057128667831421),
#  ('prefix', 0.4961537718772888)]
#
#
# --------------------------------------------------
#
# Grupo: ('character',)
#
# [('characters', 0.7418640851974487),
#  ('protagonist', 0.6623691916465759),
#  ('titular_character', 0.6126604676246643),
#  ('villain', 0.5970299243927002),
#  ('storyline', 0.5787386894226074),
#  ('plotline', 0.5761162638664246),
#  ('persona', 0.5685874223709106),
#  ('baddie', 0.5633396506309509),
#  ('personality', 0.5617915391921997),
#  ('backstory', 0.5575405359268188)]
#
#
# --------------------------------------------------
#
# Grupo: ('movie',)
#
# [('film', 0.8676769733428955),
#  ('movies', 0.8013108968734741),
#  ('films', 0.7363011837005615),
#  ('Movie', 0.6693680286407471),
#  ('horror_flick', 0.6577848792076111),
#  ('sequel', 0.657779335975647),
#  ('romantic_comedy', 0.6413198709487915),
#  ('flick', 0.6321909427642822),
#  ('cinema', 0.6317482590675354),
#  ('cinematic_masterpiece', 0.6252104043960571)]
#
#
# --------------------------------------------------
#
# Grupo: ('title',)
#
# [('championship', 0.7559839487075806),
#  ('crown', 0.7454627752304077),
#  ('titles', 0.7106324434280396),
#  ('championships', 0.6048020720481873),
#  ('champs', 0.5829601287841797),
#  ('champ', 0.5804286003112793),
#  ('champion', 0.5731834173202515),
#  ('trophy', 0.5639244318008423),
#  ('wildcard_berth', 0.5511961579322815),
#  ('champions', 0.5460461378097534)]
#
#
# --------------------------------------------------
#
# Grupo: ('person',)
#
# [('someone', 0.6657356023788452),
#  ('persons', 0.555971086025238),
#  ('woman', 0.5470173358917236),
#  ('somebody', 0.5459041595458984),
#  ('man', 0.5342026352882385),
#  ('people', 0.5083408951759338),
#  ('anyone', 0.5061744451522827),
#  ('guy', 0.48752474784851074),
#  ('Someone', 0.4730055034160614),
#  ('individuals', 0.4702949523925781)]
#
#
# --------------------------------------------------
#
# Grupo: ('role',)
#
# [('roles', 0.7852944135665894),
#  ('Role', 0.5927175283432007),
#  ('responsibilities', 0.49574482440948486),
#  ('integral', 0.48947903513908386),
#  ('pivotal', 0.4714803695678711),
#  ('involvement', 0.44052404165267944),
#  ('position', 0.430732786655426),
#  ('responsibility', 0.42584094405174255),
#  ('importance', 0.41798222064971924),
#  ('part', 0.41617488861083984)]
#
#
# --------------------------------------------------
#
# Grupo: ('casting', 'note')
#
# [('cast', 0.5393756628036499),
#  ('Casting', 0.5140201449394226),
#  ('casts', 0.497677743434906),
#  ('casted', 0.4287041425704956),
#  ('script', 0.3696068227291107),
#  ('notes', 0.3639270067214966),
#  ('missive', 0.3444916009902954),
#  ('tempering', 0.3388231098651886),
#  ('cautionary_note', 0.33709055185317993),
#  ('playbill', 0.33232614398002625)]
#
#
# --------------------------------------------------
#
# Grupo: ('casting', 'name')
#
# [('names', 0.5968519449234009),
#  ('Casting', 0.546683669090271),
#  ('cast', 0.5418398380279541),
#  ('surname', 0.5140974521636963),
#  ('casts', 0.47989368438720703),
#  ('casted', 0.45668336749076843),
#  ('moniker', 0.45288100838661194),
#  ('Trajche_Shoposki', 0.447898805141449),
#  ('monikers', 0.43050843477249146),
#  ('misspelling', 0.4181230366230011)]
#
#
# --------------------------------------------------
#
# Grupo: ('casting', 'character')
#
# [('cast', 0.660529613494873),
#  ('characters', 0.6088700890541077),
#  ('Casting', 0.6029820442199707),
#  ('titular_character', 0.5752291679382324),
#  ('casts', 0.5539715886116028),
#  ('villain', 0.5520849227905273),
#  ('portrayer', 0.5467930436134338),
#  ('protagonist', 0.5355388522148132),
#  ('actors', 0.5281932950019836),
#  ('baddie', 0.5225268602371216)]
#
#
# --------------------------------------------------
#
# Grupo: ('casting', 'movie')
#
# [('film', 0.7331258058547974),
#  ('movies', 0.6145545244216919),
#  ('cast', 0.6144665479660034),
#  ('films', 0.606360673904419),
#  ('Casting', 0.5938749313354492),
#  ('actors', 0.5692892670631409),
#  ('Airbender', 0.5687995553016663),
#  ('Delgo', 0.5566776990890503),
#  ('sequel', 0.5557857751846313),
#  ('script', 0.5515174865722656)]
#
#
# --------------------------------------------------
#
# Grupo: ('casting', 'title')
#
# [('Casting', 0.5542905330657959),
#  ('cast', 0.5264673829078674),
#  ('championship', 0.5236630439758301),
#  ('crown', 0.5051985383033752),
#  ('casts', 0.4921882152557373),
#  ('titles', 0.4603423774242401),
#  ('casted', 0.45978134870529175),
#  ('berth', 0.448350191116333),
#  ('champ', 0.4194837212562561),
#  ('semifinal_berth', 0.41032445430755615)]
#
#
# --------------------------------------------------
#
# Grupo: ('casting', 'person')
#
# [('cast', 0.5566663146018982),
#  ('Casting', 0.5290605425834656),
#  ('casts', 0.4969034194946289),
#  ('someone', 0.4922488331794739),
#  ('casted', 0.46592584252357483),
#  ('elector', 0.4209398627281189),
#  ('actor', 0.41436049342155457),
#  ('persons', 0.41211938858032227),
#  ('man', 0.41093528270721436),
#  ('woman', 0.4099278450012207)]
#
#
# --------------------------------------------------
#
# Grupo: ('casting', 'role')
#
# [('roles', 0.6653963327407837),
#  ('cast', 0.597126841545105),
#  ('Casting', 0.567267119884491),
#  ('casts', 0.5575119256973267),
#  ('casted', 0.488302081823349),
#  ('character', 0.44233086705207825),
#  ('Role', 0.4403268098831177),
#  ('understudying', 0.4401196837425232),
#  ('acting', 0.43463748693466187),
#  ('reprising', 0.43211013078689575)]
#
#
# --------------------------------------------------
#
# Grupo: ('note', 'name')
#
# [('names', 0.5982219576835632),
#  ('surname', 0.5332237482070923),
#  ('letterhead', 0.4567159116268158),
#  ('Trajche_Shoposki', 0.4555274248123169),
#  ('moniker', 0.4458901584148407),
#  ('mailing_address', 0.42975783348083496),
#  ('salutation', 0.4269752502441406),
#  ('handwritten_note', 0.42646172642707825),
#  ('spelled_incorrectly', 0.4247095584869385),
#  ('letter', 0.42435336112976074)]
#
#
# --------------------------------------------------
#
# Grupo: ('note', 'character')
#
# [('characters', 0.5341649055480957),
#  ('plotline', 0.4658385217189789),
#  ('script', 0.4633232653141022),
#  ('protagonist', 0.4629674255847931),
#  ('backstory', 0.4526647627353668),
#  ('characterisations', 0.4524131715297699),
#  ('storyline', 0.44922658801078796),
#  ('personality_trait', 0.42893850803375244),
#  ('vignette', 0.42251330614089966),
#  ('epilogue', 0.42183685302734375)]
#
#
# --------------------------------------------------
#
# Grupo: ('note', 'movie')
#
# [('film', 0.6420325636863708),
#  ('movies', 0.5538216233253479),
#  ('films', 0.5256483554840088),
#  ('script', 0.514123797416687),
#  ('David_Mumpower', 0.49580851197242737),
#  ('Seven_Pounds', 0.49435195326805115),
#  ('horror_flick', 0.49384674429893494),
#  ('Reagen_Sulewski', 0.4867483377456665),
#  ('sequel', 0.486619234085083),
#  ('Cop_Out', 0.4806899428367615)]
#
#
# --------------------------------------------------
#
# Grupo: ('note', 'title')
#
# [('crown', 0.5547052621841431),
#  ('championship', 0.5111450552940369),
#  ('titles', 0.5019819140434265),
#  ('trophy', 0.4503614902496338),
#  ('champs', 0.40436434745788574),
#  ('notes', 0.4040616452693939),
#  ('berth', 0.3977443277835846),
#  ('champ', 0.39773043990135193),
#  ('wildcard_berth', 0.3970046043395996),
#  ('Titles', 0.3774920105934143)]
#
#
# --------------------------------------------------
#
# Grupo: ('note', 'person')
# [('someone', 0.48984411358833313),
#  ('paragraph', 0.41593867540359497),
#  ('handwritten_note', 0.41318443417549133),
#  ('woman', 0.40731576085090637),
#  ('persons', 0.4059554636478424),
#  ('Someone', 0.3855779767036438),
#  ('somebody', 0.38185393810272217),
#  ('notes', 0.37928712368011475),
#  ('man', 0.3758845031261444),
#  ('one', 0.3757374882698059)]
#
#
# --------------------------------------------------
#
# Grupo: ('note', 'role')
#
# [('roles', 0.5666378736495972),
#  ('Role', 0.4394497573375702),
#  ('notes', 0.43172675371170044),
#  ('responsibilities', 0.3875700831413269),
#  ('aspect', 0.37042859196662903),
#  ('position', 0.3688497245311737),
#  ('importance', 0.3650900423526764),
#  ('stance', 0.35468435287475586),
#  ('part', 0.3531661927700043),
#  ('responsbility', 0.35314005613327026)]
#
#
# --------------------------------------------------
#
# Grupo: ('name', 'character')
#
# [('surname', 0.6221413016319275),
#  ('characters', 0.5752592086791992),
#  ('persona', 0.5731670260429382),
#  ('names', 0.5700072050094604),
#  ('Trajche_Shoposki', 0.5304112434387207),
#  ('identity', 0.5216857194900513),
#  ('protagonist', 0.5152552127838135),
#  ('villain', 0.5063074231147766),
#  ('moniker', 0.5056437253952026),
#  ('alter_ego', 0.4929381310939789)]
#
#
# --------------------------------------------------
#
# Grupo: ('name', 'movie')
#
# [('film', 0.6221790313720703),
#  ('movies', 0.561027467250824),
#  ('names', 0.5435632467269897),
#  ('surname', 0.5370115041732788),
#  ('Trajche_Shoposki', 0.5334352850914001),
#  ('films', 0.5272806882858276),
#  ('script', 0.524247944355011),
#  ('logline', 0.4981757402420044),
#  ('Viva_Zapata', 0.49600327014923096),
#  ('remake', 0.4917899966239929)]
#
#
# --------------------------------------------------
#
# Grupo: ('name', 'title')
#
# [('moniker', 0.5920394659042358),
#  ('surname', 0.5799334049224854),
#  ('titles', 0.5563105344772339),
#  ('names', 0.5559274554252625),
#  ('crown', 0.5459425449371338),
#  ('championship', 0.5182859301567078),
#  ('monicker', 0.49657633900642395),
#  ('trophy', 0.48264995217323303),
#  ('nickname', 0.46550458669662476),
#  ('Trajche_Shoposki', 0.4646056294441223)]
#
#
# --------------------------------------------------
#
# Grupo: ('name', 'person')
#
# [('surname', 0.5753118991851807),
#  ('someone', 0.5717558860778809),
#  ('names', 0.5564701557159424),
#  ('Trajche_Shoposki', 0.5368983745574951),
#  ('somebody', 0.4845631420612335),
#  ('man', 0.45889022946357727),
#  ('Name', 0.4464479684829712),
#  ('woman', 0.4454748034477234),
#  ('Heleno_Santiago', 0.44364210963249207),
#  ('foreigner', 0.44007155299186707)]
#
#
# --------------------------------------------------
#
# Grupo: ('name', 'role')
#
# [('roles', 0.6232286691665649),
#  ('names', 0.549583911895752),
#  ('surname', 0.5453311800956726),
#  ('moniker', 0.4954169690608978),
#  ('identity', 0.47571462392807007),
#  ('nickname', 0.43072640895843506),
#  ('responsibilities', 0.42789798974990845),
#  ('monikers', 0.4235251247882843),
#  ('Role', 0.42313504219055176),
#  ('character', 0.4220602512359619)]
#
#
# --------------------------------------------------
#
# Grupo: ('character', 'movie')
#
# [('film', 0.7266330718994141),
#  ('characters', 0.6871206760406494),
#  ('titular_character', 0.6491507887840271),
#  ('movies', 0.6449548602104187),
#  ('plotline', 0.6440069675445557),
#  ('script', 0.6204060316085815),
#  ('protagonist', 0.6203953623771667),
#  ('storyline', 0.6097860336303711),
#  ('cinematic_masterpiece', 0.6086910367012024),
#  ('sequel', 0.6080073118209839)]
#
#
# --------------------------------------------------
#
# Grupo: ('character', 'title')
#
# [('championship', 0.5816818475723267),
#  ('characters', 0.5715208649635315),
#  ('protagonist', 0.5394308567047119),
#  ('titles', 0.5369733572006226),
#  ('storyline', 0.5255408883094788),
#  ('crown', 0.5245215892791748),
#  ('titular_character', 0.5073556900024414),
#  ('villain', 0.5050582885742188),
#  ('plotline', 0.4888891875743866),
#  ('Character', 0.47720611095428467)]
#
#
# --------------------------------------------------
#
# Grupo: ('character', 'person')
#
# [('characters', 0.5870844125747681),
#  ('guy', 0.5555888414382935),
#  ('someone', 0.553566575050354),
#  ('protagonist', 0.5511038303375244),
#  ('personality', 0.5283448696136475),
#  ('villain', 0.5076612830162048),
#  ('somebody', 0.4984813630580902),
#  ('titular_character', 0.4822596311569214),
#  ('sociopath', 0.47397178411483765),
#  ('persona', 0.47304975986480713)]
#
#
# --------------------------------------------------
#
# Grupo: ('character', 'role')
#
# [('roles', 0.7000941634178162),
#  ('characters', 0.5707764625549316),
#  ('villain', 0.5707404613494873),
#  ('titular_character', 0.567203164100647),
#  ('protagonist', 0.5606520175933838),
#  ('baddie', 0.5292767286300659),
#  ('portrayer', 0.5214349031448364),
#  ('villainous', 0.515144407749176),
#  ('persona', 0.509145975112915),
#  ('Role', 0.501121461391449)]
#
#
# --------------------------------------------------
#
# Grupo: ('movie', 'title')
#
# [('film', 0.6736919283866882),
#  ('sequel', 0.6112103462219238),
#  ('movies', 0.5830607414245605),
#  ('titles', 0.5794307589530945),
#  ('films', 0.5596634149551392),
#  ('championship', 0.5591725707054138),
#  ('cinematic_masterpiece', 0.5438553690910339),
#  ('trilogy', 0.5394961833953857),
#  ('threequel', 0.5319578647613525),
#  ('Monsters_Vs', 0.5246365070343018)]
#
#
# --------------------------------------------------
#
# Grupo: ('movie', 'person')
#
# [('film', 0.6424682140350342),
#  ('movies', 0.6022673845291138),
#  ('moviegoer', 0.602100133895874),
#  ('films', 0.5415844917297363),
#  ('filmgoer', 0.5406589508056641),
#  ('someone', 0.5386119484901428),
#  ('popcorn_flick', 0.5253717303276062),
#  ('actor', 0.5106126666069031),
#  ('TeenHollywood', 0.5011229515075684),
#  ('romantic_comedy', 0.4998820126056671)]
#
#
# --------------------------------------------------
#
# Grupo: ('movie', 'role')
#
# [('film', 0.6829584240913391),
#  ('roles', 0.6352157592773438),
#  ('movies', 0.5803917050361633),
#  ('films', 0.5531153082847595),
#  ('titular_character', 0.5421246886253357),
#  ('character', 0.5397065281867981),
#  ('Ankahee', 0.5327735543251038),
#  ('sequel', 0.5229427218437195),
#  ('starring', 0.5172219276428223),
#  ('actor', 0.5170497298240662)]
#
#
# --------------------------------------------------
#
# Grupo: ('title', 'person')
#
# [('someone', 0.5491297245025635),
#  ('championship', 0.5409395694732666),
#  ('crown', 0.4984074532985687),
#  ('titles', 0.47867608070373535),
#  ('woman', 0.4610951244831085),
#  ('man', 0.45096859335899353),
#  ('somebody', 0.44796043634414673),
#  ('champion', 0.4462374448776245),
#  ('champ', 0.4456804096698761),
#  ('anyone', 0.43498486280441284)]
#
#
# --------------------------------------------------
#
# Grupo: ('title', 'role')
#
# [('roles', 0.6242059469223022),
#  ('crown', 0.557850182056427),
#  ('championship', 0.5324891209602356),
#  ('titles', 0.4940817952156067),
#  ('Role', 0.4620438516139984),
#  ('berth', 0.46141940355300903),
#  ('position', 0.4393320381641388),
#  ('trophy', 0.4194621443748474),
#  ('responsibilities', 0.41252046823501587),
#  ('mantle', 0.4119274318218231)]
#
#
# --------------------------------------------------
#
# Grupo: ('person', 'role')
#
# [('roles', 0.5496236681938171),
#  ('someone', 0.4965687394142151),
#  ('character', 0.4664517939090729),
#  ('gatekeeper', 0.43853873014450073),
#  ('participant', 0.4239843487739563),
#  ('guy', 0.4222643971443176),
#  ('somebody', 0.4217129945755005),
#  ('responsibilities', 0.4060300886631012),
#  ('citizen', 0.3998528718948364),
#  ('aspect', 0.3997478187084198)]
#
#
# --------------------------------------------------
#
# Grupo: ('casting', 'note', 'name')
#
# [('names', 0.56130051612854),
#  ('surname', 0.466060072183609),
#  ('cast', 0.4491136074066162),
#  ('Trajche_Shoposki', 0.4441039562225342),
#  ('misspelling', 0.43137112259864807),
#  ('Your_thestate.com', 0.4285377264022827),
#  ('misspell', 0.41422969102859497),
#  ('Casting', 0.4121630787849426),
#  ('misspelled', 0.411518931388855),
#  ('casts', 0.4070754647254944)]
#
#
# --------------------------------------------------
#
# Grupo: ('casting', 'note', 'character')
#
# [('cast', 0.5768258571624756),
#  ('characters', 0.5309369564056396),
#  ('script', 0.5237970948219299),
#  ('casts', 0.49362897872924805),
#  ('Casting', 0.4880882501602173),
#  ('characterisations', 0.48481646180152893),
#  ('plotline', 0.48074373602867126),
#  ('titular_character', 0.4795086681842804),
#  ('villain', 0.47037559747695923),
#  ('portrayer', 0.4656984210014343)]
#
#
# --------------------------------------------------
#
# Grupo: ('casting', 'note', 'movie')
#
# [('film', 0.655160665512085),
#  ('script', 0.5614087581634521),
#  ('cast', 0.5320116877555847),
#  ('films', 0.5280797481536865),
#  ('movies', 0.5226930379867554),
#  ('Reagen_Sulewski', 0.52024906873703),
#  ('David_Mumpower', 0.5034319162368774),
#  ('What_Your_Raashee', 0.4996732771396637),
#  ('sequel', 0.4966026842594147),
#  ('Dragonball_Evolution', 0.4907579720020294)]
#
#
# --------------------------------------------------
#
# Grupo: ('casting', 'note', 'title')
# [('crown', 0.44602593779563904),
#  ('cast', 0.4450969696044922),
#  ('casts', 0.42504000663757324),
#  ('Casting', 0.4248015880584717),
#  ('championship', 0.4189915657043457),
#  ('berth', 0.38622409105300903),
#  ('titles', 0.3857341408729553),
#  ('script', 0.38204026222229004),
#  ('finale', 0.37493765354156494),
#  ('trophy', 0.3637092113494873)]
#
#
# --------------------------------------------------
#
# Grupo: ('casting', 'note', 'person')
#
# [('cast', 0.4736325442790985),
#  ('casts', 0.4321720004081726),
#  ('someone', 0.43205392360687256),
#  ('Casting', 0.40929460525512695),
#  ('juror', 0.37266185879707336),
#  ('casted', 0.37258487939834595),
#  ('auditioner', 0.3717232942581177),
#  ('one', 0.3698652386665344),
#  ('paragraph', 0.3660961091518402),
#  ('script', 0.3653813600540161)]
#
#
# --------------------------------------------------
#
# Grupo: ('casting', 'note', 'role')
#
# [('roles', 0.5771487951278687),
#  ('cast', 0.510445773601532),
#  ('casts', 0.4850027561187744),
#  ('Casting', 0.44535720348358154),
#  ('casted', 0.3946385979652405),
#  ('Role', 0.3936803936958313),
#  ('acting', 0.38944563269615173),
#  ('character', 0.384879469871521),
#  ('understudying', 0.3819642663002014),
#  ('reprising', 0.3688838481903076)]
#
#
# --------------------------------------------------
#
# Grupo: ('casting', 'name', 'character')
#
# [('characters', 0.5550800561904907),
#  ('cast', 0.5533502101898193),
#  ('villain', 0.5282328724861145),
#  ('titular_character', 0.5232657790184021),
#  ('portrayer', 0.5130000114440918),
#  ('persona', 0.5128002166748047),
#  ('surname', 0.5015840530395508),
#  ('names', 0.4991327226161957),
#  ('Casting', 0.4925280809402466),
#  ('protagonist', 0.4905620515346527)]
#
#
# --------------------------------------------------
#
# Grupo: ('casting', 'name', 'movie')
#
# [('film', 0.6197350025177002),
#  ('script', 0.551072359085083),
#  ('cast', 0.5397018194198608),
#  ('starcast', 0.5126488208770752),
#  ('films', 0.5125904679298401),
#  ('movies', 0.5115570425987244),
#  ('IMDB', 0.5077738165855408),
#  ('Casting', 0.5063453912734985),
#  ('remake', 0.5021181106567383),
#  ('Scorcese', 0.5014671087265015)]
#
#
# --------------------------------------------------
#
# Grupo: ('casting', 'name', 'title')
#
# [('names', 0.520639181137085),
#  ('moniker', 0.5178282260894775),
#  ('surname', 0.49969449639320374),
#  ('Trajche_Shoposki', 0.4462616741657257),
#  ('identity', 0.4410058557987213),
#  ('Casting', 0.44011515378952026),
#  ('monicker', 0.4378248453140259),
#  ('cast', 0.436626672744751),
#  ('crown', 0.4328608512878418),
#  ('titles', 0.4259687066078186)]
#
#
# --------------------------------------------------
#
# Grupo: ('casting', 'name', 'person')
#
# [('names', 0.5092921257019043),
#  ('Trajche_Shoposki', 0.49376076459884644),
#  ('someone', 0.48894399404525757),
#  ('surname', 0.4845564067363739),
#  ('cast', 0.46648672223091125),
#  ('Casting', 0.4284161329269409),
#  ('Your_thestate.com', 0.4214000105857849),
#  ('character', 0.418548047542572),
#  ('Heleno_Santiago', 0.4177556037902832),
#  ('elector', 0.41361838579177856)]
#
#
# --------------------------------------------------
#
# Grupo: ('casting', 'name', 'role')
#
# [('roles', 0.6050370931625366),
#  ('cast', 0.5085958242416382),
#  ('names', 0.4899309277534485),
#  ('character', 0.47298869490623474),
#  ('Casting', 0.4684598445892334),
#  ('casts', 0.46755242347717285),
#  ('surname', 0.44748443365097046),
#  ('identity', 0.4313746690750122),
#  ('villain', 0.42986220121383667),
#  ('portrayer', 0.42237770557403564)]
#
#
# --------------------------------------------------
#
# Grupo: ('casting', 'character', 'movie')
#
# [('film', 0.6870578527450562),
#  ('titular_character', 0.6263443231582642),
#  ('characters', 0.6213279962539673),
#  ('script', 0.6106767058372498),
#  ('actors', 0.6038362979888916),
#  ('actor', 0.5994576215744019),
#  ('cast', 0.595592200756073),
#  ('plotline', 0.5904362201690674),
#  ('movies', 0.5698577165603638),
#  ('villain', 0.5691315531730652)]
#
#
# --------------------------------------------------
#
# Grupo: ('casting', 'character', 'title')
#
# [('characters', 0.5590018630027771),
#  ('titular_character', 0.5469440817832947),
#  ('cast', 0.5459893941879272),
#  ('villain', 0.5344260931015015),
#  ('protagonist', 0.515129029750824),
#  ('portrayer', 0.5065746307373047),
#  ('storyline', 0.5023236870765686),
#  ('Casting', 0.4996508061885834),
#  ('plotline', 0.4968666434288025),
#  ('baddie', 0.4935586750507355)]
#
#
# --------------------------------------------------
#
# Grupo: ('casting', 'character', 'person')
#
# [('characters', 0.5634799003601074),
#  ('cast', 0.5614938735961914),
#  ('villain', 0.5283385515213013),
#  ('actor', 0.5234890580177307),
#  ('titular_character', 0.5192124843597412),
#  ('protagonist', 0.5175052881240845),
#  ('portrayer', 0.49303627014160156),
#  ('actors', 0.49045807123184204),
#  ('guy', 0.47846806049346924),
#  ('Casting', 0.4780721664428711)]
#
#
# --------------------------------------------------
#
# Grupo: ('casting', 'character', 'role')
#
# [('roles', 0.6475468873977661),
#  ('cast', 0.5801510810852051),
#  ('titular_character', 0.5767202377319336),
#  ('villain', 0.5695520043373108),
#  ('portrayer', 0.5506089329719543),
#  ('characters', 0.5450093150138855),
#  ('baddie', 0.5315037965774536),
#  ('protagonist', 0.519708514213562),
#  ('villainous', 0.5160050988197327),
#  ('casts', 0.506459653377533)]
#
#
# --------------------------------------------------
#
# Grupo: ('casting', 'movie', 'title')
#
# [('film', 0.6725568771362305),
#  ('sequel', 0.5863485932350159),
#  ('films', 0.5487337112426758),
#  ('movies', 0.5404466390609741),
#  ('remake', 0.5314152240753174),
#  ('Killshot', 0.5296019315719604),
#  ('script', 0.5293183326721191),
#  ('threequel', 0.523321270942688),
#  ('Monsters_Vs', 0.5214528441429138),
#  ('Airbender', 0.5210990905761719)]
#
#
# --------------------------------------------------
#
# Grupo: ('casting', 'movie', 'person')
#
# [('film', 0.6395413875579834),
#  ('actor', 0.5533715486526489),
#  ('movies', 0.5483651161193848),
#  ('moviegoer', 0.5414559841156006),
#  ('cast', 0.5345058441162109),
#  ('actors', 0.5304466485977173),
#  ('films', 0.5276187658309937),
#  ('Reagen_Sulewski', 0.509952187538147),
#  ('script', 0.5044742226600647),
#  ('Scorcese', 0.5036112666130066)]
#
#
# --------------------------------------------------
#
# Grupo: ('casting', 'movie', 'role')
#
# [('film', 0.650625467300415),
#  ('roles', 0.5805095434188843),
#  ('cast', 0.5802339315414429),
#  ('actors', 0.5507931709289551),
#  ('titular_character', 0.5453794002532959),
#  ('actor', 0.5433568954467773),
#  ('character', 0.5333825945854187),
#  ('Casting', 0.5222331881523132),
#  ('films', 0.5205361247062683),
#  ('movies', 0.5153113603591919)]
#
#
# --------------------------------------------------
#
# Grupo: ('casting', 'title', 'person')
#
# [('cast', 0.4745214581489563),
#  ('someone', 0.4684743583202362),
#  ('Casting', 0.4516468942165375),
#  ('casts', 0.4380608797073364),
#  ('championship', 0.4218398928642273),
#  ('character', 0.4206235408782959),
#  ('elector', 0.40779411792755127),
#  ('casted', 0.40587061643600464),
#  ('actor', 0.39871641993522644),
#  ('woman', 0.3971889615058899)]
#
#
# --------------------------------------------------
#
# Grupo: ('casting', 'title', 'role')
#
# [('roles', 0.6160410642623901),
#  ('cast', 0.49495741724967957),
#  ('casts', 0.47498518228530884),
#  ('Casting', 0.4708307683467865),
#  ('character', 0.45629221200942993),
#  ('reprise', 0.4425908029079437),
#  ('reprising', 0.4357553720474243),
#  ('villain', 0.42935997247695923),
#  ('crown', 0.4258885383605957),
#  ('titular_character', 0.42312562465667725)]
#
#
# --------------------------------------------------
#
# Grupo: ('casting', 'person', 'role')
#
# [('cast', 0.5398449301719666),
#  ('roles', 0.5396671295166016),
#  ('character', 0.5014902949333191),
#  ('casts', 0.4988188147544861),
#  ('Casting', 0.4731600284576416),
#  ('actor', 0.4540867805480957),
#  ('villain', 0.4494667649269104),
#  ('casted', 0.43649786710739136),
#  ('actors', 0.42099887132644653),
#  ('titular_character', 0.42008310556411743)]
#
#
# --------------------------------------------------
#
# Grupo: ('note', 'name', 'character')
#
# [('surname', 0.5516179800033569),
#  ('names', 0.537169873714447),
#  ('Trajche_Shoposki', 0.5069935917854309),
#  ('characters', 0.4753226935863495),
#  ('Your_thestate.com', 0.4708983898162842),
#  ('persona', 0.44660520553588867),
#  ('moniker', 0.4446341395378113),
#  ('script', 0.44276928901672363),
#  ('Heleno_Santiago', 0.4357347786426544),
#  ('locution', 0.42867469787597656)]
#
#
# --------------------------------------------------
#
# Grupo: ('note', 'name', 'movie')
# [('film', 0.5201395750045776),
#  ('script', 0.5038039684295654),
#  ('names', 0.5019465684890747),
#  ('Trajche_Shoposki', 0.495784193277359),
#  ('Your_thestate.com', 0.475396990776062),
#  ('logline', 0.47045308351516724),
#  ('surname', 0.46859633922576904),
#  ('Heleno_Santiago', 0.46779778599739075),
#  ('movies', 0.4397630989551544),
#  ('Internet_Movie_Database', 0.43340229988098145)]
#
#
# --------------------------------------------------
#
# Grupo: ('note', 'name', 'title')
#
# [('names', 0.5206292867660522),
#  ('surname', 0.5121750831604004),
#  ('moniker', 0.5082496404647827),
#  ('crown', 0.46472442150115967),
#  ('titles', 0.45156562328338623),
#  ('Trajche_Shoposki', 0.4498443305492401),
#  ('letterhead', 0.4303419589996338),
#  ('trophy', 0.4295787811279297),
#  ('Heleno_Santiago', 0.4230339229106903),
#  ('monicker', 0.41911691427230835)]
#
#
# --------------------------------------------------
#
# Grupo: ('note', 'name', 'person')
#
# [('names', 0.519322395324707),
#  ('surname', 0.5067103505134583),
#  ('Trajche_Shoposki', 0.5054787993431091),
#  ('someone', 0.477470338344574),
#  ('Heleno_Santiago', 0.45523935556411743),
#  ('phrase', 0.4285416007041931),
#  ('handwritten_note', 0.4274780750274658),
#  ('Your_thestate.com', 0.4261866807937622),
#  ('letterhead', 0.4242627024650574),
#  ('word', 0.42276495695114136)]
#
#
# --------------------------------------------------
#
# Grupo: ('note', 'name', 'role')
#
# [('roles', 0.5127636194229126),
#  ('names', 0.5100733041763306),
#  ('surname', 0.4791066646575928),
#  ('moniker', 0.4264811873435974),
#  ('Trajche_Shoposki', 0.4060494005680084),
#  ('monikers', 0.3874967694282532),
#  ('Your_thestate.com', 0.38545796275138855),
#  ('position', 0.3818303942680359),
#  ('responsibilities', 0.37318000197410583),
#  ('stance', 0.367681086063385)]
#
#
# --------------------------------------------------
#
# Grupo: ('note', 'character', 'movie')
#
# [('film', 0.6443769931793213),
#  ('script', 0.6117738485336304),
#  ('characters', 0.5870466232299805),
#  ('plotline', 0.584492027759552),
#  ('movies', 0.5447908639907837),
#  ('storyline', 0.5427588224411011),
#  ('sequel', 0.5361468195915222),
#  ('cinematic_masterpiece', 0.5359851121902466),
#  ('titular_character', 0.533865213394165),
#  ('screenplay', 0.5330581665039062)]
#
#
# --------------------------------------------------
#
# Grupo: ('note', 'character', 'title')
#
# [('characters', 0.4811241924762726),
#  ('championship', 0.4693339169025421),
#  ('storyline', 0.4651389718055725),
#  ('crown', 0.461674302816391),
#  ('titles', 0.44969165325164795),
#  ('plotline', 0.449190616607666),
#  ('protagonist', 0.4427880048751831),
#  ('backstory', 0.4365267753601074),
#  ('script', 0.4356837868690491),
#  ('epilogue', 0.41877663135528564)]
#
#
# --------------------------------------------------
#
# Grupo: ('note', 'character', 'person')
#
# [('characters', 0.4971274733543396),
#  ('someone', 0.4820541739463806),
#  ('guy', 0.48110058903694153),
#  ('personality_trait', 0.45997118949890137),
#  ('protagonist', 0.4556688666343689),
#  ('personality', 0.43742620944976807),
#  ('thing', 0.4231759309768677),
#  ('script', 0.42018669843673706),
#  ('villain', 0.41967594623565674),
#  ('somebody', 0.4170106053352356)]
#
#
# --------------------------------------------------
#
# Grupo: ('note', 'character', 'role')
#
# [('roles', 0.6070564985275269),
#  ('characters', 0.48806053400039673),
#  ('villain', 0.4763738512992859),
#  ('protagonist', 0.4682047367095947),
#  ('titular_character', 0.46352314949035645),
#  ('portrayal', 0.4520057439804077),
#  ('baddie', 0.44888728857040405),
#  ('villainous', 0.44491884112358093),
#  ('Role', 0.44413048028945923),
#  ('backstory', 0.4379142224788666)]
#
#
# --------------------------------------------------
#
# Grupo: ('note', 'movie', 'title')
#
# [('film', 0.5791440606117249),
#  ('sequel', 0.5193576216697693),
#  ('script', 0.48448267579078674),
#  ('Run_Fatboy_Run', 0.48126259446144104),
#  ('What_Your_Raashee', 0.4788736402988434),
#  ('titles', 0.4745231866836548),
#  ('movies', 0.4731171727180481),
#  ('films', 0.46690669655799866),
#  ('Movie_Prizes', 0.4654872417449951),
#  ('cinematic_masterpiece', 0.46469128131866455)]
#
#
# --------------------------------------------------
#
# Grupo: ('note', 'movie', 'person')
#
# [('film', 0.557621955871582),
#  ('moviegoer', 0.5173299908638),
#  ('movies', 0.4924158453941345),
#  ('logline', 0.4767740070819855),
#  ('Seven_Pounds', 0.46966660022735596),
#  ('script', 0.46811985969543457),
#  ('Reagen_Sulewski', 0.46438562870025635),
#  ('David_Mumpower', 0.461142897605896),
#  ('someone', 0.46099579334259033),
#  ('filmgoer', 0.45833277702331543)]
#
#
# --------------------------------------------------
#
# Grupo: ('note', 'movie', 'role')
#
# [('film', 0.5816856622695923),
#  ('roles', 0.530049741268158),
#  ('Best_Friend_Wedding', 0.47366729378700256),
#  ('movies', 0.46694472432136536),
#  ('Ankahee', 0.4622088372707367),
#  ('films', 0.457772821187973),
#  ('Run_Fatboy_Run', 0.45695769786834717),
#  ('script', 0.4531477391719818),
#  ('Igby_Goes_Down', 0.4526124596595764),
#  ('character', 0.4466925263404846)]
#
#
# --------------------------------------------------
#
# Grupo: ('note', 'title', 'person')
#
# [('someone', 0.45960232615470886),
#  ('crown', 0.4261440634727478),
#  ('championship', 0.41886579990386963),
#  ('paragraph', 0.3964042663574219),
#  ('woman', 0.38929760456085205),
#  ('titles', 0.38754338026046753),
#  ("STEFEK_'S_LTD", 0.3773645758628845),
#  ('it', 0.375610888004303),
#  ('trophy', 0.37528496980667114),
#  ('Heleno_Santiago', 0.3735337257385254)]
#
#
# --------------------------------------------------
#
# Grupo: ('note', 'title', 'role')
#
# [('roles', 0.5257738828659058),
#  ('crown', 0.4794897735118866),
#  ('championship', 0.42020219564437866),
#  ('position', 0.4110642373561859),
#  ('titles', 0.4063303768634796),
#  ('Role', 0.39870500564575195),
#  ('berth', 0.38968217372894287),
#  ('trophy', 0.38429445028305054),
#  ('responsibilities', 0.36988458037376404),
#  ('notes', 0.3610447943210602)]
#
#
# --------------------------------------------------
#
# Grupo: ('note', 'person', 'role')
#
# [('roles', 0.4563809931278229),
#  ('aspect', 0.4350746273994446),
#  ('someone', 0.4156574010848999),
#  ('devil_advocate', 0.38431042432785034),
#  ('character', 0.38356614112854004),
#  ('thing', 0.3823387622833252),
#  ('implication', 0.3685784339904785),
#  ('participant', 0.3683672547340393),
#  ('element', 0.367633581161499),
#  ('position', 0.36467257142066956)]
#
#
# --------------------------------------------------
#
# Grupo: ('name', 'character', 'movie')
#
# [('characters', 0.6240777373313904),
#  ('film', 0.599344789981842),
#  ('script', 0.5889739394187927),
#  ('titular_character', 0.5884782075881958),
#  ('plotline', 0.5769297480583191),
#  ('protagonist', 0.5639005899429321),
#  ('villain', 0.5605474710464478),
#  ('storyline', 0.5373907089233398),
#  ('TeenHollywood', 0.5342550873756409),
#  ('baddie', 0.527867317199707)]
#
#
# --------------------------------------------------
#
# Grupo: ('name', 'character', 'title')
#
# [('surname', 0.567229688167572),
#  ('moniker', 0.5387578010559082),
#  ('persona', 0.5166099071502686),
#  ('identity', 0.5075798034667969),
#  ('characters', 0.506381630897522),
#  ('Trajche_Shoposki', 0.49537694454193115),
#  ('names', 0.48803478479385376),
#  ('protagonist', 0.47507718205451965),
#  ('titles', 0.47470319271087646),
#  ('villain', 0.47410133481025696)]
#
#
# --------------------------------------------------
#
# Grupo: ('name', 'character', 'person')
#
# [('surname', 0.5536125898361206),
#  ('Trajche_Shoposki', 0.5396902561187744),
#  ('characters', 0.5236777663230896),
#  ('someone', 0.5233855247497559),
#  ('persona', 0.5179482698440552),
#  ('guy', 0.5010810494422913),
#  ('personality', 0.49771809577941895),
#  ('protagonist', 0.48916274309158325),
#  ('villain', 0.4805537462234497),
#  ('names', 0.4794650971889496)]
#
#
# --------------------------------------------------
#
# Grupo: ('name', 'character', 'role')
#
# [('roles', 0.6212083101272583),
#  ('persona', 0.5526903867721558),
#  ('villain', 0.538115918636322),
#  ('characters', 0.5214903354644775),
#  ('surname', 0.5159276723861694),
#  ('titular_character', 0.5132999420166016),
#  ('protagonist', 0.5064629912376404),
#  ('identity', 0.4955819845199585),
#  ('alter_ego', 0.493259072303772),
#  ('portrayer', 0.48913753032684326)]
#
#
# --------------------------------------------------
#
# Grupo: ('name', 'movie', 'title')
#
# [('film', 0.5416486263275146),
#  ('titles', 0.5235172510147095),
#  ('surname', 0.5011926293373108),
#  ('Trajche_Shoposki', 0.4963243007659912),
#  ('moniker', 0.49219149351119995),
#  ('sequel', 0.4906643331050873),
#  ('script', 0.4730837643146515),
#  ('remake', 0.4670727252960205),
#  ('logline', 0.46702253818511963),
#  ('names', 0.46433430910110474)]
#
#
# --------------------------------------------------
#
# Grupo: ('name', 'movie', 'person')
#
# [('Trajche_Shoposki', 0.5429927110671997),
#  ('someone', 0.5298397541046143),
#  ('film', 0.5247668027877808),
#  ('surname', 0.48778414726257324),
#  ('logline', 0.4822467267513275),
#  ('movies', 0.48160111904144287),
#  ('TeenHollywood', 0.47830647230148315),
#  ('Heleno_Santiago', 0.4772658944129944),
#  ('character', 0.47087886929512024),
#  ('Your_thestate.com', 0.46748024225234985)]
#
#
# --------------------------------------------------
#
# Grupo: ('name', 'movie', 'role')
# [('roles', 0.578045666217804),
#  ('film', 0.5544825196266174),
#  ('character', 0.5474255681037903),
#  ('titular_character', 0.5007189512252808),
#  ('villain', 0.4893133044242859),
#  ('Best_Friend_Wedding', 0.4793233573436737),
#  ('surname', 0.47256284952163696),
#  ('starring', 0.47255221009254456),
#  ('Ankahee', 0.46488156914711),
#  ('movies', 0.4627610743045807)]
#
#
# --------------------------------------------------
#
# Grupo: ('name', 'title', 'person')
#
# [('surname', 0.5528602600097656),
#  ('Trajche_Shoposki', 0.5203849673271179),
#  ('someone', 0.5110615491867065),
#  ('moniker', 0.499275267124176),
#  ('names', 0.4962158501148224),
#  ('identity', 0.45665425062179565),
#  ('Heleno_Santiago', 0.4539283514022827),
#  ('Name', 0.4374006986618042),
#  ('nationality', 0.43041926622390747),
#  ('somebody', 0.42977553606033325)]
#
#
# --------------------------------------------------
#
# Grupo: ('name', 'title', 'role')
#
# [('roles', 0.5528703927993774),
#  ('moniker', 0.5343461632728577),
#  ('surname', 0.5101157426834106),
#  ('identity', 0.4746662378311157),
#  ('names', 0.47255051136016846),
#  ('crown', 0.472227543592453),
#  ('titles', 0.4494687020778656),
#  ('monicker', 0.44765445590019226),
#  ('position', 0.4313235282897949),
#  ('nickname', 0.42678338289260864)]
#
#
# --------------------------------------------------
#
# Grupo: ('name', 'person', 'role')
#
# [('surname', 0.5225273966789246),
#  ('roles', 0.4900723397731781),
#  ('names', 0.48782879114151),
#  ('Trajche_Shoposki', 0.47930818796157837),
#  ('someone', 0.479004442691803),
#  ('character', 0.4720628559589386),
#  ('identity', 0.466558575630188),
#  ('moniker', 0.41954725980758667),
#  ('somebody', 0.41600272059440613),
#  ('persona', 0.4140927791595459)]
#
#
# --------------------------------------------------
#
# Grupo: ('character', 'movie', 'title')
#
# [('film', 0.6463413238525391),
#  ('characters', 0.6119519472122192),
#  ('sequel', 0.606726884841919),
#  ('titular_character', 0.5959152579307556),
#  ('plotline', 0.595582902431488),
#  ('storyline', 0.5939432382583618),
#  ('cinematic_masterpiece', 0.5747191309928894),
#  ('protagonist', 0.5731010437011719),
#  ('script', 0.566530168056488),
#  ('villain', 0.551355242729187)]
#
#
# --------------------------------------------------
#
# Grupo: ('character', 'movie', 'person')
#
# [('film', 0.6184570789337158),
#  ('characters', 0.6166090965270996),
#  ('actor', 0.5790756940841675),
#  ('protagonist', 0.5754415988922119),
#  ('titular_character', 0.5700619220733643),
#  ('movies', 0.5574663281440735),
#  ('villain', 0.5470198392868042),
#  ('TeenHollywood', 0.5468717813491821),
#  ('superhero', 0.5456693768501282),
#  ('script', 0.5438359975814819)]
#
#
# --------------------------------------------------
#
# Grupo: ('character', 'movie', 'role')
#
# [('titular_character', 0.6461098790168762),
#  ('film', 0.6254920959472656),
#  ('characters', 0.619255006313324),
#  ('villain', 0.6075496673583984),
#  ('roles', 0.6057666540145874),
#  ('protagonist', 0.5967395305633545),
#  ('baddie', 0.5903463959693909),
#  ('plotline', 0.5825347304344177),
#  ('actor', 0.5665197372436523),
#  ('portrayer', 0.565500020980835)]
#
#
# --------------------------------------------------
#
# Grupo: ('character', 'title', 'person')
#
# [('characters', 0.5410634875297546),
#  ('protagonist', 0.5272235870361328),
#  ('someone', 0.5020731687545776),
#  ('villain', 0.4985572099685669),
#  ('guy', 0.4957749843597412),
#  ('titular_character', 0.4721987843513489),
#  ('persona', 0.46218687295913696),
#  ('championship', 0.45943713188171387),
#  ('personality', 0.45678189396858215),
#  ('Character', 0.4552745521068573)]
#
#
# --------------------------------------------------
#
# Grupo: ('character', 'title', 'role')
#
# [('roles', 0.6283230781555176),
#  ('villain', 0.5369516611099243),
#  ('titular_character', 0.5284674167633057),
#  ('protagonist', 0.5232833027839661),
#  ('characters', 0.517193615436554),
#  ('baddie', 0.4880130887031555),
#  ('storyline', 0.4823254346847534),
#  ('persona', 0.480229914188385),
#  ('portrayer', 0.47575807571411133),
#  ('villainous', 0.4611298143863678)]
#
#
# --------------------------------------------------
#
# Grupo: ('character', 'person', 'role')
#
# [('roles', 0.5590066909790039),
#  ('villain', 0.5566765666007996),
#  ('protagonist', 0.5505549907684326),
#  ('characters', 0.5480992197990417),
#  ('titular_character', 0.5270441174507141),
#  ('personality', 0.5155379176139832),
#  ('baddie', 0.496289998292923),
#  ('persona', 0.49479660391807556),
#  ('portrayer', 0.48635634779930115),
#  ('guy', 0.47944673895835876)]
#
#
# --------------------------------------------------
#
# Grupo: ('movie', 'title', 'person')
#
# [('film', 0.5942588448524475),
#  ('sequel', 0.5304116010665894),
#  ('movies', 0.525495171546936),
#  ('moviegoer', 0.499225378036499),
#  ('someone', 0.4947397708892822),
#  ('popcorn_flick', 0.4946989417076111),
#  ('films', 0.49199867248535156),
#  ('logline', 0.4867106080055237),
#  ('threequel', 0.4815714955329895),
#  ('chick_flick', 0.4809756577014923)]
#
#
# --------------------------------------------------
#
# Grupo: ('movie', 'title', 'role')
#
# [('film', 0.599699854850769),
#  ('roles', 0.569770872592926),
#  ('sequel', 0.5360079407691956),
#  ('character', 0.5149286985397339),
#  ('Ankahee', 0.5076807737350464),
#  ('titular_character', 0.5036667585372925),
#  ('starring', 0.4941225051879883),
#  ('Hindi_remake', 0.48704931139945984),
#  ('movies', 0.4851412773132324),
#  ('starring_Amitabh_Bachchan', 0.4802926778793335)]
#
#
# --------------------------------------------------
#
# Grupo: ('movie', 'person', 'role')
#
# [('film', 0.5995976328849792),
#  ('character', 0.5614451169967651),
#  ('actor', 0.5419583320617676),
#  ('movies', 0.5218217372894287),
#  ('titular_character', 0.5027135014533997),
#  ('villain', 0.49580252170562744),
#  ('roles', 0.4949266016483307),
#  ('Downey_Jr', 0.494306743144989),
#  ('films', 0.4853593111038208),
#  ('TeenHollywood', 0.4844525456428528)]
#
#
# --------------------------------------------------
#
# Grupo: ('title', 'person', 'role')
#
# [('roles', 0.5153295397758484),
#  ('character', 0.4702063798904419),
#  ('someone', 0.45027828216552734),
#  ('championship', 0.4475870728492737),
#  ('crown', 0.4412301182746887),
#  ('position', 0.4298971891403198),
#  ('villain', 0.4090997576713562),
#  ('gatekeeper', 0.4024535119533539),
#  ('titles', 0.39231884479522705),
#  ('berth', 0.39117294549942017)]
#
#
# --------------------------------------------------
#
# Grupo: ('casting', 'note', 'name', 'character')
#
# [('script', 0.507011890411377),
#  ('names', 0.502933144569397),
#  ('cast', 0.4968488812446594),
#  ('characters', 0.4967237710952759),
#  ('surname', 0.48221355676651),
#  ('Trajche_Shoposki', 0.47779226303100586),
#  ('Your_thestate.com', 0.4671723246574402),
#  ('villain', 0.4633355736732483),
#  ('titular_character', 0.45056623220443726),
#  ('portrayer', 0.44986680150032043)]
#
#
# --------------------------------------------------
#
# Grupo: ('casting', 'note', 'name', 'movie')
#
# [('film', 0.5654250979423523),
#  ('script', 0.5552432537078857),
#  ('logline', 0.4917830228805542),
#  ('cast', 0.4771193563938141),
#  ('IMDB', 0.47620177268981934),
#  ('plot_synopsis', 0.47443050146102905),
#  ('imdb', 0.47075220942497253),
#  ('names', 0.469241738319397),
#  ('Your_thestate.com', 0.46729379892349243),
#  ('Trajche_Shoposki', 0.46420764923095703)]
#
#
# --------------------------------------------------
#
# Grupo: ('casting', 'note', 'name', 'title')
#
# [('names', 0.5142975449562073),
#  ('moniker', 0.4759298264980316),
#  ('surname', 0.4723197817802429),
#  ('Trajche_Shoposki', 0.4522528648376465),
#  ('Your_thestate.com', 0.43715015053749084),
#  ('Heleno_Santiago', 0.427206426858902),
#  ('misspell', 0.40691494941711426),
#  ('monikers', 0.4066046476364136),
#  ('word', 0.3990962505340576),
#  ('crown', 0.39731353521347046)]
#
#
# --------------------------------------------------
#
# Grupo: ('casting', 'note', 'name', 'person')
#
# [('names', 0.5049725770950317),
#  ('Trajche_Shoposki', 0.4930669665336609),
#  ('surname', 0.46007007360458374),
#  ('Heleno_Santiago', 0.4481970965862274),
#  ('Your_thestate.com', 0.44486576318740845),
#  ('someone', 0.4410109519958496),
#  ('misspelling', 0.4142388105392456),
#  ('cast', 0.4128129780292511),
#  ('word', 0.4090925455093384),
#  ('locution', 0.4003165364265442)]
#
#
# --------------------------------------------------
#
# Grupo: ('casting', 'note', 'name', 'role')
#
# [('roles', 0.5400335788726807),
#  ('names', 0.4878801703453064),
#  ('cast', 0.4491085112094879),
#  ('surname', 0.4281013011932373),
#  ('character', 0.42063021659851074),
#  ('casts', 0.41988444328308105),
#  ('Your_thestate.com', 0.40236544609069824),
#  ('Trajche_Shoposki', 0.3998359143733978),
#  ('moniker', 0.39038610458374023),
#  ('Casting', 0.3819739818572998)]
#
#
# --------------------------------------------------
#
# Grupo: ('casting', 'note', 'character', 'movie')
#
# [('film', 0.649722695350647),
#  ('script', 0.6263486742973328),
#  ('characters', 0.5707575082778931),
#  ('plotline', 0.5700229406356812),
#  ('titular_character', 0.5578725337982178),
#  ('actors', 0.5519412159919739),
#  ('cast', 0.5491170287132263),
#  ('actor', 0.5419763922691345),
#  ('Yelchin', 0.5405906438827515),
#  ('sequel', 0.5311744809150696)]
#
#
# --------------------------------------------------
#
# Grupo: ('casting', 'note', 'character', 'title')
# [('script', 0.5070189237594604),
#  ('characters', 0.5059945583343506),
#  ('cast', 0.4961952567100525),
#  ('plotline', 0.48078617453575134),
#  ('titular_character', 0.4762500524520874),
#  ('villain', 0.4739525318145752),
#  ('storyline', 0.47391724586486816),
#  ('protagonist', 0.4570891261100769),
#  ('backstory', 0.4556005597114563),
#  ('characterisations', 0.4529445767402649)]
#
#
# --------------------------------------------------
#
# Grupo: ('casting', 'note', 'character', 'person')
#
# [('characters', 0.5127317905426025),
#  ('cast', 0.5126165151596069),
#  ('script', 0.4867663085460663),
#  ('villain', 0.47147244215011597),
#  ('actor', 0.46751782298088074),
#  ('protagonist', 0.46202489733695984),
#  ('titular_character', 0.45485609769821167),
#  ('guy', 0.44530564546585083),
#  ('actors', 0.4445275068283081),
#  ('villian', 0.44299936294555664)]
#
#
# --------------------------------------------------
#
# Grupo: ('casting', 'note', 'character', 'role')
#
# [('roles', 0.6004371047019958),
#  ('cast', 0.5322279930114746),
#  ('villain', 0.5115412473678589),
#  ('titular_character', 0.5097962021827698),
#  ('characters', 0.4991644024848938),
#  ('portrayer', 0.49442964792251587),
#  ('baddie', 0.4832289218902588),
#  ('villainous', 0.4757624864578247),
#  ('portrayal', 0.47341227531433105),
#  ('casts', 0.47185057401657104)]
#
#
# --------------------------------------------------
#
# Grupo: ('casting', 'note', 'movie', 'title')
#
# [('film', 0.6214298009872437),
#  ('script', 0.5460386276245117),
#  ('sequel', 0.5379077196121216),
#  ('What_Your_Raashee', 0.5148319005966187),
#  ('Reagen_Sulewski', 0.5118803381919861),
#  ('films', 0.4956951141357422),
#  ('plot_synopsis', 0.49293726682662964),
#  ('logline', 0.4920145869255066),
#  ('Run_Fatboy_Run', 0.4901103377342224),
#  ('Dragonball_Evolution', 0.49008551239967346)]
#
#
# --------------------------------------------------
#
# Grupo: ('casting', 'note', 'movie', 'person')
#
# [('film', 0.5954490900039673),
#  ('script', 0.5248620510101318),
#  ('Reagen_Sulewski', 0.5051329135894775),
#  ('moviegoer', 0.5027259588241577),
#  ('logline', 0.4963936507701874),
#  ('actor', 0.4889836311340332),
#  ('movies', 0.48814594745635986),
#  ('cast', 0.4836665987968445),
#  ('David_Mumpower', 0.4829428195953369),
#  ('films', 0.4799678921699524)]
#
#
# --------------------------------------------------
#
# Grupo: ('casting', 'note', 'movie', 'role')
#
# [('film', 0.6037399768829346),
#  ('roles', 0.5310544371604919),
#  ('cast', 0.5226835012435913),
#  ('script', 0.5033650398254395),
#  ('actors', 0.49195045232772827),
#  ('character', 0.4835273027420044),
#  ('actor', 0.4790496230125427),
#  ('Best_Friend_Wedding', 0.4789608120918274),
#  ('Ankahee', 0.47362440824508667),
#  ('films', 0.47260332107543945)]
#
#
# --------------------------------------------------
#
# Grupo: ('casting', 'note', 'title', 'person')
#
# [('someone', 0.4253953695297241),
#  ('cast', 0.42093905806541443),
#  ('casts', 0.3961799144744873),
#  ('logline', 0.3875281810760498),
#  ('Pretty_darn', 0.3874293565750122),
#  ('script', 0.38735851645469666),
#  ('Heleno_Santiago', 0.37986284494400024),
#  ('character', 0.37698453664779663),
#  ('blog_accepts_trackbacks', 0.37523940205574036),
#  ('one', 0.37025824189186096)]
#
#
# --------------------------------------------------
#
# Grupo: ('casting', 'note', 'title', 'role')
#
# [('roles', 0.5570343732833862),
#  ('cast', 0.4433656334877014),
#  ('casts', 0.432181179523468),
#  ('character', 0.4119086265563965),
#  ('reprise', 0.4097020626068115),
#  ('crown', 0.39779192209243774),
#  ('Casting', 0.38855183124542236),
#  ('reprising', 0.3877594470977783),
#  ('Role', 0.37906819581985474),
#  ('berth', 0.37671342492103577)]
#
#
# --------------------------------------------------
#
# Grupo: ('casting', 'note', 'person', 'role')
#
# [('roles', 0.4886127710342407),
#  ('cast', 0.4801340699195862),
#  ('casts', 0.450893372297287),
#  ('character', 0.44912445545196533),
#  ('actor', 0.3941221833229065),
#  ('villain', 0.3897514343261719),
#  ('Casting', 0.3884223401546478),
#  ('acting', 0.3866267502307892),
#  ('mensch', 0.3783700168132782),
#  ('someone', 0.37427622079849243)]
#
#
# --------------------------------------------------
#
# Grupo: ('casting', 'name', 'character', 'movie')
#
# [('film', 0.6059656143188477),
#  ('script', 0.6004654169082642),
#  ('characters', 0.5951557159423828),
#  ('titular_character', 0.5950061082839966),
#  ('villain', 0.564184308052063),
#  ('plotline', 0.5582650303840637),
#  ('actor', 0.5520570278167725),
#  ('portrayer', 0.5481674671173096),
#  ('actors', 0.5411908626556396),
#  ('cast', 0.5401485562324524)]
#
#
# --------------------------------------------------
#
# Grupo: ('casting', 'name', 'character', 'title')
#
# [('characters', 0.5207065343856812),
# ...
#  ('titular_character', 0.5012651681900024),
#  ('Your_thestate.com', 0.49506738781929016),
#  ('storyline', 0.49140989780426025),
#  ('TeenHollywood', 0.4890759587287903)]
#
#
# --------------------------------------------------
#
# Grupo: ('note', 'name', 'character', 'title')
#
# [('surname', 0.5312304496765137),
#  ('moniker', 0.49570417404174805),
#  ('Trajche_Shoposki', 0.49301624298095703),
#  ('names', 0.48538222908973694),
#  ('Your_thestate.com', 0.4614720642566681),
#  ('characters', 0.4472576379776001),
#  ('Heleno_Santiago', 0.44059938192367554),
#  ('persona', 0.4339960515499115),
#  ('script', 0.42724573612213135),
#  ('identity', 0.4207368493080139)]
#
#
# --------------------------------------------------
#
# Grupo: ('note', 'name', 'character', 'person')
#
# [('Trajche_Shoposki', 0.5313975214958191),
#  ('surname', 0.520042359828949),
#  ('names', 0.47811347246170044),
#  ('someone', 0.47271695733070374),
#  ('Your_thestate.com', 0.46923014521598816),
#  ('characters', 0.46303704380989075),
#  ('Heleno_Santiago', 0.46082931756973267),
#  ('guy', 0.45138493180274963),
#  ('locution', 0.4454652667045593),
#  ('persona', 0.4362991452217102)]
#
#
# --------------------------------------------------
#
# Grupo: ('note', 'name', 'character', 'role')
#
# [('roles', 0.5574489831924438),
#  ('surname', 0.4877851903438568),
#  ('persona', 0.46748510003089905),
#  ('villain', 0.46689870953559875),
#  ('characters', 0.4619349241256714),
#  ('names', 0.4609016180038452),
#  ('Trajche_Shoposki', 0.44250988960266113),
#  ('protagonist', 0.43969422578811646),
#  ('titular_character', 0.4374231696128845),
#  ('Your_thestate.com', 0.4278237819671631)]
#
#
# --------------------------------------------------
#
# Grupo: ('note', 'name', 'movie', 'title')
#
# [('film', 0.4884031414985657),
#  ('Trajche_Shoposki', 0.48628735542297363),
#  ('script', 0.47905629873275757),
#  ('Heleno_Santiago', 0.46938759088516235),
#  ('Your_thestate.com', 0.46750408411026),
#  ('surname', 0.4659462869167328),
#  ('logline', 0.4631655514240265),
#  ('names', 0.4580059051513672),
#  ('subtitle', 0.4499099850654602),
#  ('titles', 0.4495584964752197)]
#
#
# --------------------------------------------------
#
# Grupo: ('note', 'name', 'movie', 'person')
#
# [('Trajche_Shoposki', 0.5260300040245056),
#  ('Heleno_Santiago', 0.4899321496486664),
#  ('logline', 0.4762679636478424),
#  ('Your_thestate.com', 0.4754749536514282),
#  ('film', 0.47507214546203613),
#  ('someone', 0.4688926637172699),
#  ('script', 0.4683271646499634),
#  ('surname', 0.4552968740463257),
#  ('names', 0.450904905796051),
#  ('TeenHollywood', 0.43278729915618896)]
#
#
# --------------------------------------------------
#
# Grupo: ('note', 'name', 'movie', 'role')
#
# [('roles', 0.503644585609436),
#  ('film', 0.49521446228027344),
#  ('character', 0.47189605236053467),
#  ('script', 0.45790547132492065),
#  ('Best_Friend_Wedding', 0.4559614062309265),
#  ('Trajche_Shoposki', 0.4502931833267212),
#  ('names', 0.4494313597679138),
#  ('Your_thestate.com', 0.4484565556049347),
#  ('surname', 0.43854331970214844),
#  ('Heleno_Santiago', 0.42097944021224976)]
#
#
# --------------------------------------------------
#
# Grupo: ('note', 'name', 'title', 'person')
#
# [('surname', 0.5102257132530212),
#  ('Trajche_Shoposki', 0.5073401927947998),
#  ('names', 0.48560917377471924),
#  ('Heleno_Santiago', 0.471005916595459),
#  ('moniker', 0.45366790890693665),
#  ('someone', 0.4527404010295868),
#  ('phrase', 0.4419299364089966),
#  ('Your_thestate.com', 0.43845081329345703),
#  ('Comment_Guidelines', 0.42373281717300415),
#  ('word', 0.42339202761650085)]
#
#
# --------------------------------------------------
#
# Grupo: ('note', 'name', 'title', 'role')
#
# [('roles', 0.48897218704223633),
#  ('moniker', 0.48448652029037476),
#  ('surname', 0.47512978315353394),
#  ('names', 0.4660035967826843),
#  ('crown', 0.4261358082294464),
#  ('Trajche_Shoposki', 0.4133821725845337),
#  ('position', 0.4125699996948242),
#  ('monicker', 0.3999916911125183),
#  ('Your_thestate.com', 0.3943805396556854),
#  ('titles', 0.38922977447509766)]
#
#
# --------------------------------------------------
#
# Grupo: ('note', 'name', 'person', 'role')
#
# [('surname', 0.4814468324184418),
#  ('names', 0.4756174087524414),
#  ('Trajche_Shoposki', 0.4698476493358612),
#  ('roles', 0.43142110109329224),
#  ('someone', 0.4227229654788971),
#  ('Heleno_Santiago', 0.421114057302475),
#  ('Your_thestate.com', 0.4178076684474945),
#  ('character', 0.41015589237213135),
#  ('description', 0.38542693853378296),
#  ('moniker', 0.38387125730514526)]
#
#
# --------------------------------------------------
#
# Grupo: ('note', 'character', 'movie', 'title')
#
# [('film', 0.598210334777832),
#  ('script', 0.574913501739502),
#  ('plotline', 0.5612751841545105),
#  ('sequel', 0.5558264255523682),
#  ('storyline', 0.5488825440406799),
#  ('characters', 0.5477873086929321),
#  ('cinematic_masterpiece', 0.5271437168121338),
#  ('titular_character', 0.5158427953720093),
#  ('Run_Fatboy_Run', 0.5127255916595459),
#  ('logline', 0.5056421160697937)]
#
#
# --------------------------------------------------
#
# Grupo: ('note', 'character', 'movie', 'person')
# [('film', 0.5760312080383301),
#  ('script', 0.5557022094726562),
#  ('characters', 0.5546655654907227),
#  ('plotline', 0.5174629092216492),
#  ('actor', 0.5124837160110474),
#  ('logline', 0.5107388496398926),
#  ('TeenHollywood', 0.5099733471870422),
#  ('protagonist', 0.5091184973716736),
#  ('movies', 0.49678361415863037),
#  ('titular_character', 0.4961925148963928)]
#
#
# --------------------------------------------------
#
# Grupo: ('note', 'character', 'movie', 'role')
#
# [('film', 0.5815382599830627),
#  ('titular_character', 0.5628587007522583),
#  ('characters', 0.556465208530426),
#  ('roles', 0.5537433624267578),
#  ('plotline', 0.5510051250457764),
#  ('villain', 0.536811351776123),
#  ('script', 0.5331549644470215),
#  ('protagonist', 0.5274613499641418),
#  ('baddie', 0.527255654335022),
#  ('storyline', 0.519762396812439)]
#
#
# --------------------------------------------------
#
# Grupo: ('note', 'character', 'title', 'person')
#
# [('characters', 0.47993049025535583),
#  ('protagonist', 0.45799919962882996),
#  ('someone', 0.4567081332206726),
#  ('guy', 0.44905543327331543),
#  ('villain', 0.43299439549446106),
#  ('storyline', 0.42292892932891846),
#  ('script', 0.4221116006374359),
#  ('personality_trait', 0.4218122959136963),
#  ('likeable', 0.4159013032913208),
#  ('plotline', 0.41583865880966187)]
#
#
# --------------------------------------------------
#
# Grupo: ('note', 'character', 'title', 'role')
#
# [('roles', 0.5708004236221313),
#  ('villain', 0.4716212749481201),
#  ('characters', 0.4639893174171448),
#  ('protagonist', 0.4598354399204254),
#  ('titular_character', 0.4559711813926697),
#  ('storyline', 0.45035532116889954),
#  ('backstory', 0.4359300136566162),
#  ('plotline', 0.4354584515094757),
#  ('portrayal', 0.43462246656417847),
#  ('baddie', 0.4345710277557373)]
#
#
# --------------------------------------------------
#
# Grupo: ('note', 'character', 'person', 'role')
#
# [('roles', 0.508151113986969),
#  ('characters', 0.48908019065856934),
#  ('villain', 0.4868207573890686),
#  ('protagonist', 0.4816679060459137),
#  ('aspect', 0.4548771381378174),
#  ('personality_trait', 0.45325544476509094),
#  ('titular_character', 0.45270371437072754),
#  ('personality', 0.4515320062637329),
#  ('baddie', 0.44001227617263794),
#  ('guy', 0.4372076988220215)]
#
#
# --------------------------------------------------
#
# Grupo: ('note', 'movie', 'title', 'person')
#
# [('film', 0.5392161011695862),
#  ('logline', 0.4863123893737793),
#  ('sequel', 0.4767313003540039),
#  ('script', 0.46731990575790405),
#  ('Reagen_Sulewski', 0.4648903012275696),
#  ('What_Your_Raashee', 0.4609857499599457),
#  ('movies', 0.45285606384277344),
#  ('moviegoer', 0.4517623782157898),
#  ('Run_Fatboy_Run', 0.447416752576828),
#  ('someone', 0.44360238313674927)]
#
#
# --------------------------------------------------
#
# Grupo: ('note', 'movie', 'title', 'role')
#
# [('film', 0.5437541007995605),
#  ('roles', 0.5069262981414795),
#  ('sequel', 0.4814671277999878),
#  ('Ankahee', 0.4650741517543793),
#  ('Run_Fatboy_Run', 0.46454209089279175),
#  ('character', 0.4539504051208496),
#  ('Best_Friend_Wedding', 0.44899654388427734),
#  ('script', 0.4420008063316345),
#  ('Igby_Goes_Down', 0.4413527846336365),
#  ('What_Your_Raashee', 0.4371539354324341)]
#
#
# --------------------------------------------------
#
# Grupo: ('note', 'movie', 'person', 'role')
#
# [('film', 0.541047215461731),
#  ('character', 0.4909878969192505),
#  ('Best_Friend_Wedding', 0.4618028998374939),
#  ('actor', 0.4608518183231354),
#  ('movies', 0.4474579691886902),
#  ('Ankahee', 0.4423941373825073),
#  ('script', 0.44101691246032715),
#  ('roles', 0.4409683048725128),
#  ('TeenHollywood', 0.4403531551361084),
#  ('logline', 0.4370303452014923)]
#
#
# --------------------------------------------------
#
# Grupo: ('note', 'title', 'person', 'role')
#
# [('roles', 0.4547366499900818),
#  ('position', 0.41178494691848755),
#  ('character', 0.410344660282135),
#  ('someone', 0.4007854461669922),
#  ('crown', 0.3984883427619934),
#  ('gracious_loser', 0.3818061053752899),
#  ('something', 0.37538230419158936),
#  ('aspect', 0.3753490149974823),
#  ('championship', 0.3701750338077545),
#  ('blog_accepts_trackbacks', 0.3626328706741333)]
#
#
# --------------------------------------------------
#
# Grupo: ('name', 'character', 'movie', 'title')
#
# [('characters', 0.5710077285766602),
#  ('titular_character', 0.5532271862030029),
#  ('film', 0.5531215667724609),
#  ('script', 0.5481810569763184),
#  ('plotline', 0.5467849373817444),
#  ('storyline', 0.535193145275116),
#  ('villain', 0.5348597764968872),
#  ('protagonist', 0.5329124927520752),
#  ('sequel', 0.5180492401123047),
#  ('Trajche_Shoposki', 0.49933961033821106)]
#
#
# --------------------------------------------------
#
# Grupo: ('name', 'character', 'movie', 'person')
#
# [('characters', 0.5793502330780029),
#  ('protagonist', 0.5390738248825073),
#  ('titular_character', 0.5360091924667358),
#  ('film', 0.5355339646339417),
#  ('villain', 0.5348297357559204),
#  ('script', 0.5329338312149048),
#  ('Trajche_Shoposki', 0.5307431817054749),
#  ('TeenHollywood', 0.5241966247558594),
#  ('actor', 0.5235871076583862),
#  ('plotline', 0.5079195499420166)]
#
#
# --------------------------------------------------
#
# Grupo: ('name', 'character', 'movie', 'role')
#
# [('titular_character', 0.6036178469657898),
#  ('villain', 0.5892297625541687),
#  ('characters', 0.5854407548904419),
#  ('roles', 0.5734751224517822),
#  ('protagonist', 0.5606124997138977),
#  ('baddie', 0.5492388606071472),
#  ('film', 0.5453252196311951),
#  ('portrayer', 0.545073390007019),
#  ('plotline', 0.544040322303772),
#  ('persona', 0.5284203290939331)]
#
#
# --------------------------------------------------
#
# Grupo: ('name', 'character', 'title', 'person')
#
# [('surname', 0.5426545739173889),
#  ('Trajche_Shoposki', 0.52924644947052),
#  ('persona', 0.5016474723815918),
#  ('characters', 0.49668088555336),
#  ('identity', 0.4922536015510559),
#  ('someone', 0.4867509603500366),
#  ('protagonist', 0.47955870628356934),
#  ('villain', 0.4771524965763092),
#  ('moniker', 0.46966245770454407),
#  ('guy', 0.4617312252521515)]
#
#
# --------------------------------------------------
#
# Grupo: ('name', 'character', 'title', 'role')
#
# [('roles', 0.5766409039497375),
#  ('persona', 0.5218636989593506),
#  ('villain', 0.5164867043495178),
#  ('surname', 0.5021400451660156),
#  ('identity', 0.4987221658229828),
#  ('titular_character', 0.4913034439086914),
#  ('moniker', 0.4908948540687561),
#  ('characters', 0.4865858256816864),
#  ('protagonist', 0.485627681016922),
#  ('personas', 0.46066468954086304)]
#
#
# --------------------------------------------------
#
# Grupo: ('name', 'character', 'person', 'role')
#
# [('persona', 0.5339963436126709),
#  ('villain', 0.532244086265564),
#  ('roles', 0.5196162462234497),
#  ('characters', 0.5113565921783447),
#  ('protagonist', 0.5073752403259277),
#  ('surname', 0.5024518966674805),
#  ('personality', 0.5000002980232239),
#  ('titular_character', 0.4896966218948364),
#  ('identity', 0.4844338595867157),
#  ('Trajche_Shoposki', 0.4814947843551636)]
#
#
# --------------------------------------------------
#
# Grupo: ('name', 'movie', 'title', 'person')
#
# [('Trajche_Shoposki', 0.5328288078308105),
#  ('film', 0.5002951622009277),
#  ('someone', 0.4916514754295349),
#  ('surname', 0.488558828830719),
#  ('Heleno_Santiago', 0.48377448320388794),
#  ('logline', 0.47974708676338196),
#  ('character', 0.47579193115234375),
#  ('Your_thestate.com', 0.4677215814590454),
#  ('script', 0.4503260552883148),
#  ('sequel', 0.44622766971588135)]
#
#
# --------------------------------------------------
#
# Grupo: ('name', 'movie', 'title', 'role')
#
# [('roles', 0.5343043804168701),
#  ('character', 0.5245715379714966),
#  ('film', 0.5098464488983154),
#  ('titular_character', 0.476163774728775),
#  ('villain', 0.4719841480255127),
#  ('moniker', 0.4679110646247864),
#  ('surname', 0.46280407905578613),
#  ('starring', 0.4612154960632324),
#  ('Ankahee', 0.45636186003685),
#  ('Hindi_remake', 0.45634084939956665)]
#
#
# --------------------------------------------------
#
# Grupo: ('name', 'movie', 'person', 'role')
#
# [('character', 0.5623505711555481),
#  ('film', 0.5085469484329224),
#  ('Trajche_Shoposki', 0.4995061755180359),
#  ('villain', 0.48924511671066284),
#  ('actor', 0.48479771614074707),
#  ('titular_character', 0.4749000668525696),
#  ('roles', 0.4727913737297058),
#  ('TeenHollywood', 0.46839988231658936),
#  ('someone', 0.46542978286743164),
#  ('surname', 0.46336472034454346)]
#
#
# --------------------------------------------------
#
# Grupo: ('name', 'title', 'person', 'role')
#
# [('surname', 0.5142356753349304),
#  ('identity', 0.4828127324581146),
#  ('moniker', 0.48225241899490356),
#  ('Trajche_Shoposki', 0.4767262935638428),
#  ('character', 0.47393667697906494),
#  ('roles', 0.47354114055633545),
#  ('names', 0.45072901248931885),
#  ('someone', 0.44577622413635254),
#  ('position', 0.4219103157520294),
#  ('nationality', 0.41965341567993164)]
#
#
# --------------------------------------------------
#
# Grupo: ('character', 'movie', 'title', 'person')
#
# [('film', 0.5894100666046143),
#  ('characters', 0.5852700471878052),
#  ('protagonist', 0.5616018772125244),
#  ('titular_character', 0.5570026636123657),
#  ('sequel', 0.5450313091278076),
#  ('villain', 0.5419498682022095),
#  ('actor', 0.5392777919769287),
#  ('plotline', 0.5374728441238403),
#  ('storyline', 0.5306825041770935),
#  ('script', 0.5290020704269409)]
#
#
# --------------------------------------------------
#
# Grupo: ('character', 'movie', 'title', 'role')
# [('titular_character', 0.6108077764511108),
#  ('film', 0.5845144987106323),
#  ('villain', 0.5829018354415894),
#  ('characters', 0.5767648220062256),
#  ('roles', 0.5728666186332703),
#  ('protagonist', 0.5691592693328857),
#  ('storyline', 0.5611318349838257),
#  ('plotline', 0.5602355003356934),
#  ('baddie', 0.5552335977554321),
#  ('sequel', 0.5407454371452332)]
#
#
# --------------------------------------------------
#
# Grupo: ('character', 'movie', 'person', 'role')
#
# [('titular_character', 0.602862536907196),
#  ('characters', 0.5948085784912109),
#  ('villain', 0.591832160949707),
#  ('protagonist', 0.5842756032943726),
#  ('actor', 0.5791710615158081),
#  ('film', 0.5762848854064941),
#  ('baddie', 0.5555722117424011),
#  ('portrayer', 0.5317524671554565),
#  ('plotline', 0.530717134475708),
#  ('superhero', 0.5242215991020203)]
#
#
# --------------------------------------------------
#
# Grupo: ('character', 'title', 'person', 'role')
#
# [('villain', 0.5456328392028809),
#  ('roles', 0.5385805368423462),
#  ('protagonist', 0.5355598330497742),
#  ('characters', 0.5214459300041199),
#  ('titular_character', 0.5156883001327515),
#  ('persona', 0.4862716794013977),
#  ('baddie', 0.480623334646225),
#  ('portrayer', 0.4670199155807495),
#  ('villian', 0.4641403555870056),
#  ('personality', 0.46381837129592896)]
#
#
# --------------------------------------------------
#
# Grupo: ('movie', 'title', 'person', 'role')
#
# [('film', 0.5650711059570312),
#  ('character', 0.554402232170105),
#  ('actor', 0.4989469051361084),
#  ('sequel', 0.4985315799713135),
#  ('titular_character', 0.4942748546600342),
#  ('villain', 0.4937194585800171),
#  ('Ankahee', 0.48767945170402527),
#  ('roles', 0.48333775997161865),
#  ('movies', 0.469716340303421),
#  ('Scorcese', 0.46465742588043213)]
#
#
# --------------------------------------------------

# %%
model.most_similar(positive=('casting','note','name','character','movie','title','person','role'))
# Out:
# [('villain', 0.5476974248886108),
#  ('titular_character', 0.5406320691108704),
#  ('script', 0.5320925712585449),
#  ('characters', 0.5231883525848389),
#  ('film', 0.5155347585678101),
#  ('actor', 0.5099252462387085),
#  ('protagonist', 0.5049434304237366),
#  ('plotline', 0.5017982721328735),
#  ('portrayer', 0.5017803907394409),
#  ('villian', 0.5005027055740356)]

# %%
schema = ['will','sound','music','movie','best','bond','actor','thriller','movie','don','king','return','cast','Friends']

for word in schema:
    print ('Palavra:',word,'\n')
    pp(model.most_similar(word))
    print('\n\n--------------------------------------------------\n')
# Out:
# Palavra: will
#
# [('wil', 0.6996577382087708),
#  ('can', 0.6850050687789917),
#  ('would', 0.6743634939193726),
#  ('should', 0.6727123260498047),
#  ("'ll", 0.6635366678237915),
#  ('willl', 0.6531535387039185),
#  ('must', 0.638272762298584),
#  ('could', 0.6337965726852417),
#  ('may', 0.6271187663078308),
#  ('wll', 0.5843123197555542)]
#
#
# --------------------------------------------------
#
# Palavra: sound
#
# [('sounds', 0.7409017086029053),
#  ('sounding', 0.6120067834854126),
#  ('sonics', 0.5831335783004761),
#  ('bassy', 0.5668196082115173),
#  ('sounded', 0.5613648891448975),
#  ('noises', 0.5532741546630859),
#  ('tinny_sound', 0.5496965646743774),
#  ('tinny', 0.5458980798721313),
#  ('synth_sounds', 0.5311281085014343),
#  ('miking', 0.5238438844680786)]
#
#
# --------------------------------------------------
#
# Palavra: music
#
# [('classical_music', 0.719779372215271),
#  ('jazz', 0.6834639310836792),
#  ('Music', 0.6595720648765564),
#  ('songs', 0.6396344304084778),
#  ('musicians', 0.6336299180984497),
#  ('tunes', 0.6330114603042603),
#  ('musical', 0.618602991104126),
#  ('musics', 0.6148059368133545),
#  ('hip_hop', 0.5746347308158875),
#  ('reggae', 0.5712140798568726)]
#
#
# --------------------------------------------------
#
# Palavra: movie
#
# [('film', 0.8676769733428955),
#  ('movies', 0.8013108968734741),
#  ('films', 0.7363011837005615),
#  ('Movie', 0.6693680286407471),
#  ('horror_flick', 0.6577848792076111),
#  ('sequel', 0.657779335975647),
#  ('romantic_comedy', 0.6413198709487915),
#  ('flick', 0.6321909427642822),
#  ('cinema', 0.6317482590675354),
#  ('cinematic_masterpiece', 0.6252104043960571)]
#
#
# --------------------------------------------------
#
# Palavra: best
#
# [('finest', 0.63836270570755),
#  ('worst', 0.5835111141204834),
#  ('greatest', 0.5824128985404968),
#  ('strongest', 0.5785793662071228),
#  ('smartest', 0.5695626735687256),
#  ('easiest', 0.5528991222381592),
#  ('good', 0.5467195510864258),
#  ('quickest', 0.5399829149246216),
#  ('healthiest', 0.5372903347015381),
#  ('terrific', 0.5293141007423401)]
#
#
# --------------------------------------------------
#
# Palavra: bond
#
# [('bonds', 0.7486939430236816),
#  ('bail', 0.5878828763961792),
#  ('surety_bond', 0.5336567163467407),
#  ('recognizance_bond', 0.5026445388793945),
#  ('muni_bonds', 0.49589216709136963),
#  ('personal_recognizance', 0.47623410820961),
#  ('Bail', 0.47461265325546265),
#  ('muni_bond', 0.4737405478954315),
#  ('surety', 0.45017558336257935),
#  ('Bond', 0.44849133491516113)]
#
#
# --------------------------------------------------
#
# Palavra: actor
#
# [('actress', 0.7930009961128235),
#  ('Actor', 0.7446157932281494),
#  ('thesp', 0.6954970955848694),
#  ('thespian', 0.6651668548583984),
#  ('actors', 0.651985228061676),
#  ('funnyman', 0.6352446675300598),
#  ('entertainer', 0.6184110641479492),
#  ('Shakespearean_actor', 0.6067742109298706),
#  ('ACTOR', 0.6015552878379822),
#  ('comedian', 0.5981959104537964)]
#
#
# --------------------------------------------------
#
# Palavra: thriller
#
# [('thrillers', 0.7824050188064575),
#  ('suspense_thriller', 0.744051456451416),
#  ('psychological_thriller', 0.725502073764801),
#  ('spy_thriller', 0.7165005207061768),
#  ('thriller_starring', 0.6966469287872314),
#  ('espionage_thriller', 0.669083833694458),
#  ('supernatural_thriller', 0.6546313166618347),
#  ('drama', 0.6441254019737244),
#  ('potboiler', 0.6434438824653625),
#  ('horror_thriller', 0.6433016657829285)]
#
#
# --------------------------------------------------
#
# Palavra: movie
#
# [('film', 0.8676769733428955),
#  ('movies', 0.8013108968734741),
#  ('films', 0.7363011837005615),
#  ('Movie', 0.6693680286407471),
#  ('horror_flick', 0.6577848792076111),
#  ('sequel', 0.657779335975647),
#  ('romantic_comedy', 0.6413198709487915),
#  ('flick', 0.6321909427642822),
#  ('cinema', 0.6317482590675354),
#  ('cinematic_masterpiece', 0.6252104043960571)]
#
#
# --------------------------------------------------
#
# Palavra: don
#
# [('donning', 0.745770275592804),
#  ('donned', 0.7095696330070496),
#  ('wear', 0.7078770399093628),
#  ('dons', 0.7011986970901489),
#  ('wearing', 0.6341906785964966),
#  ('Donning', 0.6274535655975342),
#  ('doff', 0.6104148626327515),
#  ('wore', 0.6004799604415894),
#  ('wearin', 0.5627576112747192),
#  ('wears', 0.5499244332313538)]
#
#
# --------------------------------------------------
#
# Palavra: king
#
# [('kings', 0.7138045430183411),
#  ('queen', 0.6510956287384033),
#  ('monarch', 0.6413194537162781),
#  ('crown_prince', 0.6204219460487366),
#  ('prince', 0.6159993410110474),
#  ('sultan', 0.5864823460578918),
#  ('ruler', 0.5797567367553711),
#  ('princes', 0.5646552443504333),
#  ('throne', 0.5422105193138123),
#  ('royal', 0.5239794254302979)]
#
#
# --------------------------------------------------
#
# Palavra: return
#
# [('returning', 0.6680353879928589),
#  ('returns', 0.6663143634796143),
#  ('returned', 0.6630153656005859),
#  ('rejoin', 0.54058837890625),
#  ('Return', 0.5261482000350952),
#  ('leave', 0.5068633556365967),
#  ('depart', 0.49588292837142944),
#  ('Returning', 0.47308263182640076),
#  ('reclaim', 0.4721235930919647),
#  ('Returns', 0.4431346654891968)]
#
#
# --------------------------------------------------
#
# Palavra: cast
#
# [('casts', 0.7218879461288452),
#  ('casting', 0.7188456058502197),
#  ('Cast', 0.6638122797012329),
#  ('casted', 0.6500102281570435),
#  ('Casting', 0.5647554397583008),
#  ('ensemble_cast', 0.5198166966438293),
#  ('actors', 0.500441312789917),
#  ('castmembers', 0.4498378038406372),
#  ('ensemble', 0.44345179200172424),
#  ('thesps', 0.43203386664390564)]
#
#
# --------------------------------------------------
#
# Palavra: Friends
#
# [('FRIENDS', 0.5370755791664124),
#  ('Friend', 0.4768397808074951),
#  ('friends', 0.4659155309200287),
#  ('Neighbors', 0.45019108057022095),
#  ('Pals', 0.4395257830619812),
#  ('Neighbours', 0.4151124358177185),
#  ('Family', 0.40755224227905273),
#  ('Preservation_Society', 0.40176960825920105),
#  ('Furry_Friends', 0.39566266536712646),
#  ('Concerned_Citizens', 0.3920227885246277)]
#
#
# --------------------------------------------------

# %%
schema = ['will','sound','music','movie','best','bond','actor','thriller','movie','don','king','return','cast','Friends']

for word in schema:
    print ('Palavra:',word,'\n')
    pp(model.most_similar(word))
    print('\n\n--------------------------------------------------\n')

# %%
x = ['denzel', 'washington', 'clint', 'eastwood', 'john', 'wayne', 'will', 'smith', 'harrison', 'ford', 'julia', 'roberts', 'tom', 'hanks', 'johnny', 'depp', 'angelina', 'jolie', 'morgan', 'freeman', 'gone', 'wind', 'star', 'wars', 'casablanca', 'lord', 'rings', 'sound', 'music', 'wizard', 'oz', 'notebook', 'forrest', 'gump', 'princess', 'bride', 'godfather']


for word in x:
    print ('Palavra:',word,'\n')
    if word in model:
        pp(model.most_similar(word))
    else:
        print('Not in model')
    print('\n\n--------------------------------------------------\n')
# Out:
# Palavra: denzel
#
# Not in model
#
#
# --------------------------------------------------
#
# Palavra: washington
#
# [('obama', 0.6320589780807495),
#  ('america', 0.6175941228866577),
#  ('charles', 0.599067211151123),
#  ('michigan', 0.594323992729187),
#  ('american', 0.5877395272254944),
#  ('lincoln', 0.582454264163971),
#  ('austin', 0.58155357837677),
#  ('chicago', 0.5770257115364075),
#  ('miami', 0.5758569836616516),
#  ('wisconsin', 0.5735213756561279)]
#
#
# --------------------------------------------------
#
# Palavra: clint
#
# Not in model
#
#
# --------------------------------------------------
#
# Palavra: eastwood
#
# Not in model
#
#
# --------------------------------------------------
#
# Palavra: john
#
# [('dave', 0.6527622938156128),
#  ('jeff', 0.6436978578567505),
#  ('robert', 0.6381956338882446),
#  ('pete', 0.6303378343582153),
#  ('jason', 0.6301511526107788),
#  ('charles', 0.6275457739830017),
#  ('david', 0.6239280700683594),
#  ('gary', 0.620205283164978),
#  ('mary', 0.6196797490119934),
#  ('stewart', 0.6155771017074585)]
#
#
# --------------------------------------------------
#
# Palavra: wayne
#
# [('ross', 0.6415929794311523),
#  ('johnson', 0.6304833889007568),
#  ('henry', 0.6264059543609619),
#  ('steve', 0.625153660774231),
#  ('clark', 0.621313214302063),
#  ('robert', 0.6195943355560303),
#  ('evans', 0.6186923980712891),
#  ('lewis', 0.6179536581039429),
#  ('jackson', 0.615801990032196),
#  ('williams', 0.615409255027771)]
#
#
# --------------------------------------------------
#
# Palavra: will
#
# [('wil', 0.6996577382087708),
#  ('can', 0.6850050687789917),
#  ('would', 0.6743634939193726),
#  ('should', 0.6727123260498047),
#  ("'ll", 0.6635366678237915),
#  ('willl', 0.6531535387039185),
#  ('must', 0.638272762298584),
#  ('could', 0.6337965726852417),
#  ('may', 0.6271187663078308),
#  ('wll', 0.5843123197555542)]
#
#
# --------------------------------------------------
#
# Palavra: smith
#
# [('thomas', 0.6172632575035095),
#  ('gordon', 0.6158428192138672),
#  ('wilson', 0.6154751181602478),
#  ('clark', 0.614583432674408),
#  ('evans', 0.6131755113601685),
#  ('anderson', 0.6114382743835449),
#  ('taylor', 0.610157310962677),
#  ('harris', 0.6089308261871338),
#  ('robert', 0.6067844033241272),
#  ('larry', 0.6044260263442993)]
#
#
# --------------------------------------------------
#
# Palavra: harrison
#
# Not in model
#
#
# --------------------------------------------------
#
# Palavra: ford
#
# [('fording', 0.47911643981933594),
#  ('honda', 0.4750613868236542),
#  ('ross', 0.4673130512237549),
#  ('toyota', 0.46509745717048645),
#  ('porsche', 0.4610391855239868),
#  ('chevy', 0.456371545791626),
#  ('suv', 0.4561130702495575),
#  ('lincoln', 0.4494035243988037),
#  ('dale', 0.4400670528411865),
#  ('Vauxhall_Nova', 0.44004228711128235)]
#
#
# --------------------------------------------------
#
# Palavra: julia
#
# Not in model
#
#
# --------------------------------------------------
#
# Palavra: roberts
#
# Not in model
#
#
# --------------------------------------------------
#
# Palavra: tom
#
# [('toms', 0.659879744052887),
#  ('jake', 0.6178301572799683),
#  ('gobbler', 0.5771142840385437),
#  ('keith', 0.5633037090301514),
#  ('jim', 0.561802864074707),
#  ('tommy', 0.5497992038726807),
#  ('john', 0.5449903011322021),
#  ('jay', 0.5359062552452087),
#  ('drake', 0.5345537662506104),
#  ('amy', 0.5327091217041016)]
#
#
# --------------------------------------------------
#
# Palavra: hanks
#
# Not in model
#
#
# --------------------------------------------------
#
# Palavra: johnny
#
# [('robert', 0.5379736423492432),
#  ('sarah', 0.5375268459320068),
#  ('patrick', 0.5368435382843018),
#  ('sharon', 0.533951461315155),
#  ('luke', 0.5279735922813416),
#  ('george', 0.5272600054740906),
#  ('alan', 0.5256290435791016),
#  ('dave', 0.5251407623291016),
#  ('tommy', 0.5238155126571655),
#  ('greg', 0.5229476094245911)]
#
#
# --------------------------------------------------
#
# Palavra: depp
#
# Not in model
#
#
# --------------------------------------------------
#
# Palavra: angelina
#
# Not in model
#
#
# --------------------------------------------------
#
# Palavra: jolie
#
# Not in model
#
#
# --------------------------------------------------
#
# Palavra: morgan
#
# [('eddie', 0.6900689601898193),
#  ('dave', 0.6822458505630493),
#  ('ross', 0.6788012981414795),
#  ('jeff', 0.6766823530197144),
#  ('alex', 0.6690089702606201),
#  ('joseph', 0.6664299368858337),
#  ('gordon', 0.6645047664642334),
#  ('anderson', 0.6625774502754211),
#  ('greg', 0.6585044860839844),
#  ('anthony', 0.6566369533538818)]
#
#
# --------------------------------------------------
#
# Palavra: freeman
#
# [('freemen', 0.536767840385437),
#  ('perry', 0.42658811807632446),
#  ('laird', 0.41869255900382996),
#  ('Knighthood', 0.4166279435157776),
#  ('plowman', 0.41394132375717163),
#  ('dustman', 0.4120287299156189),
#  ('town_crier', 0.4010693430900574),
#  ('direct_descendent', 0.3983164429664612),
#  ('highwayman', 0.39558231830596924),
#  ('bard', 0.39430490136146545)]
#
#
# --------------------------------------------------
#
# Palavra: gone
#
# [('went', 0.6404926776885986),
#  ('go', 0.6219985485076904),
#  ('goes', 0.5667665004730225),
#  ('fallen', 0.5528549551963806),
#  ('come', 0.5440619587898254),
#  ('gotten', 0.5398510694503784),
#  ('done', 0.5011739730834961),
#  ('moved', 0.4977017045021057),
#  ('going', 0.49731671810150146),
#  ('disappeared', 0.48638564348220825)]
#
#
# --------------------------------------------------
#
# Palavra: wind
#
# [('winds', 0.7204775810241699),
#  ('Wind', 0.6752252578735352),
#  ('gusts', 0.5962637662887573),
#  ('Winds', 0.5948995351791382),
#  ('breeze', 0.592047929763794),
#  ('wind_blows', 0.589418888092041),
#  ('breezes', 0.5883914828300476),
#  ('gusty', 0.5816086530685425),
#  ('wind_gusts', 0.5773173570632935),
#  ('gust', 0.575178325176239)]
#
#
# --------------------------------------------------
#
# Palavra: star
#
# [('stars', 0.7763955593109131),
#  ('superstar', 0.7340599298477173),
#  ('starlet', 0.6381063461303711),
#  ('megastar', 0.6165119409561157),
#  ('heart_throb', 0.5726701617240906),
#  ('heartthrob', 0.543801486492157),
#  ('superstars', 0.5326131582260132),
#  ('standout', 0.5210359692573547),
#  ('stardom', 0.5145710110664368),
#  ('hunk', 0.5054152011871338)]
#
#
# --------------------------------------------------
#
# Palavra: wars
#
# [('war', 0.7484659552574158),
#  ('Wars', 0.6566379070281982),
#  ('War', 0.5720333456993103),
#  ('warfare', 0.5526193380355835),
#  ('jihads', 0.5412110686302185),
#  ('insurgencies', 0.5110849738121033),
#  ('battles', 0.49461567401885986),
#  ('conflicts', 0.4942978620529175),
#  ('holocausts', 0.4881473183631897),
#  ('intifadas', 0.48687049746513367)]
#
#
# --------------------------------------------------
#
# Palavra: casablanca
#
# Not in model
#
#
# --------------------------------------------------
#
# Palavra: lord
#
# [('lords', 0.6912548542022705),
#  ('god', 0.6350281238555908),
#  ('Lord', 0.5923005938529968),
#  ('lordship', 0.5454695224761963),
#  ('archangel', 0.5204272270202637),
#  ('overlord', 0.5066044330596924),
#  ('Almighty', 0.5031397342681885),
#  ('God_Almighty', 0.49179577827453613),
#  ('God', 0.4889553487300873),
#  ('Verily', 0.48285794258117676)]
#
#
# --------------------------------------------------
#
# Palavra: rings
#
# [('ring', 0.7108522057533264),
#  ('diamond_ring', 0.4947955012321472),
#  ('bauble', 0.48497718572616577),
#  ('pendant', 0.4820955693721771),
#  ('necklace', 0.46326765418052673),
#  ('baubles', 0.45639365911483765),
#  ('lockets', 0.4527300298213959),
#  ('sterling_silver', 0.44664886593818665),
#  ('pendants', 0.44546598196029663),
#  ('necklaces', 0.4430774450302124)]
#
#
# --------------------------------------------------
#
# Palavra: sound
#
# [('sounds', 0.7409017086029053),
#  ('sounding', 0.6120067834854126),
#  ('sonics', 0.5831335783004761),
#  ('bassy', 0.5668196082115173),
#  ('sounded', 0.5613648891448975),
#  ('noises', 0.5532741546630859),
#  ('tinny_sound', 0.5496965646743774),
#  ('tinny', 0.5458980798721313),
#  ('synth_sounds', 0.5311281085014343),
#  ('miking', 0.5238438844680786)]
#
#
# --------------------------------------------------
#
# Palavra: music
#
# [('classical_music', 0.719779372215271),
#  ('jazz', 0.6834639310836792),
#  ('Music', 0.6595720648765564),
#  ('songs', 0.6396344304084778),
#  ('musicians', 0.6336299180984497),
#  ('tunes', 0.6330114603042603),
#  ('musical', 0.618602991104126),
#  ('musics', 0.6148059368133545),
#  ('hip_hop', 0.5746347308158875),
#  ('reggae', 0.5712140798568726)]
#
#
# --------------------------------------------------
#
# Palavra: wizard
#
# [('wizards', 0.7168444395065308),
#  ('Wizard', 0.5538618564605713),
#  ('sorcerer', 0.5371533036231995),
#  ('wizardry', 0.5160967707633972),
#  ('wiz', 0.513116717338562),
#  ('wizardly', 0.49428999423980713),
#  ('magician', 0.4863496422767639),
#  ('genius', 0.47884413599967957),
#  ('savant', 0.4767761826515198),
#  ('whiz', 0.47650596499443054)]
#
#
# --------------------------------------------------
#
# Palavra: oz
# [('ounces', 0.7894831299781799),
#  ('ounce', 0.7191354036331177),
#  ('ozs', 0.6963871717453003),
#  ('oz_Au', 0.619745671749115),
#  ('fl_oz', 0.5970772504806519),
#  ('oz_Ag', 0.5839002132415771),
#  ('###/ounce', 0.5822954177856445),
#  ('#.#Moz', 0.5808774828910828),
#  ('1oz', 0.5734949111938477),
#  ('PGM_ounces', 0.5650689601898193)]
#
#
# --------------------------------------------------
#
# Palavra: notebook
#
# [('notebooks', 0.8130300641059875),
#  ('notebook_PC', 0.7035420536994934),
#  ('laptop', 0.6785783171653748),
#  ('Notebook', 0.6411164999008179),
#  ('notebook_PCs', 0.6308704614639282),
#  ('Notebooks', 0.6298628449440002),
#  ('netbook', 0.6259939670562744),
#  ('notebook_computers', 0.6200518608093262),
#  ('laptops', 0.5986273884773254),
#  ('ultraportable_laptop', 0.5867843627929688)]
#
#
# --------------------------------------------------
#
# Palavra: forrest
#
# Not in model
#
#
# --------------------------------------------------
#
# Palavra: gump
#
# Not in model
#
#
# --------------------------------------------------
#
# Palavra: princess
#
# [('princesses', 0.7389641404151917),
#  ('queen', 0.7070531249046326),
#  ('prince', 0.6986510157585144),
#  ('Princess', 0.6705749034881592),
#  ('fairy_princess', 0.589386522769928),
#  ('handsome_prince', 0.577378511428833),
#  ('Princesses', 0.5768439769744873),
#  ('Prince_Charming', 0.568822979927063),
#  ('fairy', 0.5677118301391602),
#  ('monarch', 0.5586379766464233)]
#
#
# --------------------------------------------------
#
# Palavra: bride
#
# [('wedding', 0.7104349732398987),
#  ('bridegroom', 0.7067198157310486),
#  ('groom', 0.67582106590271),
#  ('brides', 0.6602778434753418),
#  ('newlyweds', 0.640753984451294),
#  ('wedding_dress', 0.6177147626876831),
#  ('fiancé', 0.6071049571037292),
#  ('fiance', 0.597750186920166),
#  ('fiancée', 0.5943275690078735),
#  ('blushing_bride', 0.5929684638977051)]
#
#
# --------------------------------------------------
#
# Palavra: godfather
#
# [('godfathers', 0.5788048505783081),
#  ('godson', 0.5327345132827759),
#  ('father', 0.5315773487091064),
#  ('godmother', 0.5150611996650696),
#  ('uncle', 0.4940725564956665),
#  ('forefather', 0.4735293388366699),
#  ('guru', 0.4733124375343323),
#  ('Godfather', 0.47151264548301697),
#  ('legend', 0.47080832719802856),
#  ('eldest_son', 0.4647064805030823)]
#
#
# --------------------------------------------------

# %%
'car' in model
# Out:
# True
